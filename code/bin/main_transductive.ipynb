# %%
data_name = 'FB15K237'
model_id = 'main_transductive'

# %%
#difine the names for saving
model_name = 'Model_' + model_id + '_' + data_name
one_hop_model_name = 'One_hop_model_' + model_id + '_' + data_name
ids_name = 'IDs_' + model_id + '_' + data_name

# %%
import librosa
import opensmile
import os
import sys
import numpy as np
import random
import pickle

from collections import defaultdict
from copy import deepcopy
from sklearn.utils import shuffle
from sys import getsizeof

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras import initializers
from tensorflow.keras.utils import plot_model

# %%
class LoadKG:
    
    def __init__(self):
        
        self.x = 'Hello'
        
    def load_train_data(self, data_path, one_hop, data, s_t_r, entity2id, id2entity,
                     relation2id, id2relation):
        
        data_ = set()
    
        ####load the train, valid and test set##########
        with open (data_path, 'r') as f:
            
            data_ini = f.readlines()
                        
            for i in range(len(data_ini)):
            
                x = data_ini[i].split()
                
                x_ = tuple(x)
                
                data_.add(x_)
        
        ####relation dict#################
        index = len(relation2id)
     
        for key in data_:
            
            if key[1] not in relation2id:
                
                relation = key[1]
                
                relation2id[relation] = index
                
                id2relation[index] = relation
                
                index += 1
                
                #the inverse relation
                iv_r = '_inverse_' + relation
                
                relation2id[iv_r] = index
                
                id2relation[index] = iv_r
                
                index += 1
        
        #get the id of the inverse relation, by above definition, initial relation has 
        #always even id, while inverse relation has always odd id.
        def inverse_r(r):
            
            if r % 2 == 0: #initial relation
                
                iv_r = r + 1
            
            else: #inverse relation
                
                iv_r = r - 1
            
            return(iv_r)
        
        ####entity dict###################
        index = len(entity2id)
        
        for key in data_:
            
            source, target = key[0], key[2]
            
            if source not in entity2id:
                                
                entity2id[source] = index
                
                id2entity[index] = source
                
                index += 1
            
            if target not in entity2id:
                
                entity2id[target] = index
                
                id2entity[index] = target
                
                index += 1
                
        #create the set of triples using id instead of string        
        for ele in data_:
            
            s = entity2id[ele[0]]
            
            r = relation2id[ele[1]]
            
            t = entity2id[ele[2]]
            
            if (s,r,t) not in data:
                
                data.add((s,r,t))
            
            s_t_r[(s,t)].add(r)
            
            if s not in one_hop:
                
                one_hop[s] = set()
            
            one_hop[s].add((r,t))
            
            if t not in one_hop:
                
                one_hop[t] = set()
            
            r_inv = inverse_r(r)
            
            s_t_r[(t,s)].add(r_inv)
            
            one_hop[t].add((r_inv,s))
            
        #change each set in one_hop to list
        for e in one_hop:
            
            one_hop[e] = list(one_hop[e])

# %%
class ObtainPathsByDynamicProgramming:

    def __init__(self, amount_bd=50, size_bd=50, threshold=20000):
        
        self.amount_bd = amount_bd #how many Tuples we choose in one_hop[node] for next recursion
                        
        self.size_bd = size_bd #size bound limit the number of paths to a target entity t
        
        #number of times paths with specific length been performed for recursion
        self.threshold = threshold
        
    '''
    Given an entity s, the function will find the paths from s to other entities, using recursion.
    
    One may refer to LeetCode Problem 797 for details:
        https://leetcode.com/problems/all-paths-from-source-to-target/
    '''
    def obtain_paths(self, mode, s, t_input, lower_bd, upper_bd, one_hop):

        if type(lower_bd) != type(1) or lower_bd < 1:
            
            raise TypeError("!!! invalid lower bound setting, must >= 1 !!!")
            
        if type(upper_bd) != type(1) or upper_bd < 1:
            
            raise TypeError("!!! invalid upper bound setting, must >= 1 !!!")
            
        if lower_bd > upper_bd:
            
            raise TypeError("!!! lower bound must not exced upper bound !!!")
            
        if s not in one_hop:
            
            raise ValueError('!!! entity not in one_hop. Please work on existing entities')

        #here is the result dict. Its key is each entity t sharing paths from s
        #The value of each t is a set containing the paths from s to t
        #These paths can be either the direct connection r, or a multi-hop path
        res = defaultdict(set)
        
        #qualified_t contains the types of t we want to consider,
        #that is, what t will be added to the result set.
        qualified_t = set()

        #under this mode, we will only consider the direct neighbour of s
        if mode == 'direct_neighbour':
        
            for Tuple in one_hop[s]:
            
                t = Tuple[1]
                
                qualified_t.add(t)
        
        #under this mode, we will only consider one specified entity t
        elif mode == 'target_specified':
            
            qualified_t.add(t_input)
        
        #under this mode, we will consider any entity
        elif mode == 'any_target':
            
            for s_any in one_hop:
                
                qualified_t.add(s_any)
                
        else:
            
            raise ValueError('not a valid mode')
        
        '''
        We use recursion to find the paths
        On current node with the path [r1, ..., rk] and on-path entities {s, e1, ..., ek-1, node}
        from s to this node, we will further find the direct neighbor t' of this node. 
        If t' is not an on-path entity (not among s, e1,...ek-1, node), we recursively proceed to t' 
        '''
        def helper(node, path, on_path_en, res, qualified_t, lower_bd, upper_bd, one_hop, count_dict):

            #when the current path is within lower_bd and upper_bd, 
            #and the node is among the qualified t, and it has not been fill of paths w.r.t size_limit,
            #we will add this path to the node
            if (len(path) >= lower_bd) and (len(path) <= upper_bd) and (
                node in qualified_t) and (len(res[node]) < self.size_bd):
                
                res[node].add(tuple(path))
                    
            #won't start new recursions if the current path length already reaches upper limit
            #or the number of recursions performed on this length has reached the limit
            if (len(path) < upper_bd) and (count_dict[len(path)] <= self.threshold):
                                
                #temp list is the id list for us to go-over one_hop[node]
                temp_list = [i for i in range(len(one_hop[node]))]
                random.shuffle(temp_list) #so we random-shuffle the list
                
                #only take 20 recursions if there are too many (r,t)
                for i in temp_list[:self.amount_bd]:
                    
                    #obtain tuple of (r,t)
                    Tuple = one_hop[node][i]
                    r, t = Tuple[0], Tuple[1]
                    
                    #add to count_dict even if eventually this step not proceed
                    count_dict[len(path)] += 1
                    
                    #if t not on the path and we not exceed the computation threshold, 
                    #then finally proceed to next recursion
                    if (t not in on_path_en) and (count_dict[len(path)] <= self.threshold):

                        helper(t, path + [r], on_path_en.union({t}), res, qualified_t, 
                               lower_bd, upper_bd, one_hop, count_dict)

        length_dict = defaultdict(int)
        count_dict = defaultdict(int)
        
        helper(s, [], {s}, res, qualified_t, lower_bd, upper_bd, one_hop, count_dict)
        
        return(res, count_dict)

# %%
train_path = '../data/' + data_name + '/train.txt'
valid_path = '../data/' + data_name + '/valid.txt'

# %%
#load the classes
Class_1 = LoadKG()
Class_2 = ObtainPathsByDynamicProgramming()

# %%
#define the dictionaries and sets for load KG
one_hop = dict() 
data = set()
s_t_r = defaultdict(set)

#define the dictionaries, which is shared by initail and inductive train/valid/test
entity2id = dict()
id2entity = dict()
relation2id = dict()
id2relation = dict()

#fill in the sets and dicts
Class_1.load_train_data(train_path, one_hop, data, s_t_r,
                        entity2id, id2entity, relation2id, id2relation)

# %%
#define the dictionaries and sets for load KG
one_hop_valid = dict() 
data_valid = set()
s_t_r_valid = defaultdict(set)

#fill in the sets and dicts
Class_1.load_train_data(valid_path, one_hop_valid, data_valid, s_t_r_valid,
                        entity2id, id2entity, relation2id, id2relation)

# %% [markdown]
# #### Build the path-based siamese neural network structure
#
# We use biLSTM to train on the input path embedding sequence to predict the output embedding or the relation.

# %%
# Input layer, using integer to represent each relation type
#note that inputs_path is the path inputs, while inputs_out_re is the output relation inputs
fst_path = keras.Input(shape=(None,), dtype="int32")
scd_path = keras.Input(shape=(None,), dtype="int32")
thd_path = keras.Input(shape=(None,), dtype="int32")

#the relation input layer (for output embedding)
id_rela = keras.Input(shape=(None,), dtype="int32")

# Embed each integer in a 300-dimensional vector as input,
# note that we add another "space holder" embedding, 
# which hold the spaces if the initial length of paths are not the same
in_embd_var = layers.Embedding(len(relation2id)+1, 300)

# Obtain the embedding
fst_p_embd = in_embd_var(fst_path)
scd_p_embd = in_embd_var(scd_path)
thd_p_embd = in_embd_var(thd_path)

# Embed each integer in a 300-dimensional vector as output
rela_embd = layers.Embedding(len(relation2id)+1, 300)(id_rela)

#add 2 layer bi-directional LSTM
lstm_layer_1 = layers.Bidirectional(layers.LSTM(150, return_sequences=True))
lstm_layer_2 = layers.Bidirectional(layers.LSTM(150, return_sequences=True))

#first LSTM layer
fst_lstm_mid = lstm_layer_1(fst_p_embd)
scd_lstm_mid = lstm_layer_1(scd_p_embd)
thd_lstm_mid = lstm_layer_1(thd_p_embd)

#second LSTM layer
fst_lstm_out = lstm_layer_2(fst_lstm_mid)
scd_lstm_out = lstm_layer_2(scd_lstm_mid)
thd_lstm_out = lstm_layer_2(thd_lstm_mid)

#reduce max
fst_reduce_max = tf.reduce_max(fst_lstm_out, axis=1)
scd_reduce_max = tf.reduce_max(scd_lstm_out, axis=1)
thd_reduce_max = tf.reduce_max(thd_lstm_out, axis=1)

#concatenate the output vector from both siamese tunnel: (Batch, 900)
path_concat = layers.concatenate([fst_reduce_max, scd_reduce_max, thd_reduce_max], axis=-1)

#add dropout on top of the concatenation from all channels
dropout = layers.Dropout(0.25)(path_concat)

#multiply into output embd size by dense layer: (Batch, 300)
path_out_vect = layers.Dense(300, activation='tanh')(dropout)

#remove the time dimension from the output embd since there is only one step
rela_out_embd = tf.reduce_sum(rela_embd, axis=1)

# Normalize the vectors to have unit length
path_out_vect_norm = tf.math.l2_normalize(path_out_vect, axis=-1)
rela_out_embd_norm = tf.math.l2_normalize(rela_out_embd, axis=-1)

# Calculate the dot product
dot_product = layers.Dot(axes=-1)([path_out_vect_norm, rela_out_embd_norm])

#put together the model
model = keras.Model([fst_path, scd_path, thd_path, id_rela], dot_product)
# Out:
# 2023-03-14 10:23:15.188576: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#config the Adam optimizer 
opt = keras.optimizers.Adam(learning_rate=0.0005, decay=1e-6)

#compile the model
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['binary_accuracy'])

# %% [markdown]
# #### Build the subgraph-based siamese neural network

# %%
#each input is an vector with number of relations to be dim:
#each dim represent the existence (1) or not (0) of an out-going relation from the entity
source_path_1 = keras.Input(shape=(None,), dtype="int32")
source_path_2 = keras.Input(shape=(None,), dtype="int32")
source_path_3 = keras.Input(shape=(None,), dtype="int32")

target_path_1 = keras.Input(shape=(None,), dtype="int32")
target_path_2 = keras.Input(shape=(None,), dtype="int32")
target_path_3 = keras.Input(shape=(None,), dtype="int32")

#the relation input layer (for output embedding)
id_rela_ = keras.Input(shape=(None,), dtype="int32")

# Embed each integer in a 300-dimensional vector as input,
# note that we add another "space holder" embedding, 
# which hold the spaces if the initial length of paths are not the same
in_embd_var_ = layers.Embedding(len(relation2id)+1, 300)

# Obtain the source embeddings
source_embd_1 = in_embd_var_(source_path_1)
source_embd_2 = in_embd_var_(source_path_2)
source_embd_3 = in_embd_var_(source_path_3)

#Obtain the target embeddings
target_embd_1 = in_embd_var_(target_path_1)
target_embd_2 = in_embd_var_(target_path_2)
target_embd_3 = in_embd_var_(target_path_3)

# Embed each integer in a 300-dimensional vector as output
rela_embd_ = layers.Embedding(len(relation2id)+1, 300)(id_rela_)

#add 2 layer bi-directional LSTM network
lstm_1 = layers.Bidirectional(layers.LSTM(150, return_sequences=True))
lstm_2 = layers.Bidirectional(layers.LSTM(150, return_sequences=True))

###source lstm implimentation########
#first LSTM layer
source_mid_1 = lstm_1(source_embd_1)
source_mid_2 = lstm_1(source_embd_2)
source_mid_3 = lstm_1(source_embd_3)

#second LSTM layer
source_out_1 = lstm_2(source_mid_1)
source_out_2 = lstm_2(source_mid_2)
source_out_3 = lstm_2(source_mid_3)

#reduce max
source_max_1 = tf.reduce_max(source_out_1, axis=1)
source_max_2 = tf.reduce_max(source_out_2, axis=1)
source_max_3 = tf.reduce_max(source_out_3, axis=1)

#concatenate the output vector from both siamese tunnel: (Batch, 900)
source_concat = layers.concatenate([source_max_1, source_max_2, source_max_3], axis=-1)

#add dropout on top of the concatenation from all channels
source_dropout = layers.Dropout(0.25)(source_concat)

###target lstm implimentation########
#first LSTM layer
target_mid_1 = lstm_1(target_embd_1)
target_mid_2 = lstm_1(target_embd_2)
target_mid_3 = lstm_1(target_embd_3)

#second LSTM layer
target_out_1 = lstm_2(target_mid_1)
target_out_2 = lstm_2(target_mid_2)
target_out_3 = lstm_2(target_mid_3)

#reduce max
target_max_1 = tf.reduce_max(target_out_1, axis=1)
target_max_2 = tf.reduce_max(target_out_2, axis=1)
target_max_3 = tf.reduce_max(target_out_3, axis=1)

#concatenate the output vector from both siamese tunnel: (Batch, 900)
target_concat = layers.concatenate([target_max_1, target_max_2, target_max_3], axis=-1)

#add dropout on top of the concatenation from all channels
target_dropout = layers.Dropout(0.25)(target_concat)

#further concatenate source and target output embeddings
final_concat = layers.concatenate([source_dropout, target_dropout], axis=-1)

#multiply into output embd size by dense layer: (Batch, 300)
out_vect = layers.Dense(300, activation='tanh')(final_concat)

#remove the time dimension from the output embd since there is only one step
rela_out_embd_ = tf.reduce_sum(rela_embd_, axis=1)

# Normalize the vectors to have unit length
out_vect_norm = tf.math.l2_normalize(out_vect, axis=-1)
rela_out_embd_norm_ = tf.math.l2_normalize(rela_out_embd_, axis=-1)

# Calculate the dot product
dot_product_ = layers.Dot(axes=-1)([out_vect_norm, rela_out_embd_norm_])

#put together the model
model_2 = keras.Model([source_path_1, source_path_2, source_path_3,
                       target_path_1, target_path_2, target_path_3, id_rela_], dot_product_)

# %%
#config the Adam optimizer 
opt_ = keras.optimizers.Adam(learning_rate=0.0005, decay=1e-6)

#compile the model
model_2.compile(loss='binary_crossentropy', optimizer=opt_, metrics=['binary_accuracy'])

# %% [markdown]
# ### Build the big-batch for path-based model
# We will build the big-batch for the path-based model training. That is, we will build three list to store three paths, respectively. But different from the relation prediction, this time the negative samples are paths from s to another t'. We will keep the relation r invariant.
#
# In order to reduce computational complexity, we will run the path-finding algorithm for each entity e in the dataset before the training. That is, for each entity e, we will have two dictionaries. Dict 1 stores the paths between e and any other entities in the dataset. Will Dict 2 stores the paths between e and its direct neighbors. The two dicts will be used and invariant throughout the training.
#
# * At each step, three different paths between two entities s and t are selected. Each path is append to one of the list.
# * If this step is for positive samples, t will be the directly connected entity from s. Then, relation r will be the existing connection from s to t. The label will be 1.
# * If this step is for negative samples, t will be another entity that can be reached from s, but not directly connected. Relation r will be the same. The label will be 0.
# * In practice, the positive step is always fallowed by a negative step. That is, for positive step, we have s and t. But for negative step we have s and t'. Relaiton r will be the same in both steps.
# * We do this until all the entity in the dataset is visited as s. Then we complete building the entire batches for one session. The model will be trained on these batches for fixed number of epochs in each session.
#
# **For source and target entity prediciton, we will need to train using both (s,r,t) triple and (t,r-1,s) triple**

# %%
#function to build the big batche for path-based training
def build_big_batches_path(lower_bd, upper_bd, data, one_hop, s_t_r,
                      x_p_list, x_r_list, y_list,
                      relation2id, entity2id, id2relation, id2entity):
    
    #the set of all relation IDs
    relation_id_set = set()
    
    for i in range(len(id2relation)):
        
        if i not in id2relation:
            raise ValueError('error when generaing id2relation')
        
        relation_id_set.add(i)
    
    num_r = len(id2relation)
    
    #in case not all entities in entity2id are in one_hop, 
    #so we need to find out who are indeed in
    existing_ids = set()
    
    for s_1 in one_hop:
        existing_ids.add(s_1)
        
    existing_ids = list(existing_ids)
    random.shuffle(existing_ids)
    
    count = 0
    for s in existing_ids:
        
        #impliment the path finding algorithm to find paths between s and t
        #result 1 is for postitive case (direct neighbor)
        #result 2 is for negative case (any reachable entity)
        result_1 = defaultdict(set)

        result_2, length_dict_2 = Class_2.obtain_paths('any_target', s, 'any', lower_bd, upper_bd, one_hop)

        for t_ in result_2:

            #if (s, t_) or (t_, s) in s_t_r, then it t_ is a direct neighbor of s
            if (s, t_) in s_t_r or (t_, s) in s_t_r:
                result_1[t_] = deepcopy(result_2[t_])
        
        #qualified_1 stores the direct neighbors with at least 3 differetn paths from s
        #qualified_2 stores any entity with at least 3 diff paths from s
        qualified_1, qualified_2 = set(), set()
        
        for t in result_1:
            if len(result_1[t]) >= 3:
                qualified_1.add(t)
        
        for t in result_2:
            if len(result_2[t]) >= 3:
                qualified_2.add(t)
        
        #proceed if both qualified_1 and qualified_2 are not empty
        if len(qualified_1) > 0 and len(qualified_2) > 0:
            
            qualified_1 = list(qualified_1)
            qualified_2 = list(qualified_2)
            
            for iteration in range(5):
                
                random.shuffle(qualified_1)
            
                for t in qualified_1:

                    if len(s_t_r[(s,t)]) == 0:

                        raise ValueError(s, t, id2entity[s], id2entity[t])

                    #we randomly choose the t_ for negative samples each time
                    t_ = random.choice(qualified_2)

                    #we already know there are more than 3 paths between s and t, 
                    #and s_t_r is not empty, so directly proceed
                    temp_r_list = list(s_t_r[(s,t)])
                    r = random.choice(temp_r_list)

                    #####positive#####################
                    #obtain the list form of all the paths from s to t
                    temp_path_list = list(result_1[t])
                    temp_pair = random.sample(temp_path_list, 3)
                    path_1, path_2, path_3 = temp_pair[0], temp_pair[1], temp_pair[2]

                    #append the paths: note that we add the space holder id at the end of the shorter path
                    x_p_list['1'].append(list(path_1) + [num_r]*abs(len(path_1)-upper_bd))
                    x_p_list['2'].append(list(path_2) + [num_r]*abs(len(path_2)-upper_bd))
                    x_p_list['3'].append(list(path_3) + [num_r]*abs(len(path_3)-upper_bd))

                    #append relation
                    x_r_list.append([r])
                    y_list.append(1.)

                    del(temp_path_list, temp_pair, path_1, path_2, path_3)

                    #####negative#####################
                    #obtain the list form of all the paths from s to t
                    temp_path_list = list(result_2[t_])
                    temp_pair = random.sample(temp_path_list, 3)
                    path_1, path_2, path_3 = temp_pair[0], temp_pair[1], temp_pair[2]

                    #append the paths: note that we add the space holder id at the end
                    #of the shorter path
                    x_p_list['1'].append(list(path_1) + [num_r]*abs(len(path_1)-upper_bd))
                    x_p_list['2'].append(list(path_2) + [num_r]*abs(len(path_2)-upper_bd))
                    x_p_list['3'].append(list(path_3) + [num_r]*abs(len(path_3)-upper_bd))

                    #append relation
                    x_r_list.append([r])
                    y_list.append(0.)

                    del(temp_path_list, temp_pair, path_1, path_2, path_3)
        
        count += 1
        if count % 100 == 0:
            print('generating big-batches for path-based model', count, len(existing_ids))

# %% [markdown]
# ### Build the big-batch for the subgraph-based network training
#
# Different from relation prediciton, the negative sample will be a corrupted triple (s,r,t') or a (s',r,t). Also, in order to reduce computational complexity, we will store the subgraph of each entity e at the beginning.
#
# * At each step, we will select one triple (s,r,t) from the dataset. Then, subgraphs of s and t are selected.
# * We will select three paths for each of source and target entity from their subgraphs, respectively. Add them to the corresponding list.
# * If this is a positive sample step, (s,r,t) is a true triple.
# * If this is a negative sample step, we will use either (s',r,t) or (s,r,t').
# * Similarly, one negative sample step always follows one positive step.
# * After we go over all the triples, we built the big-batch for one session. Then, fixed number of epoches are trained. Then we enter a new session to rebuilt the big-batch. However, as we indicated, the subgraphs are stored and won't change aross different sessions.

# %%
#Again, it is too slow to run the path-finding algorithm again and again on the complete FB15K-237
#Instead, we will find the subgraph for each entity once.
#then in the subgraph based training, the subgraphs are stored and used for multiple times
def store_subgraph_dicts(lower_bd, upper_bd, data, one_hop, s_t_r,
                         relation2id, entity2id, id2relation, id2entity):
    
    #the set of all relation IDs
    relation_id_set = set()
    
    for i in range(len(id2relation)):
        
        if i not in id2relation:
            raise ValueError('error when generaing id2relation')
        
        relation_id_set.add(i)
    
    num_r = len(id2relation)
    
    #in case not all entities in entity2id are in one_hop, 
    #so we need to find out who are indeed in
    existing_ids = set()
    
    for s_1 in one_hop:
        existing_ids.add(s_1)
    
    #the ids to start path finding
    existing_ids = list(existing_ids)
    random.shuffle(existing_ids)
    
    #Dict stores the subgraph for each entity
    Dict_1 = dict()
    
    count = 0
    for s in existing_ids:
        
        path_set = set()
            
        result, length_dict = Class_2.obtain_paths('any_target', s, 'any', lower_bd, upper_bd, one_hop)

        for t_ in result:
            for path in result[t_]:
                path_set.add(path)

        del(result, length_dict)
        
        path_list = list(path_set)
        
        path_select = random.sample(path_list, min(len(path_list), 100))
            
        Dict_1[s] = deepcopy(path_select)
        
        count += 1
        if count % 100 == 0:
            print('generating and storing paths for the path-based model', count, len(existing_ids))
        
    return(Dict_1)

# %%
#function to build the big-batch for one-hope neighbor training
def build_big_batches_subgraph(lower_bd, upper_bd, data, one_hop, s_t_r,
                      x_s_list, x_t_list, x_r_list, y_list, Dict,
                      relation2id, entity2id, id2relation, id2entity):
    
    #the set of all relation IDs
    relation_id_set = set()
    
    #the set of all initial relations
    ini_r_id_set = set()
    
    for i in range(len(id2relation)):
        
        if i not in id2relation:
            raise ValueError('error when generaing id2relation')
        
        relation_id_set.add(i)
        
        if i % 2 == 0: #initial relation id is always an even number
            ini_r_id_set.add(i)
    
    num_r = len(id2relation)
    num_ini_r = len(ini_r_id_set)
    
    if num_ini_r != int(num_r/2):
        raise ValueError('error when generating id2relation')
        
    #if an entity has at least three out-stretching paths, it is a qualified one
    qualified = set()
    for e in Dict:
        if len(Dict[e]) >= 3:
            qualified.add(e)
    qualified = list(qualified)
    
    data = list(data)
    
    for iteration in range(5):
    
        data = shuffle(data)

        for i_0 in range(len(data)):

            triple = data[i_0]

            s, r, t = triple[0], triple[1], triple[2] #obtain entities and relation IDs

            if s in qualified and t in qualified:

                #obtain the path list for true entities
                path_s, path_t = list(Dict[s]), list(Dict[t])

                #randomly choose two negative sampled entities
                s_ran = random.choice(qualified)
                t_ran = random.choice(qualified)

                #obtain the path list for random entities
                path_s_ran, path_t_ran = list(Dict[s_ran]), list(Dict[t_ran])

                #####positive step###########
                #randomly obtain three paths
                temp_s = random.sample(path_s, 3)
                temp_t = random.sample(path_t, 3)
                s_p_1, s_p_2, s_p_3 = temp_s[0], temp_s[1], temp_s[2]
                t_p_1, t_p_2, t_p_3 = temp_t[0], temp_t[1], temp_t[2]

                #append the paths: note that we add the space holder id at the end of the shorter path
                x_s_list['1'].append(list(s_p_1) + [num_r]*abs(len(s_p_1)-upper_bd))
                x_s_list['2'].append(list(s_p_2) + [num_r]*abs(len(s_p_2)-upper_bd))
                x_s_list['3'].append(list(s_p_3) + [num_r]*abs(len(s_p_3)-upper_bd))

                x_t_list['1'].append(list(t_p_1) + [num_r]*abs(len(t_p_1)-upper_bd))
                x_t_list['2'].append(list(t_p_2) + [num_r]*abs(len(t_p_2)-upper_bd))
                x_t_list['3'].append(list(t_p_3) + [num_r]*abs(len(t_p_3)-upper_bd))

                #append relation
                x_r_list.append([r])
                y_list.append(1.)

                #####negative for source entity###########
                #randomly obtain three paths
                temp_s = random.sample(path_s_ran, 3)
                s_p_1, s_p_2, s_p_3 = temp_s[0], temp_s[1], temp_s[2]

                #append the paths: note that we add the space holder id at the end of the shorter path
                x_s_list['1'].append(list(s_p_1) + [num_r]*abs(len(s_p_1)-upper_bd))
                x_s_list['2'].append(list(s_p_2) + [num_r]*abs(len(s_p_2)-upper_bd))
                x_s_list['3'].append(list(s_p_3) + [num_r]*abs(len(s_p_3)-upper_bd))

                x_t_list['1'].append(list(t_p_1) + [num_r]*abs(len(t_p_1)-upper_bd))
                x_t_list['2'].append(list(t_p_2) + [num_r]*abs(len(t_p_2)-upper_bd))
                x_t_list['3'].append(list(t_p_3) + [num_r]*abs(len(t_p_3)-upper_bd))

                #append relation
                x_r_list.append([r])
                y_list.append(0.)

                #####positive step###########
                #randomly obtain three paths
                temp_s = random.sample(path_s, 3)
                temp_t = random.sample(path_t, 3)
                s_p_1, s_p_2, s_p_3 = temp_s[0], temp_s[1], temp_s[2]
                t_p_1, t_p_2, t_p_3 = temp_t[0], temp_t[1], temp_t[2]

                #append the paths: note that we add the space holder id at the end of the shorter path
                x_s_list['1'].append(list(s_p_1) + [num_r]*abs(len(s_p_1)-upper_bd))
                x_s_list['2'].append(list(s_p_2) + [num_r]*abs(len(s_p_2)-upper_bd))
                x_s_list['3'].append(list(s_p_3) + [num_r]*abs(len(s_p_3)-upper_bd))

                x_t_list['1'].append(list(t_p_1) + [num_r]*abs(len(t_p_1)-upper_bd))
                x_t_list['2'].append(list(t_p_2) + [num_r]*abs(len(t_p_2)-upper_bd))
                x_t_list['3'].append(list(t_p_3) + [num_r]*abs(len(t_p_3)-upper_bd))

                #append relation
                x_r_list.append([r])
                y_list.append(1.)

                #####negative for target entity###########
                #randomly obtain three paths
                temp_t = random.sample(path_t_ran, 3)
                t_p_1, t_p_2, t_p_3 = temp_t[0], temp_t[1], temp_t[2]

                #append the paths: note that we add the space holder id at the end of the shorter path
                x_s_list['1'].append(list(s_p_1) + [num_r]*abs(len(s_p_1)-upper_bd))
                x_s_list['2'].append(list(s_p_2) + [num_r]*abs(len(s_p_2)-upper_bd))
                x_s_list['3'].append(list(s_p_3) + [num_r]*abs(len(s_p_3)-upper_bd))

                x_t_list['1'].append(list(t_p_1) + [num_r]*abs(len(t_p_1)-upper_bd))
                x_t_list['2'].append(list(t_p_2) + [num_r]*abs(len(t_p_2)-upper_bd))
                x_t_list['3'].append(list(t_p_3) + [num_r]*abs(len(t_p_3)-upper_bd))

                #append relation
                x_r_list.append([r])
                y_list.append(0.)

            if i_0 % 2000 == 0:
                print('generating big-batches for subgraph-based model', i_0, len(data), iteration)

# %% [markdown]
# ### Start Training: load the KG and call classes
#
# Here, we use the validation set to see the training efficiency. That is, we use the validation to check whether the true relation between entities can be predicted by paths.
#
# The trick is: in validation, we have to use the same relation ID and entity ID as in the training. But we don't want to use the links in training anymore. That is, in validation, we want to use (and update if necessary) entity2id, id2entity, relation2id and id2relation. But we want to use new one_hop, data, data_ and s_t_r for validation set. Then, path-finding will also be based on new one_hop.

# %%
model_name
# Out:
# 'Model_main_transductive_FB15K237'

# %%
one_hop_model_name
# Out:
# 'One_hop_model_main_transductive_FB15K237'

# %%
ids_name
# Out:
# 'IDs_main_transductive_FB15K237'

# %%
#first, we save the relation and ids
Dict = dict()

#save training data
Dict['one_hop'] = one_hop
Dict['data'] = data
Dict['s_t_r'] = s_t_r

#save valid data
Dict['one_hop_valid'] = one_hop_valid
Dict['data_valid'] = data_valid
Dict['s_t_r_valid'] = s_t_r_valid

#save shared dictionaries
Dict['entity2id'] = entity2id
Dict['id2entity'] = id2entity
Dict['relation2id'] = relation2id
Dict['id2relation'] = id2relation

with open('../weight_bin/' + ids_name + '.pickle', 'wb') as handle:
    pickle.dump(Dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
###train the path-based model
lower_bd = 1
upper_bd = 10
num_epoch = 10
batch_size = 32

        
#define the training lists
train_p_list, train_r_list, train_y_list = {'1': [], '2': [], '3': []}, list(), list()

#define the validation lists
valid_p_list, valid_r_list, valid_y_list = {'1': [], '2': [], '3': []}, list(), list()

#######################################
###build the big-batches###############      

#fill in the training array list
build_big_batches_path(lower_bd, upper_bd, data, one_hop, s_t_r,
                      train_p_list, train_r_list, train_y_list,
                      relation2id, entity2id, id2relation, id2entity)

#fill in the validation array list
build_big_batches_path(lower_bd, upper_bd, data_valid, one_hop_valid, s_t_r_valid,
                      valid_p_list, valid_r_list, valid_y_list,
                      relation2id, entity2id, id2relation, id2entity)    

#######################################
###do the training#####################
#sometimes the validation dataset is so small so sparse, 
#which cannot find three paths between any pair of s and t.
#in such a case, we will divide the training big-batch into train and valid
if len(valid_y_list) >= 100:
    #generate the input arrays
    x_train_1 = np.asarray(train_p_list['1'], dtype='int')
    x_train_2 = np.asarray(train_p_list['2'], dtype='int')
    x_train_3 = np.asarray(train_p_list['3'], dtype='int')
    x_train_r = np.asarray(train_r_list, dtype='int')
    y_train = np.asarray(train_y_list, dtype='int')

    #generate the validation arrays
    x_valid_1 = np.asarray(valid_p_list['1'], dtype='int')
    x_valid_2 = np.asarray(valid_p_list['2'], dtype='int')
    x_valid_3 = np.asarray(valid_p_list['3'], dtype='int')
    x_valid_r = np.asarray(valid_r_list, dtype='int')
    y_valid = np.asarray(valid_y_list, dtype='int')

else:
    split = int(len(train_y_list)*0.8)
    #generate the input arrays
    x_train_1 = np.asarray(train_p_list['1'][:split], dtype='int')
    x_train_2 = np.asarray(train_p_list['2'][:split], dtype='int')
    x_train_3 = np.asarray(train_p_list['3'][:split], dtype='int')
    x_train_r = np.asarray(train_r_list[:split], dtype='int')
    y_train = np.asarray(train_y_list[:split], dtype='int')

    #generate the validation arrays
    x_valid_1 = np.asarray(train_p_list['1'][split:], dtype='int')
    x_valid_2 = np.asarray(train_p_list['2'][split:], dtype='int')
    x_valid_3 = np.asarray(train_p_list['3'][split:], dtype='int')
    x_valid_r = np.asarray(train_r_list[split:], dtype='int')
    y_valid = np.asarray(train_y_list[split:], dtype='int')
    
#do the training
model.fit([x_train_1, x_train_2, x_train_3, x_train_r], y_train, 
          validation_data=([x_valid_1, x_valid_2, x_valid_3, x_valid_r], y_valid),
          batch_size=batch_size, epochs=num_epoch)

# Save model and weights
add_h5 = model_name + '.h5'
save_dir = os.path.join(os.getcwd(), '../weight_bin')

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, add_h5)
model.save(model_path)
print('Save model')
del(model)
# Out:
# generating big-batches for path-based model 100 14505
# generating big-batches for path-based model 200 14505
# generating big-batches for path-based model 300 14505
# generating big-batches for path-based model 400 14505
# generating big-batches for path-based model 500 14505
# generating big-batches for path-based model 600 14505
# generating big-batches for path-based model 700 14505
# generating big-batches for path-based model 800 14505
# generating big-batches for path-based model 900 14505
# generating big-batches for path-based model 1000 14505
# generating big-batches for path-based model 1100 14505
# generating big-batches for path-based model 1200 14505
# generating big-batches for path-based model 1300 14505
# generating big-batches for path-based model 1400 14505
# generating big-batches for path-based model 1500 14505
# generating big-batches for path-based model 1600 14505
# generating big-batches for path-based model 1700 14505
# generating big-batches for path-based model 1800 14505
# generating big-batches for path-based model 1900 14505
# generating big-batches for path-based model 2000 14505
# generating big-batches for path-based model 2100 14505
# generating big-batches for path-based model 2200 14505
# generating big-batches for path-based model 2300 14505
# generating big-batches for path-based model 2400 14505
# generating big-batches for path-based model 2500 14505
# generating big-batches for path-based model 2600 14505
# generating big-batches for path-based model 2700 14505
# generating big-batches for path-based model 2800 14505
# generating big-batches for path-based model 2900 14505
# generating big-batches for path-based model 3000 14505
# generating big-batches for path-based model 3100 14505
# generating big-batches for path-based model 3200 14505
# generating big-batches for path-based model 3300 14505
# generating big-batches for path-based model 3400 14505
# generating big-batches for path-based model 3500 14505
# generating big-batches for path-based model 3600 14505
# generating big-batches for path-based model 3700 14505
# generating big-batches for path-based model 3800 14505
# generating big-batches for path-based model 3900 14505
# generating big-batches for path-based model 4000 14505
# generating big-batches for path-based model 4100 14505
# generating big-batches for path-based model 4200 14505
# generating big-batches for path-based model 4300 14505
# generating big-batches for path-based model 4400 14505
# generating big-batches for path-based model 4500 14505
# generating big-batches for path-based model 4600 14505
# generating big-batches for path-based model 4700 14505
# generating big-batches for path-based model 4800 14505
# generating big-batches for path-based model 4900 14505
# generating big-batches for path-based model 5000 14505
# generating big-batches for path-based model 5100 14505
# generating big-batches for path-based model 5200 14505
# generating big-batches for path-based model 5300 14505
# generating big-batches for path-based model 5400 14505
# generating big-batches for path-based model 5500 14505
# generating big-batches for path-based model 5600 14505
# generating big-batches for path-based model 5700 14505
# generating big-batches for path-based model 5800 14505
# generating big-batches for path-based model 5900 14505
# generating big-batches for path-based model 6000 14505
# generating big-batches for path-based model 6100 14505
# generating big-batches for path-based model 6200 14505
# generating big-batches for path-based model 6300 14505
# generating big-batches for path-based model 6400 14505
# generating big-batches for path-based model 6500 14505
# generating big-batches for path-based model 6600 14505
# generating big-batches for path-based model 6700 14505
# generating big-batches for path-based model 6800 14505
# generating big-batches for path-based model 6900 14505
# generating big-batches for path-based model 7000 14505
# generating big-batches for path-based model 7100 14505
# generating big-batches for path-based model 7200 14505
# generating big-batches for path-based model 7300 14505
# generating big-batches for path-based model 7400 14505
# generating big-batches for path-based model 7500 14505
# generating big-batches for path-based model 7600 14505
# generating big-batches for path-based model 7700 14505
# generating big-batches for path-based model 7800 14505
# generating big-batches for path-based model 7900 14505
# generating big-batches for path-based model 8000 14505
# generating big-batches for path-based model 8100 14505
# generating big-batches for path-based model 8200 14505
# generating big-batches for path-based model 8300 14505
# generating big-batches for path-based model 8400 14505
# generating big-batches for path-based model 8500 14505
# generating big-batches for path-based model 8600 14505
# generating big-batches for path-based model 8700 14505
# generating big-batches for path-based model 8800 14505
# generating big-batches for path-based model 8900 14505
# generating big-batches for path-based model 9000 14505
# generating big-batches for path-based model 9100 14505
# generating big-batches for path-based model 9200 14505
# generating big-batches for path-based model 9300 14505
# generating big-batches for path-based model 9400 14505
# generating big-batches for path-based model 9500 14505
# generating big-batches for path-based model 9600 14505
# generating big-batches for path-based model 9700 14505
# generating big-batches for path-based model 9800 14505
# generating big-batches for path-based model 9900 14505
# generating big-batches for path-based model 10000 14505
# generating big-batches for path-based model 10100 14505
# generating big-batches for path-based model 10200 14505
# generating big-batches for path-based model 10300 14505
# generating big-batches for path-based model 10400 14505
# generating big-batches for path-based model 10500 14505
# generating big-batches for path-based model 10600 14505
# generating big-batches for path-based model 10700 14505
# generating big-batches for path-based model 10800 14505
# generating big-batches for path-based model 10900 14505
# generating big-batches for path-based model 11000 14505
# generating big-batches for path-based model 11100 14505
# generating big-batches for path-based model 11200 14505
# generating big-batches for path-based model 11300 14505
# generating big-batches for path-based model 11400 14505
# generating big-batches for path-based model 11500 14505
# generating big-batches for path-based model 11600 14505
# generating big-batches for path-based model 11700 14505
# generating big-batches for path-based model 11800 14505
# generating big-batches for path-based model 11900 14505
# generating big-batches for path-based model 12000 14505
# generating big-batches for path-based model 12100 14505
# generating big-batches for path-based model 12200 14505
# generating big-batches for path-based model 12300 14505
# generating big-batches for path-based model 12400 14505
# generating big-batches for path-based model 12500 14505
# generating big-batches for path-based model 12600 14505
# generating big-batches for path-based model 12700 14505
# generating big-batches for path-based model 12800 14505
# generating big-batches for path-based model 12900 14505
# generating big-batches for path-based model 13000 14505
# generating big-batches for path-based model 13100 14505
# generating big-batches for path-based model 13200 14505
# generating big-batches for path-based model 13300 14505
# generating big-batches for path-based model 13400 14505
# generating big-batches for path-based model 13500 14505
# generating big-batches for path-based model 13600 14505
# generating big-batches for path-based model 13700 14505
# generating big-batches for path-based model 13800 14505
# generating big-batches for path-based model 13900 14505
# generating big-batches for path-based model 14000 14505
# generating big-batches for path-based model 14100 14505
# generating big-batches for path-based model 14200 14505
# generating big-batches for path-based model 14300 14505
# generating big-batches for path-based model 14400 14505
# generating big-batches for path-based model 14500 14505
# generating big-batches for path-based model 100 9809
# generating big-batches for path-based model 200 9809
# generating big-batches for path-based model 300 9809
# generating big-batches for path-based model 400 9809
# generating big-batches for path-based model 500 9809
# generating big-batches for path-based model 600 9809
# generating big-batches for path-based model 700 9809
# generating big-batches for path-based model 800 9809
# generating big-batches for path-based model 900 9809
# generating big-batches for path-based model 1000 9809
# generating big-batches for path-based model 1100 9809
# generating big-batches for path-based model 1200 9809
# generating big-batches for path-based model 1300 9809
# generating big-batches for path-based model 1400 9809
# generating big-batches for path-based model 1500 9809
# generating big-batches for path-based model 1600 9809
# generating big-batches for path-based model 1700 9809
# generating big-batches for path-based model 1800 9809
# generating big-batches for path-based model 1900 9809
# generating big-batches for path-based model 2000 9809
# generating big-batches for path-based model 2100 9809
# generating big-batches for path-based model 2200 9809
# generating big-batches for path-based model 2300 9809
# generating big-batches for path-based model 2400 9809
# generating big-batches for path-based model 2500 9809
# generating big-batches for path-based model 2600 9809
# generating big-batches for path-based model 2700 9809
# generating big-batches for path-based model 2800 9809
# generating big-batches for path-based model 2900 9809
# generating big-batches for path-based model 3000 9809
# generating big-batches for path-based model 3100 9809
# generating big-batches for path-based model 3200 9809
# generating big-batches for path-based model 3300 9809
# generating big-batches for path-based model 3400 9809
# generating big-batches for path-based model 3500 9809
# generating big-batches for path-based model 3600 9809
# generating big-batches for path-based model 3700 9809
# generating big-batches for path-based model 3800 9809
# generating big-batches for path-based model 3900 9809
# generating big-batches for path-based model 4000 9809
# generating big-batches for path-based model 4100 9809
# generating big-batches for path-based model 4200 9809
# generating big-batches for path-based model 4300 9809
# generating big-batches for path-based model 4400 9809
# generating big-batches for path-based model 4500 9809
# generating big-batches for path-based model 4600 9809
# generating big-batches for path-based model 4700 9809
# generating big-batches for path-based model 4800 9809
# generating big-batches for path-based model 4900 9809
# generating big-batches for path-based model 5000 9809
# generating big-batches for path-based model 5100 9809
# generating big-batches for path-based model 5200 9809
# generating big-batches for path-based model 5300 9809
# generating big-batches for path-based model 5400 9809
# generating big-batches for path-based model 5500 9809
# generating big-batches for path-based model 5600 9809
# generating big-batches for path-based model 5700 9809
# generating big-batches for path-based model 5800 9809
# generating big-batches for path-based model 5900 9809
# generating big-batches for path-based model 6000 9809
# generating big-batches for path-based model 6100 9809
# generating big-batches for path-based model 6200 9809
# generating big-batches for path-based model 6300 9809
# generating big-batches for path-based model 6400 9809
# generating big-batches for path-based model 6500 9809
# generating big-batches for path-based model 6600 9809
# generating big-batches for path-based model 6700 9809
# generating big-batches for path-based model 6800 9809
# generating big-batches for path-based model 6900 9809
# generating big-batches for path-based model 7000 9809
# generating big-batches for path-based model 7100 9809
# generating big-batches for path-based model 7200 9809
# generating big-batches for path-based model 7300 9809
# generating big-batches for path-based model 7400 9809
# generating big-batches for path-based model 7500 9809
# generating big-batches for path-based model 7600 9809
# generating big-batches for path-based model 7700 9809
# generating big-batches for path-based model 7800 9809
# generating big-batches for path-based model 7900 9809
# generating big-batches for path-based model 8000 9809
# generating big-batches for path-based model 8100 9809
# generating big-batches for path-based model 8200 9809
# generating big-batches for path-based model 8300 9809
# generating big-batches for path-based model 8400 9809
# generating big-batches for path-based model 8500 9809
# generating big-batches for path-based model 8600 9809
# generating big-batches for path-based model 8700 9809
# generating big-batches for path-based model 8800 9809
# generating big-batches for path-based model 8900 9809
# generating big-batches for path-based model 9000 9809
# generating big-batches for path-based model 9100 9809
# generating big-batches for path-based model 9200 9809
# generating big-batches for path-based model 9300 9809
# generating big-batches for path-based model 9400 9809
# generating big-batches for path-based model 9500 9809
# generating big-batches for path-based model 9600 9809
# generating big-batches for path-based model 9700 9809
# generating big-batches for path-based model 9800 9809
# Epoch 1/10
# 126595/126595 [==============================] - 5252s 41ms/step - loss: 0.3156 - binary_accuracy: 0.8991 - val_loss: 0.2322 - val_binary_accuracy: 0.9151
# Epoch 2/10
# 126595/126595 [==============================] - 8099s 64ms/step - loss: 0.1802 - binary_accuracy: 0.9266 - val_loss: 0.2260 - val_binary_accuracy: 0.9152
# Epoch 3/10
# 126595/126595 [==============================] - 5216s 41ms/step - loss: 0.1754 - binary_accuracy: 0.9286 - val_loss: 0.2299 - val_binary_accuracy: 0.9159
# Epoch 4/10
# 126595/126595 [==============================] - 7882s 62ms/step - loss: 0.1724 - binary_accuracy: 0.9299 - val_loss: 0.2393 - val_binary_accuracy: 0.9141
# Epoch 5/10
# 126595/126595 [==============================] - 5481s 43ms/step - loss: 0.1702 - binary_accuracy: 0.9310 - val_loss: 0.2218 - val_binary_accuracy: 0.9165
# Epoch 6/10
# 126595/126595 [==============================] - 5404s 43ms/step - loss: 0.1681 - binary_accuracy: 0.9319 - val_loss: 0.2132 - val_binary_accuracy: 0.9157
# Epoch 7/10
# 126595/126595 [==============================] - 5412s 43ms/step - loss: 0.1666 - binary_accuracy: 0.9327 - val_loss: 0.2222 - val_binary_accuracy: 0.9159
# Epoch 8/10
# 126595/126595 [==============================] - 5376s 42ms/step - loss: 0.1650 - binary_accuracy: 0.9335 - val_loss: 0.2347 - val_binary_accuracy: 0.9139
# Epoch 9/10
# 126595/126595 [==============================] - 5378s 42ms/step - loss: 0.1634 - binary_accuracy: 0.9343 - val_loss: 0.2424 - val_binary_accuracy: 0.9153
# Epoch 10/10
# 126595/126595 [==============================] - 5379s 42ms/step - loss: 0.1620 - binary_accuracy: 0.9349 - val_loss: 0.2493 - val_binary_accuracy: 0.9133
# Save model

# %%
###train the subgraph-based model
lower_bd = 1
upper_bd = 3
num_epoch = 10
batch_size = 32

Dict_train = store_subgraph_dicts(lower_bd, upper_bd, data, one_hop, s_t_r,
                         relation2id, entity2id, id2relation, id2entity)

Dict_valid = store_subgraph_dicts(lower_bd, upper_bd, data_valid, one_hop_valid, s_t_r_valid,
                         relation2id, entity2id, id2relation, id2entity)

        
#define the training lists
train_s_list, train_t_list, train_r_list, train_y_list = {'1': [], '2': [], '3': []}, {'1': [], '2': [], '3': []}, list(), list()

#define the validation lists
valid_s_list, valid_t_list, valid_r_list, valid_y_list = {'1': [], '2': [], '3': []}, {'1': [], '2': [], '3': []}, list(), list()

#######################################
###build the big-batches###############      

#fill in the training array list
build_big_batches_subgraph(lower_bd, upper_bd, data, one_hop, s_t_r,
                      train_s_list, train_t_list, train_r_list, train_y_list, Dict_train,
                      relation2id, entity2id, id2relation, id2entity)

#fill in the validation array list
build_big_batches_subgraph(lower_bd, upper_bd, data_valid, one_hop_valid, s_t_r_valid,
                      valid_s_list, valid_t_list, valid_r_list, valid_y_list, Dict_valid,
                      relation2id, entity2id, id2relation, id2entity)    

#######################################
###do the training#####################
#sometimes the validation dataset is so small so sparse, 
#which cannot find three paths between any pair of s and t.
#in such a case, we will divide the training big-batch into train and valid
if len(valid_y_list) >= 100:
    #generate the input arrays
    x_train_s_1 = np.asarray(train_s_list['1'], dtype='int')
    x_train_s_2 = np.asarray(train_s_list['2'], dtype='int')
    x_train_s_3 = np.asarray(train_s_list['3'], dtype='int')

    x_train_t_1 = np.asarray(train_t_list['1'], dtype='int')
    x_train_t_2 = np.asarray(train_t_list['2'], dtype='int')
    x_train_t_3 = np.asarray(train_t_list['3'], dtype='int')

    x_train_r = np.asarray(train_r_list, dtype='int')
    y_train = np.asarray(train_y_list, dtype='int')

    #generate the validation arrays
    x_valid_s_1 = np.asarray(valid_s_list['1'], dtype='int')
    x_valid_s_2 = np.asarray(valid_s_list['2'], dtype='int')
    x_valid_s_3 = np.asarray(valid_s_list['3'], dtype='int')

    x_valid_t_1 = np.asarray(valid_t_list['1'], dtype='int')
    x_valid_t_2 = np.asarray(valid_t_list['2'], dtype='int')
    x_valid_t_3 = np.asarray(valid_t_list['3'], dtype='int')

    x_valid_r = np.asarray(valid_r_list, dtype='int')
    y_valid = np.asarray(valid_y_list, dtype='int')

else:
    split = int(len(train_y_list)*0.8)
    #generate the input arrays
    x_train_s_1 = np.asarray(train_s_list['1'][:split], dtype='int')
    x_train_s_2 = np.asarray(train_s_list['2'][:split], dtype='int')
    x_train_s_3 = np.asarray(train_s_list['3'][:split], dtype='int')

    x_train_t_1 = np.asarray(train_t_list['1'][:split], dtype='int')
    x_train_t_2 = np.asarray(train_t_list['2'][:split], dtype='int')
    x_train_t_3 = np.asarray(train_t_list['3'][:split], dtype='int')

    x_train_r = np.asarray(train_r_list[:split], dtype='int')
    y_train = np.asarray(train_y_list[:split], dtype='int')

    #generate the validation arrays
    x_valid_s_1 = np.asarray(train_s_list['1'][split:], dtype='int')
    x_valid_s_2 = np.asarray(train_s_list['2'][split:], dtype='int')
    x_valid_s_3 = np.asarray(train_s_list['3'][split:], dtype='int')

    x_valid_t_1 = np.asarray(train_t_list['1'][split:], dtype='int')
    x_valid_t_2 = np.asarray(train_t_list['2'][split:], dtype='int')
    x_valid_t_3 = np.asarray(train_t_list['3'][split:], dtype='int')

    x_valid_r = np.asarray(train_r_list[split:], dtype='int')
    y_valid = np.asarray(train_y_list[split:], dtype='int')

#do the training
model_2.fit([x_train_s_1, x_train_s_2, x_train_s_3, x_train_t_1, x_train_t_2, x_train_t_3, x_train_r], y_train, 
          validation_data=([x_valid_s_1, x_valid_s_2, x_valid_s_3, x_valid_t_1, x_valid_t_2, x_valid_t_3, x_valid_r], y_valid),
          batch_size=batch_size, epochs=num_epoch)

# Save model and weights
one_hop_add_h5 = one_hop_model_name + '.h5'
one_hop_save_dir = os.path.join(os.getcwd(), '../weight_bin')

if not os.path.isdir(one_hop_save_dir):
    os.makedirs(one_hop_save_dir)
one_hop_model_path = os.path.join(one_hop_save_dir, one_hop_add_h5)
model_2.save(one_hop_model_path)
print('Save model')
del(model_2, Dict_train, Dict_valid)
# Out:
# generating and storing paths for the path-based model 100 14505
# generating and storing paths for the path-based model 200 14505
# generating and storing paths for the path-based model 300 14505
# generating and storing paths for the path-based model 400 14505
# generating and storing paths for the path-based model 500 14505
# generating and storing paths for the path-based model 600 14505
# generating and storing paths for the path-based model 700 14505
# generating and storing paths for the path-based model 800 14505
# generating and storing paths for the path-based model 900 14505
# generating and storing paths for the path-based model 1000 14505
# generating and storing paths for the path-based model 1100 14505
# generating and storing paths for the path-based model 1200 14505
# generating and storing paths for the path-based model 1300 14505
# generating and storing paths for the path-based model 1400 14505
# generating and storing paths for the path-based model 1500 14505
# generating and storing paths for the path-based model 1600 14505
# generating and storing paths for the path-based model 1700 14505
# generating and storing paths for the path-based model 1800 14505
# generating and storing paths for the path-based model 1900 14505
# generating and storing paths for the path-based model 2000 14505
# generating and storing paths for the path-based model 2100 14505
# generating and storing paths for the path-based model 2200 14505
# generating and storing paths for the path-based model 2300 14505
# generating and storing paths for the path-based model 2400 14505
# generating and storing paths for the path-based model 2500 14505
# generating and storing paths for the path-based model 2600 14505
# generating and storing paths for the path-based model 2700 14505
# generating and storing paths for the path-based model 2800 14505
# generating and storing paths for the path-based model 2900 14505
# generating and storing paths for the path-based model 3000 14505
# generating and storing paths for the path-based model 3100 14505
# generating and storing paths for the path-based model 3200 14505
# generating and storing paths for the path-based model 3300 14505
# generating and storing paths for the path-based model 3400 14505
# generating and storing paths for the path-based model 3500 14505
# generating and storing paths for the path-based model 3600 14505
# generating and storing paths for the path-based model 3700 14505
# generating and storing paths for the path-based model 3800 14505
# generating and storing paths for the path-based model 3900 14505
# generating and storing paths for the path-based model 4000 14505
# generating and storing paths for the path-based model 4100 14505
# generating and storing paths for the path-based model 4200 14505
# generating and storing paths for the path-based model 4300 14505
# generating and storing paths for the path-based model 4400 14505
# generating and storing paths for the path-based model 4500 14505
# generating and storing paths for the path-based model 4600 14505
# generating and storing paths for the path-based model 4700 14505
# generating and storing paths for the path-based model 4800 14505
# generating and storing paths for the path-based model 4900 14505
# generating and storing paths for the path-based model 5000 14505
# generating and storing paths for the path-based model 5100 14505
# generating and storing paths for the path-based model 5200 14505
# generating and storing paths for the path-based model 5300 14505
# generating and storing paths for the path-based model 5400 14505
# generating and storing paths for the path-based model 5500 14505
# generating and storing paths for the path-based model 5600 14505
# generating and storing paths for the path-based model 5700 14505
# generating and storing paths for the path-based model 5800 14505
# generating and storing paths for the path-based model 5900 14505
# generating and storing paths for the path-based model 6000 14505
# generating and storing paths for the path-based model 6100 14505
# generating and storing paths for the path-based model 6200 14505
# generating and storing paths for the path-based model 6300 14505
# generating and storing paths for the path-based model 6400 14505
# generating and storing paths for the path-based model 6500 14505
# generating and storing paths for the path-based model 6600 14505
# generating and storing paths for the path-based model 6700 14505
# generating and storing paths for the path-based model 6800 14505
# generating and storing paths for the path-based model 6900 14505
# generating and storing paths for the path-based model 7000 14505
# generating and storing paths for the path-based model 7100 14505
# generating and storing paths for the path-based model 7200 14505
# generating and storing paths for the path-based model 7300 14505
# generating and storing paths for the path-based model 7400 14505
# generating and storing paths for the path-based model 7500 14505
# generating and storing paths for the path-based model 7600 14505
# generating and storing paths for the path-based model 7700 14505
# generating and storing paths for the path-based model 7800 14505
# generating and storing paths for the path-based model 7900 14505
# generating and storing paths for the path-based model 8000 14505
# generating and storing paths for the path-based model 8100 14505
# generating and storing paths for the path-based model 8200 14505
# generating and storing paths for the path-based model 8300 14505
# generating and storing paths for the path-based model 8400 14505
# generating and storing paths for the path-based model 8500 14505
# generating and storing paths for the path-based model 8600 14505
# generating and storing paths for the path-based model 8700 14505
# generating and storing paths for the path-based model 8800 14505
# generating and storing paths for the path-based model 8900 14505
# generating and storing paths for the path-based model 9000 14505
# generating and storing paths for the path-based model 9100 14505
# generating and storing paths for the path-based model 9200 14505
# generating and storing paths for the path-based model 9300 14505
# generating and storing paths for the path-based model 9400 14505
# generating and storing paths for the path-based model 9500 14505
# generating and storing paths for the path-based model 9600 14505
# generating and storing paths for the path-based model 9700 14505
# generating and storing paths for the path-based model 9800 14505
# generating and storing paths for the path-based model 9900 14505
# generating and storing paths for the path-based model 10000 14505
# generating and storing paths for the path-based model 10100 14505
# generating and storing paths for the path-based model 10200 14505
# generating and storing paths for the path-based model 10300 14505
# generating and storing paths for the path-based model 10400 14505
# generating and storing paths for the path-based model 10500 14505
# generating and storing paths for the path-based model 10600 14505
# generating and storing paths for the path-based model 10700 14505
# generating and storing paths for the path-based model 10800 14505
# generating and storing paths for the path-based model 10900 14505
# generating and storing paths for the path-based model 11000 14505
# generating and storing paths for the path-based model 11100 14505
# generating and storing paths for the path-based model 11200 14505
# generating and storing paths for the path-based model 11300 14505
# generating and storing paths for the path-based model 11400 14505
# generating and storing paths for the path-based model 11500 14505
# generating and storing paths for the path-based model 11600 14505
# generating and storing paths for the path-based model 11700 14505
# generating and storing paths for the path-based model 11800 14505
# generating and storing paths for the path-based model 11900 14505
# generating and storing paths for the path-based model 12000 14505
# generating and storing paths for the path-based model 12100 14505
# generating and storing paths for the path-based model 12200 14505
# generating and storing paths for the path-based model 12300 14505
# generating and storing paths for the path-based model 12400 14505
# generating and storing paths for the path-based model 12500 14505
# generating and storing paths for the path-based model 12600 14505
# generating and storing paths for the path-based model 12700 14505
# generating and storing paths for the path-based model 12800 14505
# generating and storing paths for the path-based model 12900 14505
# generating and storing paths for the path-based model 13000 14505
# generating and storing paths for the path-based model 13100 14505
# generating and storing paths for the path-based model 13200 14505
# generating and storing paths for the path-based model 13300 14505
# generating and storing paths for the path-based model 13400 14505
# generating and storing paths for the path-based model 13500 14505
# generating and storing paths for the path-based model 13600 14505
# generating and storing paths for the path-based model 13700 14505
# generating and storing paths for the path-based model 13800 14505
# generating and storing paths for the path-based model 13900 14505
# generating and storing paths for the path-based model 14000 14505
# generating and storing paths for the path-based model 14100 14505
# generating and storing paths for the path-based model 14200 14505
# generating and storing paths for the path-based model 14300 14505
# generating and storing paths for the path-based model 14400 14505
# generating and storing paths for the path-based model 14500 14505
# generating and storing paths for the path-based model 100 9809
# generating and storing paths for the path-based model 200 9809
# generating and storing paths for the path-based model 300 9809
# generating and storing paths for the path-based model 400 9809
# generating and storing paths for the path-based model 500 9809
# generating and storing paths for the path-based model 600 9809
# generating and storing paths for the path-based model 700 9809
# generating and storing paths for the path-based model 800 9809
# generating and storing paths for the path-based model 900 9809
# generating and storing paths for the path-based model 1000 9809
# generating and storing paths for the path-based model 1100 9809
# generating and storing paths for the path-based model 1200 9809
# generating and storing paths for the path-based model 1300 9809
# generating and storing paths for the path-based model 1400 9809
# generating and storing paths for the path-based model 1500 9809
# generating and storing paths for the path-based model 1600 9809
# generating and storing paths for the path-based model 1700 9809
# generating and storing paths for the path-based model 1800 9809
# generating and storing paths for the path-based model 1900 9809
# generating and storing paths for the path-based model 2000 9809
# generating and storing paths for the path-based model 2100 9809
# generating and storing paths for the path-based model 2200 9809
# generating and storing paths for the path-based model 2300 9809
# generating and storing paths for the path-based model 2400 9809
# generating and storing paths for the path-based model 2500 9809
# generating and storing paths for the path-based model 2600 9809
# generating and storing paths for the path-based model 2700 9809
# generating and storing paths for the path-based model 2800 9809
# generating and storing paths for the path-based model 2900 9809
# generating and storing paths for the path-based model 3000 9809
# generating and storing paths for the path-based model 3100 9809
# generating and storing paths for the path-based model 3200 9809
# generating and storing paths for the path-based model 3300 9809
# generating and storing paths for the path-based model 3400 9809
# generating and storing paths for the path-based model 3500 9809
# generating and storing paths for the path-based model 3600 9809
# generating and storing paths for the path-based model 3700 9809
# generating and storing paths for the path-based model 3800 9809
# generating and storing paths for the path-based model 3900 9809
# generating and storing paths for the path-based model 4000 9809
# generating and storing paths for the path-based model 4100 9809
# generating and storing paths for the path-based model 4200 9809
# generating and storing paths for the path-based model 4300 9809
# generating and storing paths for the path-based model 4400 9809
# generating and storing paths for the path-based model 4500 9809
# generating and storing paths for the path-based model 4600 9809
# generating and storing paths for the path-based model 4700 9809
# generating and storing paths for the path-based model 4800 9809
# generating and storing paths for the path-based model 4900 9809
# generating and storing paths for the path-based model 5000 9809
# generating and storing paths for the path-based model 5100 9809
# generating and storing paths for the path-based model 5200 9809
# generating and storing paths for the path-based model 5300 9809
# generating and storing paths for the path-based model 5400 9809
# generating and storing paths for the path-based model 5500 9809
# generating and storing paths for the path-based model 5600 9809
# generating and storing paths for the path-based model 5700 9809
# generating and storing paths for the path-based model 5800 9809
# generating and storing paths for the path-based model 5900 9809
# generating and storing paths for the path-based model 6000 9809
# generating and storing paths for the path-based model 6100 9809
# generating and storing paths for the path-based model 6200 9809
# generating and storing paths for the path-based model 6300 9809
# generating and storing paths for the path-based model 6400 9809
# generating and storing paths for the path-based model 6500 9809
# generating and storing paths for the path-based model 6600 9809
# generating and storing paths for the path-based model 6700 9809
# generating and storing paths for the path-based model 6800 9809
# generating and storing paths for the path-based model 6900 9809
# generating and storing paths for the path-based model 7000 9809
# generating and storing paths for the path-based model 7100 9809
# generating and storing paths for the path-based model 7200 9809
# generating and storing paths for the path-based model 7300 9809
# generating and storing paths for the path-based model 7400 9809
# generating and storing paths for the path-based model 7500 9809
# generating and storing paths for the path-based model 7600 9809
# generating and storing paths for the path-based model 7700 9809
# generating and storing paths for the path-based model 7800 9809
# generating and storing paths for the path-based model 7900 9809
# generating and storing paths for the path-based model 8000 9809
# generating and storing paths for the path-based model 8100 9809
# generating and storing paths for the path-based model 8200 9809
# generating and storing paths for the path-based model 8300 9809
# generating and storing paths for the path-based model 8400 9809
# generating and storing paths for the path-based model 8500 9809
# generating and storing paths for the path-based model 8600 9809
# generating and storing paths for the path-based model 8700 9809
# generating and storing paths for the path-based model 8800 9809
# generating and storing paths for the path-based model 8900 9809
# generating and storing paths for the path-based model 9000 9809
# generating and storing paths for the path-based model 9100 9809
# generating and storing paths for the path-based model 9200 9809
# generating and storing paths for the path-based model 9300 9809
# generating and storing paths for the path-based model 9400 9809
# generating and storing paths for the path-based model 9500 9809
# generating and storing paths for the path-based model 9600 9809
# generating and storing paths for the path-based model 9700 9809
# generating and storing paths for the path-based model 9800 9809
# generating big-batches for subgraph-based model 0 272115 0
# generating big-batches for subgraph-based model 2000 272115 0
# generating big-batches for subgraph-based model 4000 272115 0
# generating big-batches for subgraph-based model 6000 272115 0
# generating big-batches for subgraph-based model 8000 272115 0
# generating big-batches for subgraph-based model 10000 272115 0
# generating big-batches for subgraph-based model 12000 272115 0
# generating big-batches for subgraph-based model 14000 272115 0
# generating big-batches for subgraph-based model 16000 272115 0
# generating big-batches for subgraph-based model 18000 272115 0
# generating big-batches for subgraph-based model 20000 272115 0
# generating big-batches for subgraph-based model 22000 272115 0
# generating big-batches for subgraph-based model 24000 272115 0
# generating big-batches for subgraph-based model 26000 272115 0
# generating big-batches for subgraph-based model 28000 272115 0
# generating big-batches for subgraph-based model 30000 272115 0
# generating big-batches for subgraph-based model 32000 272115 0
# generating big-batches for subgraph-based model 34000 272115 0
# generating big-batches for subgraph-based model 36000 272115 0
# generating big-batches for subgraph-based model 38000 272115 0
# generating big-batches for subgraph-based model 40000 272115 0
# generating big-batches for subgraph-based model 42000 272115 0
# generating big-batches for subgraph-based model 44000 272115 0
# generating big-batches for subgraph-based model 46000 272115 0
# generating big-batches for subgraph-based model 48000 272115 0
# generating big-batches for subgraph-based model 50000 272115 0
# generating big-batches for subgraph-based model 52000 272115 0
# generating big-batches for subgraph-based model 54000 272115 0
# generating big-batches for subgraph-based model 56000 272115 0
# generating big-batches for subgraph-based model 58000 272115 0
# generating big-batches for subgraph-based model 60000 272115 0
# generating big-batches for subgraph-based model 62000 272115 0
# generating big-batches for subgraph-based model 64000 272115 0
# generating big-batches for subgraph-based model 66000 272115 0
# generating big-batches for subgraph-based model 68000 272115 0
# generating big-batches for subgraph-based model 70000 272115 0
# generating big-batches for subgraph-based model 72000 272115 0
# generating big-batches for subgraph-based model 74000 272115 0
# generating big-batches for subgraph-based model 76000 272115 0
# generating big-batches for subgraph-based model 78000 272115 0
# generating big-batches for subgraph-based model 80000 272115 0
# generating big-batches for subgraph-based model 82000 272115 0
# generating big-batches for subgraph-based model 84000 272115 0
# generating big-batches for subgraph-based model 86000 272115 0
# generating big-batches for subgraph-based model 88000 272115 0
# generating big-batches for subgraph-based model 90000 272115 0
# generating big-batches for subgraph-based model 92000 272115 0
# generating big-batches for subgraph-based model 94000 272115 0
# generating big-batches for subgraph-based model 96000 272115 0
# generating big-batches for subgraph-based model 98000 272115 0
# generating big-batches for subgraph-based model 100000 272115 0
# generating big-batches for subgraph-based model 102000 272115 0
# generating big-batches for subgraph-based model 104000 272115 0
# generating big-batches for subgraph-based model 106000 272115 0
# generating big-batches for subgraph-based model 108000 272115 0
# generating big-batches for subgraph-based model 110000 272115 0
# generating big-batches for subgraph-based model 112000 272115 0
# generating big-batches for subgraph-based model 114000 272115 0
# generating big-batches for subgraph-based model 116000 272115 0
# generating big-batches for subgraph-based model 118000 272115 0
# generating big-batches for subgraph-based model 120000 272115 0
# generating big-batches for subgraph-based model 122000 272115 0
# generating big-batches for subgraph-based model 124000 272115 0
# generating big-batches for subgraph-based model 126000 272115 0
# generating big-batches for subgraph-based model 128000 272115 0
# generating big-batches for subgraph-based model 130000 272115 0
# generating big-batches for subgraph-based model 132000 272115 0
# generating big-batches for subgraph-based model 134000 272115 0
# generating big-batches for subgraph-based model 136000 272115 0
# generating big-batches for subgraph-based model 138000 272115 0
# generating big-batches for subgraph-based model 140000 272115 0
# generating big-batches for subgraph-based model 142000 272115 0
# generating big-batches for subgraph-based model 144000 272115 0
# generating big-batches for subgraph-based model 146000 272115 0
# generating big-batches for subgraph-based model 148000 272115 0
# generating big-batches for subgraph-based model 150000 272115 0
# generating big-batches for subgraph-based model 152000 272115 0
# generating big-batches for subgraph-based model 154000 272115 0
# generating big-batches for subgraph-based model 156000 272115 0
# generating big-batches for subgraph-based model 158000 272115 0
# generating big-batches for subgraph-based model 160000 272115 0
# generating big-batches for subgraph-based model 162000 272115 0
# generating big-batches for subgraph-based model 164000 272115 0
# generating big-batches for subgraph-based model 166000 272115 0
# generating big-batches for subgraph-based model 168000 272115 0
# generating big-batches for subgraph-based model 170000 272115 0
# generating big-batches for subgraph-based model 172000 272115 0
# generating big-batches for subgraph-based model 174000 272115 0
# generating big-batches for subgraph-based model 176000 272115 0
# generating big-batches for subgraph-based model 178000 272115 0
# generating big-batches for subgraph-based model 180000 272115 0
# generating big-batches for subgraph-based model 182000 272115 0
# generating big-batches for subgraph-based model 184000 272115 0
# generating big-batches for subgraph-based model 186000 272115 0
# generating big-batches for subgraph-based model 188000 272115 0
# generating big-batches for subgraph-based model 190000 272115 0
# generating big-batches for subgraph-based model 192000 272115 0
# generating big-batches for subgraph-based model 194000 272115 0
# generating big-batches for subgraph-based model 196000 272115 0
# generating big-batches for subgraph-based model 198000 272115 0
# generating big-batches for subgraph-based model 200000 272115 0
# generating big-batches for subgraph-based model 202000 272115 0
# generating big-batches for subgraph-based model 204000 272115 0
# generating big-batches for subgraph-based model 206000 272115 0
# generating big-batches for subgraph-based model 208000 272115 0
# generating big-batches for subgraph-based model 210000 272115 0
# generating big-batches for subgraph-based model 212000 272115 0
# generating big-batches for subgraph-based model 214000 272115 0
# generating big-batches for subgraph-based model 216000 272115 0
# generating big-batches for subgraph-based model 218000 272115 0
# generating big-batches for subgraph-based model 220000 272115 0
# generating big-batches for subgraph-based model 222000 272115 0
# generating big-batches for subgraph-based model 224000 272115 0
# generating big-batches for subgraph-based model 226000 272115 0
# generating big-batches for subgraph-based model 228000 272115 0
# generating big-batches for subgraph-based model 230000 272115 0
# generating big-batches for subgraph-based model 232000 272115 0
# generating big-batches for subgraph-based model 234000 272115 0
# generating big-batches for subgraph-based model 236000 272115 0
# generating big-batches for subgraph-based model 238000 272115 0
# generating big-batches for subgraph-based model 240000 272115 0
# generating big-batches for subgraph-based model 242000 272115 0
# generating big-batches for subgraph-based model 244000 272115 0
# generating big-batches for subgraph-based model 246000 272115 0
# generating big-batches for subgraph-based model 248000 272115 0
# generating big-batches for subgraph-based model 250000 272115 0
# generating big-batches for subgraph-based model 252000 272115 0
# generating big-batches for subgraph-based model 254000 272115 0
# generating big-batches for subgraph-based model 256000 272115 0
# generating big-batches for subgraph-based model 258000 272115 0
# generating big-batches for subgraph-based model 260000 272115 0
# generating big-batches for subgraph-based model 262000 272115 0
# generating big-batches for subgraph-based model 264000 272115 0
# generating big-batches for subgraph-based model 266000 272115 0
# generating big-batches for subgraph-based model 268000 272115 0
# generating big-batches for subgraph-based model 270000 272115 0
# generating big-batches for subgraph-based model 272000 272115 0
# generating big-batches for subgraph-based model 0 272115 1
# generating big-batches for subgraph-based model 2000 272115 1
# generating big-batches for subgraph-based model 4000 272115 1
# generating big-batches for subgraph-based model 6000 272115 1
# generating big-batches for subgraph-based model 8000 272115 1
# generating big-batches for subgraph-based model 10000 272115 1
# generating big-batches for subgraph-based model 12000 272115 1
# generating big-batches for subgraph-based model 14000 272115 1
# generating big-batches for subgraph-based model 16000 272115 1
# generating big-batches for subgraph-based model 18000 272115 1
# generating big-batches for subgraph-based model 20000 272115 1
# generating big-batches for subgraph-based model 22000 272115 1
# generating big-batches for subgraph-based model 24000 272115 1
# generating big-batches for subgraph-based model 26000 272115 1
# generating big-batches for subgraph-based model 28000 272115 1
# generating big-batches for subgraph-based model 30000 272115 1
# generating big-batches for subgraph-based model 32000 272115 1
# generating big-batches for subgraph-based model 34000 272115 1
# generating big-batches for subgraph-based model 36000 272115 1
# generating big-batches for subgraph-based model 38000 272115 1
# generating big-batches for subgraph-based model 40000 272115 1
# generating big-batches for subgraph-based model 42000 272115 1
# generating big-batches for subgraph-based model 44000 272115 1
# generating big-batches for subgraph-based model 46000 272115 1
# generating big-batches for subgraph-based model 48000 272115 1
# generating big-batches for subgraph-based model 50000 272115 1
# generating big-batches for subgraph-based model 52000 272115 1
# generating big-batches for subgraph-based model 54000 272115 1
# generating big-batches for subgraph-based model 56000 272115 1
# generating big-batches for subgraph-based model 58000 272115 1
# generating big-batches for subgraph-based model 60000 272115 1
# generating big-batches for subgraph-based model 62000 272115 1
# generating big-batches for subgraph-based model 64000 272115 1
# generating big-batches for subgraph-based model 66000 272115 1
# generating big-batches for subgraph-based model 68000 272115 1
# generating big-batches for subgraph-based model 70000 272115 1
# generating big-batches for subgraph-based model 72000 272115 1
# generating big-batches for subgraph-based model 74000 272115 1
# generating big-batches for subgraph-based model 76000 272115 1
# generating big-batches for subgraph-based model 78000 272115 1
# generating big-batches for subgraph-based model 80000 272115 1
# generating big-batches for subgraph-based model 82000 272115 1
# generating big-batches for subgraph-based model 84000 272115 1
# generating big-batches for subgraph-based model 86000 272115 1
# generating big-batches for subgraph-based model 88000 272115 1
# generating big-batches for subgraph-based model 90000 272115 1
# generating big-batches for subgraph-based model 92000 272115 1
# generating big-batches for subgraph-based model 94000 272115 1
# generating big-batches for subgraph-based model 96000 272115 1
# generating big-batches for subgraph-based model 98000 272115 1
# generating big-batches for subgraph-based model 100000 272115 1
# generating big-batches for subgraph-based model 102000 272115 1
# generating big-batches for subgraph-based model 104000 272115 1
# generating big-batches for subgraph-based model 106000 272115 1
# generating big-batches for subgraph-based model 108000 272115 1
# generating big-batches for subgraph-based model 110000 272115 1
# generating big-batches for subgraph-based model 112000 272115 1
# generating big-batches for subgraph-based model 114000 272115 1
# generating big-batches for subgraph-based model 116000 272115 1
# generating big-batches for subgraph-based model 118000 272115 1
# generating big-batches for subgraph-based model 120000 272115 1
# generating big-batches for subgraph-based model 122000 272115 1
# generating big-batches for subgraph-based model 124000 272115 1
# generating big-batches for subgraph-based model 126000 272115 1
# generating big-batches for subgraph-based model 128000 272115 1
# generating big-batches for subgraph-based model 130000 272115 1
# generating big-batches for subgraph-based model 132000 272115 1
# generating big-batches for subgraph-based model 134000 272115 1
# generating big-batches for subgraph-based model 136000 272115 1
# generating big-batches for subgraph-based model 138000 272115 1
# generating big-batches for subgraph-based model 140000 272115 1
# generating big-batches for subgraph-based model 142000 272115 1
# generating big-batches for subgraph-based model 144000 272115 1
# generating big-batches for subgraph-based model 146000 272115 1
# generating big-batches for subgraph-based model 148000 272115 1
# generating big-batches for subgraph-based model 150000 272115 1
# generating big-batches for subgraph-based model 152000 272115 1
# generating big-batches for subgraph-based model 154000 272115 1
# generating big-batches for subgraph-based model 156000 272115 1
# generating big-batches for subgraph-based model 158000 272115 1
# generating big-batches for subgraph-based model 160000 272115 1
# generating big-batches for subgraph-based model 162000 272115 1
# generating big-batches for subgraph-based model 164000 272115 1
# generating big-batches for subgraph-based model 166000 272115 1
# generating big-batches for subgraph-based model 168000 272115 1
# generating big-batches for subgraph-based model 170000 272115 1
# generating big-batches for subgraph-based model 172000 272115 1
# generating big-batches for subgraph-based model 174000 272115 1
# generating big-batches for subgraph-based model 176000 272115 1
# generating big-batches for subgraph-based model 178000 272115 1
# generating big-batches for subgraph-based model 180000 272115 1
# generating big-batches for subgraph-based model 182000 272115 1
# generating big-batches for subgraph-based model 184000 272115 1
# generating big-batches for subgraph-based model 186000 272115 1
# generating big-batches for subgraph-based model 188000 272115 1
# generating big-batches for subgraph-based model 190000 272115 1
# generating big-batches for subgraph-based model 192000 272115 1
# generating big-batches for subgraph-based model 194000 272115 1
# generating big-batches for subgraph-based model 196000 272115 1
# generating big-batches for subgraph-based model 198000 272115 1
# generating big-batches for subgraph-based model 200000 272115 1
# generating big-batches for subgraph-based model 202000 272115 1
# generating big-batches for subgraph-based model 204000 272115 1
# generating big-batches for subgraph-based model 206000 272115 1
# generating big-batches for subgraph-based model 208000 272115 1
# generating big-batches for subgraph-based model 210000 272115 1
# generating big-batches for subgraph-based model 212000 272115 1
# generating big-batches for subgraph-based model 214000 272115 1
# generating big-batches for subgraph-based model 216000 272115 1
# generating big-batches for subgraph-based model 218000 272115 1
# generating big-batches for subgraph-based model 220000 272115 1
# generating big-batches for subgraph-based model 222000 272115 1
# generating big-batches for subgraph-based model 224000 272115 1
# generating big-batches for subgraph-based model 226000 272115 1
# generating big-batches for subgraph-based model 228000 272115 1
# generating big-batches for subgraph-based model 230000 272115 1
# generating big-batches for subgraph-based model 232000 272115 1
# generating big-batches for subgraph-based model 234000 272115 1
# generating big-batches for subgraph-based model 236000 272115 1
# generating big-batches for subgraph-based model 238000 272115 1
# generating big-batches for subgraph-based model 240000 272115 1
# generating big-batches for subgraph-based model 242000 272115 1
# generating big-batches for subgraph-based model 244000 272115 1
# generating big-batches for subgraph-based model 246000 272115 1
# generating big-batches for subgraph-based model 248000 272115 1
# generating big-batches for subgraph-based model 250000 272115 1
# generating big-batches for subgraph-based model 252000 272115 1
# generating big-batches for subgraph-based model 254000 272115 1
# generating big-batches for subgraph-based model 256000 272115 1
# generating big-batches for subgraph-based model 258000 272115 1
# generating big-batches for subgraph-based model 260000 272115 1
# generating big-batches for subgraph-based model 262000 272115 1
# generating big-batches for subgraph-based model 264000 272115 1
# generating big-batches for subgraph-based model 266000 272115 1
# generating big-batches for subgraph-based model 268000 272115 1
# generating big-batches for subgraph-based model 270000 272115 1
# generating big-batches for subgraph-based model 272000 272115 1
# generating big-batches for subgraph-based model 0 272115 2
# generating big-batches for subgraph-based model 2000 272115 2
# generating big-batches for subgraph-based model 4000 272115 2
# generating big-batches for subgraph-based model 6000 272115 2
# generating big-batches for subgraph-based model 8000 272115 2
# generating big-batches for subgraph-based model 10000 272115 2
# generating big-batches for subgraph-based model 12000 272115 2
# generating big-batches for subgraph-based model 14000 272115 2
# generating big-batches for subgraph-based model 16000 272115 2
# generating big-batches for subgraph-based model 18000 272115 2
# generating big-batches for subgraph-based model 20000 272115 2
# generating big-batches for subgraph-based model 22000 272115 2
# generating big-batches for subgraph-based model 24000 272115 2
# generating big-batches for subgraph-based model 26000 272115 2
# generating big-batches for subgraph-based model 28000 272115 2
# generating big-batches for subgraph-based model 30000 272115 2
# generating big-batches for subgraph-based model 32000 272115 2
# generating big-batches for subgraph-based model 34000 272115 2
# generating big-batches for subgraph-based model 36000 272115 2
# generating big-batches for subgraph-based model 38000 272115 2
# generating big-batches for subgraph-based model 40000 272115 2
# generating big-batches for subgraph-based model 42000 272115 2
# generating big-batches for subgraph-based model 44000 272115 2
# generating big-batches for subgraph-based model 46000 272115 2
# generating big-batches for subgraph-based model 48000 272115 2
# generating big-batches for subgraph-based model 50000 272115 2
# generating big-batches for subgraph-based model 52000 272115 2
# generating big-batches for subgraph-based model 54000 272115 2
# generating big-batches for subgraph-based model 56000 272115 2
# generating big-batches for subgraph-based model 58000 272115 2
# generating big-batches for subgraph-based model 60000 272115 2
# generating big-batches for subgraph-based model 62000 272115 2
# generating big-batches for subgraph-based model 64000 272115 2
# generating big-batches for subgraph-based model 66000 272115 2
# generating big-batches for subgraph-based model 68000 272115 2
# generating big-batches for subgraph-based model 70000 272115 2
# generating big-batches for subgraph-based model 72000 272115 2
# generating big-batches for subgraph-based model 74000 272115 2
# generating big-batches for subgraph-based model 76000 272115 2
# generating big-batches for subgraph-based model 78000 272115 2
# generating big-batches for subgraph-based model 80000 272115 2
# generating big-batches for subgraph-based model 82000 272115 2
# generating big-batches for subgraph-based model 84000 272115 2
# generating big-batches for subgraph-based model 86000 272115 2
# generating big-batches for subgraph-based model 88000 272115 2
# generating big-batches for subgraph-based model 90000 272115 2
# generating big-batches for subgraph-based model 92000 272115 2
# generating big-batches for subgraph-based model 94000 272115 2
# generating big-batches for subgraph-based model 96000 272115 2
# generating big-batches for subgraph-based model 98000 272115 2
# generating big-batches for subgraph-based model 100000 272115 2
# generating big-batches for subgraph-based model 102000 272115 2
# generating big-batches for subgraph-based model 104000 272115 2
# generating big-batches for subgraph-based model 106000 272115 2
# generating big-batches for subgraph-based model 108000 272115 2
# generating big-batches for subgraph-based model 110000 272115 2
# generating big-batches for subgraph-based model 112000 272115 2
# generating big-batches for subgraph-based model 114000 272115 2
# generating big-batches for subgraph-based model 116000 272115 2
# generating big-batches for subgraph-based model 118000 272115 2
# generating big-batches for subgraph-based model 120000 272115 2
# generating big-batches for subgraph-based model 122000 272115 2
# generating big-batches for subgraph-based model 124000 272115 2
# generating big-batches for subgraph-based model 126000 272115 2
# generating big-batches for subgraph-based model 128000 272115 2
# generating big-batches for subgraph-based model 130000 272115 2
# generating big-batches for subgraph-based model 132000 272115 2
# generating big-batches for subgraph-based model 134000 272115 2
# generating big-batches for subgraph-based model 136000 272115 2
# generating big-batches for subgraph-based model 138000 272115 2
# generating big-batches for subgraph-based model 140000 272115 2
# generating big-batches for subgraph-based model 142000 272115 2
# generating big-batches for subgraph-based model 144000 272115 2
# generating big-batches for subgraph-based model 146000 272115 2
# generating big-batches for subgraph-based model 148000 272115 2
# generating big-batches for subgraph-based model 150000 272115 2
# generating big-batches for subgraph-based model 152000 272115 2
# generating big-batches for subgraph-based model 154000 272115 2
# generating big-batches for subgraph-based model 156000 272115 2
# generating big-batches for subgraph-based model 158000 272115 2
# generating big-batches for subgraph-based model 160000 272115 2
# generating big-batches for subgraph-based model 162000 272115 2
# generating big-batches for subgraph-based model 164000 272115 2
# generating big-batches for subgraph-based model 166000 272115 2
# generating big-batches for subgraph-based model 168000 272115 2
# generating big-batches for subgraph-based model 170000 272115 2
# generating big-batches for subgraph-based model 172000 272115 2
# generating big-batches for subgraph-based model 174000 272115 2
# generating big-batches for subgraph-based model 176000 272115 2
# generating big-batches for subgraph-based model 178000 272115 2
# generating big-batches for subgraph-based model 180000 272115 2
# generating big-batches for subgraph-based model 182000 272115 2
# generating big-batches for subgraph-based model 184000 272115 2
# generating big-batches for subgraph-based model 186000 272115 2
# generating big-batches for subgraph-based model 188000 272115 2
# generating big-batches for subgraph-based model 190000 272115 2
# generating big-batches for subgraph-based model 192000 272115 2
# generating big-batches for subgraph-based model 194000 272115 2
# generating big-batches for subgraph-based model 196000 272115 2
# generating big-batches for subgraph-based model 198000 272115 2
# generating big-batches for subgraph-based model 200000 272115 2
# generating big-batches for subgraph-based model 202000 272115 2
# generating big-batches for subgraph-based model 204000 272115 2
# generating big-batches for subgraph-based model 206000 272115 2
# generating big-batches for subgraph-based model 208000 272115 2
# generating big-batches for subgraph-based model 210000 272115 2
# generating big-batches for subgraph-based model 212000 272115 2
# generating big-batches for subgraph-based model 214000 272115 2
# generating big-batches for subgraph-based model 216000 272115 2
# generating big-batches for subgraph-based model 218000 272115 2
# generating big-batches for subgraph-based model 220000 272115 2
# generating big-batches for subgraph-based model 222000 272115 2
# generating big-batches for subgraph-based model 224000 272115 2
# generating big-batches for subgraph-based model 226000 272115 2
# generating big-batches for subgraph-based model 228000 272115 2
# generating big-batches for subgraph-based model 230000 272115 2
# generating big-batches for subgraph-based model 232000 272115 2
# generating big-batches for subgraph-based model 234000 272115 2
# generating big-batches for subgraph-based model 236000 272115 2
# generating big-batches for subgraph-based model 238000 272115 2
# generating big-batches for subgraph-based model 240000 272115 2
# generating big-batches for subgraph-based model 242000 272115 2
# generating big-batches for subgraph-based model 244000 272115 2
# generating big-batches for subgraph-based model 246000 272115 2
# generating big-batches for subgraph-based model 248000 272115 2
# generating big-batches for subgraph-based model 250000 272115 2
# generating big-batches for subgraph-based model 252000 272115 2
# generating big-batches for subgraph-based model 254000 272115 2
# generating big-batches for subgraph-based model 256000 272115 2
# generating big-batches for subgraph-based model 258000 272115 2
# generating big-batches for subgraph-based model 260000 272115 2
# generating big-batches for subgraph-based model 262000 272115 2
# generating big-batches for subgraph-based model 264000 272115 2
# generating big-batches for subgraph-based model 266000 272115 2
# generating big-batches for subgraph-based model 268000 272115 2
# generating big-batches for subgraph-based model 270000 272115 2
# generating big-batches for subgraph-based model 272000 272115 2
# generating big-batches for subgraph-based model 0 272115 3
# generating big-batches for subgraph-based model 2000 272115 3
# generating big-batches for subgraph-based model 4000 272115 3
# generating big-batches for subgraph-based model 6000 272115 3
# generating big-batches for subgraph-based model 8000 272115 3
# generating big-batches for subgraph-based model 10000 272115 3
# generating big-batches for subgraph-based model 12000 272115 3
# generating big-batches for subgraph-based model 14000 272115 3
# generating big-batches for subgraph-based model 16000 272115 3
# generating big-batches for subgraph-based model 18000 272115 3
# generating big-batches for subgraph-based model 20000 272115 3
# generating big-batches for subgraph-based model 22000 272115 3
# generating big-batches for subgraph-based model 24000 272115 3
# generating big-batches for subgraph-based model 26000 272115 3
# generating big-batches for subgraph-based model 28000 272115 3
# generating big-batches for subgraph-based model 30000 272115 3
# generating big-batches for subgraph-based model 32000 272115 3
# generating big-batches for subgraph-based model 34000 272115 3
# generating big-batches for subgraph-based model 36000 272115 3
# generating big-batches for subgraph-based model 38000 272115 3
# generating big-batches for subgraph-based model 40000 272115 3
# generating big-batches for subgraph-based model 42000 272115 3
# generating big-batches for subgraph-based model 44000 272115 3
# generating big-batches for subgraph-based model 46000 272115 3
# generating big-batches for subgraph-based model 48000 272115 3
# generating big-batches for subgraph-based model 50000 272115 3
# generating big-batches for subgraph-based model 52000 272115 3
# generating big-batches for subgraph-based model 54000 272115 3
# generating big-batches for subgraph-based model 56000 272115 3
# generating big-batches for subgraph-based model 58000 272115 3
# generating big-batches for subgraph-based model 60000 272115 3
# generating big-batches for subgraph-based model 62000 272115 3
# generating big-batches for subgraph-based model 64000 272115 3
# generating big-batches for subgraph-based model 66000 272115 3
# generating big-batches for subgraph-based model 68000 272115 3
# generating big-batches for subgraph-based model 70000 272115 3
# generating big-batches for subgraph-based model 72000 272115 3
# generating big-batches for subgraph-based model 74000 272115 3
# generating big-batches for subgraph-based model 76000 272115 3
# generating big-batches for subgraph-based model 78000 272115 3
# generating big-batches for subgraph-based model 80000 272115 3
# generating big-batches for subgraph-based model 82000 272115 3
# generating big-batches for subgraph-based model 84000 272115 3
# generating big-batches for subgraph-based model 86000 272115 3
# generating big-batches for subgraph-based model 88000 272115 3
# generating big-batches for subgraph-based model 90000 272115 3
# generating big-batches for subgraph-based model 92000 272115 3
# generating big-batches for subgraph-based model 94000 272115 3
# generating big-batches for subgraph-based model 96000 272115 3
# generating big-batches for subgraph-based model 98000 272115 3
# generating big-batches for subgraph-based model 100000 272115 3
# generating big-batches for subgraph-based model 102000 272115 3
# generating big-batches for subgraph-based model 104000 272115 3
# generating big-batches for subgraph-based model 106000 272115 3
# generating big-batches for subgraph-based model 108000 272115 3
# generating big-batches for subgraph-based model 110000 272115 3
# generating big-batches for subgraph-based model 112000 272115 3
# generating big-batches for subgraph-based model 114000 272115 3
# generating big-batches for subgraph-based model 116000 272115 3
# generating big-batches for subgraph-based model 118000 272115 3
# generating big-batches for subgraph-based model 120000 272115 3
# generating big-batches for subgraph-based model 122000 272115 3
# generating big-batches for subgraph-based model 124000 272115 3
# generating big-batches for subgraph-based model 126000 272115 3
# generating big-batches for subgraph-based model 128000 272115 3
# generating big-batches for subgraph-based model 130000 272115 3
# generating big-batches for subgraph-based model 132000 272115 3
# generating big-batches for subgraph-based model 134000 272115 3
# generating big-batches for subgraph-based model 136000 272115 3
# generating big-batches for subgraph-based model 138000 272115 3
# generating big-batches for subgraph-based model 140000 272115 3
# generating big-batches for subgraph-based model 142000 272115 3
# generating big-batches for subgraph-based model 144000 272115 3
# generating big-batches for subgraph-based model 146000 272115 3
# generating big-batches for subgraph-based model 148000 272115 3
# generating big-batches for subgraph-based model 150000 272115 3
# generating big-batches for subgraph-based model 152000 272115 3
# generating big-batches for subgraph-based model 154000 272115 3
# generating big-batches for subgraph-based model 156000 272115 3
# generating big-batches for subgraph-based model 158000 272115 3
# generating big-batches for subgraph-based model 160000 272115 3
# generating big-batches for subgraph-based model 162000 272115 3
# generating big-batches for subgraph-based model 164000 272115 3
# generating big-batches for subgraph-based model 166000 272115 3
# generating big-batches for subgraph-based model 168000 272115 3
# generating big-batches for subgraph-based model 170000 272115 3
# generating big-batches for subgraph-based model 172000 272115 3
# generating big-batches for subgraph-based model 174000 272115 3
# generating big-batches for subgraph-based model 176000 272115 3
# generating big-batches for subgraph-based model 178000 272115 3
# generating big-batches for subgraph-based model 180000 272115 3
# generating big-batches for subgraph-based model 182000 272115 3
# generating big-batches for subgraph-based model 184000 272115 3
# generating big-batches for subgraph-based model 186000 272115 3
# generating big-batches for subgraph-based model 188000 272115 3
# generating big-batches for subgraph-based model 190000 272115 3
# generating big-batches for subgraph-based model 192000 272115 3
# generating big-batches for subgraph-based model 194000 272115 3
# generating big-batches for subgraph-based model 196000 272115 3
# generating big-batches for subgraph-based model 198000 272115 3
# generating big-batches for subgraph-based model 200000 272115 3
# generating big-batches for subgraph-based model 202000 272115 3
# generating big-batches for subgraph-based model 204000 272115 3
# generating big-batches for subgraph-based model 206000 272115 3
# generating big-batches for subgraph-based model 208000 272115 3
# generating big-batches for subgraph-based model 210000 272115 3
# generating big-batches for subgraph-based model 212000 272115 3
# generating big-batches for subgraph-based model 214000 272115 3
# generating big-batches for subgraph-based model 216000 272115 3
# generating big-batches for subgraph-based model 218000 272115 3
# generating big-batches for subgraph-based model 220000 272115 3
# generating big-batches for subgraph-based model 222000 272115 3
# generating big-batches for subgraph-based model 224000 272115 3
# generating big-batches for subgraph-based model 226000 272115 3
# generating big-batches for subgraph-based model 228000 272115 3
# generating big-batches for subgraph-based model 230000 272115 3
# generating big-batches for subgraph-based model 232000 272115 3
# generating big-batches for subgraph-based model 234000 272115 3
# generating big-batches for subgraph-based model 236000 272115 3
# generating big-batches for subgraph-based model 238000 272115 3
# generating big-batches for subgraph-based model 240000 272115 3
# generating big-batches for subgraph-based model 242000 272115 3
# generating big-batches for subgraph-based model 244000 272115 3
# generating big-batches for subgraph-based model 246000 272115 3
# generating big-batches for subgraph-based model 248000 272115 3
# generating big-batches for subgraph-based model 250000 272115 3
# generating big-batches for subgraph-based model 252000 272115 3
# generating big-batches for subgraph-based model 254000 272115 3
# generating big-batches for subgraph-based model 256000 272115 3
# generating big-batches for subgraph-based model 258000 272115 3
# generating big-batches for subgraph-based model 260000 272115 3
# generating big-batches for subgraph-based model 262000 272115 3
# generating big-batches for subgraph-based model 264000 272115 3
# generating big-batches for subgraph-based model 266000 272115 3
# generating big-batches for subgraph-based model 268000 272115 3
# generating big-batches for subgraph-based model 270000 272115 3
# generating big-batches for subgraph-based model 272000 272115 3
# generating big-batches for subgraph-based model 0 272115 4
# generating big-batches for subgraph-based model 2000 272115 4
# generating big-batches for subgraph-based model 4000 272115 4
# generating big-batches for subgraph-based model 6000 272115 4
# generating big-batches for subgraph-based model 8000 272115 4
# generating big-batches for subgraph-based model 10000 272115 4
# generating big-batches for subgraph-based model 12000 272115 4
# generating big-batches for subgraph-based model 14000 272115 4
# generating big-batches for subgraph-based model 16000 272115 4
# generating big-batches for subgraph-based model 18000 272115 4
# generating big-batches for subgraph-based model 20000 272115 4
# generating big-batches for subgraph-based model 22000 272115 4
# generating big-batches for subgraph-based model 24000 272115 4
# generating big-batches for subgraph-based model 26000 272115 4
# generating big-batches for subgraph-based model 28000 272115 4
# generating big-batches for subgraph-based model 30000 272115 4
# generating big-batches for subgraph-based model 32000 272115 4
# generating big-batches for subgraph-based model 34000 272115 4
# generating big-batches for subgraph-based model 36000 272115 4
# generating big-batches for subgraph-based model 38000 272115 4
# generating big-batches for subgraph-based model 40000 272115 4
# generating big-batches for subgraph-based model 42000 272115 4
# generating big-batches for subgraph-based model 44000 272115 4
# generating big-batches for subgraph-based model 46000 272115 4
# generating big-batches for subgraph-based model 48000 272115 4
# generating big-batches for subgraph-based model 50000 272115 4
# generating big-batches for subgraph-based model 52000 272115 4
# generating big-batches for subgraph-based model 54000 272115 4
# generating big-batches for subgraph-based model 56000 272115 4
# generating big-batches for subgraph-based model 58000 272115 4
# generating big-batches for subgraph-based model 60000 272115 4
# generating big-batches for subgraph-based model 62000 272115 4
# generating big-batches for subgraph-based model 64000 272115 4
# generating big-batches for subgraph-based model 66000 272115 4
# generating big-batches for subgraph-based model 68000 272115 4
# generating big-batches for subgraph-based model 70000 272115 4
# generating big-batches for subgraph-based model 72000 272115 4
# generating big-batches for subgraph-based model 74000 272115 4
# generating big-batches for subgraph-based model 76000 272115 4
# generating big-batches for subgraph-based model 78000 272115 4
# generating big-batches for subgraph-based model 80000 272115 4
# generating big-batches for subgraph-based model 82000 272115 4
# generating big-batches for subgraph-based model 84000 272115 4
# generating big-batches for subgraph-based model 86000 272115 4
# generating big-batches for subgraph-based model 88000 272115 4
# generating big-batches for subgraph-based model 90000 272115 4
# generating big-batches for subgraph-based model 92000 272115 4
# generating big-batches for subgraph-based model 94000 272115 4
# generating big-batches for subgraph-based model 96000 272115 4
# generating big-batches for subgraph-based model 98000 272115 4
# generating big-batches for subgraph-based model 100000 272115 4
# generating big-batches for subgraph-based model 102000 272115 4
# generating big-batches for subgraph-based model 104000 272115 4
# generating big-batches for subgraph-based model 106000 272115 4
# generating big-batches for subgraph-based model 108000 272115 4
# generating big-batches for subgraph-based model 110000 272115 4
# generating big-batches for subgraph-based model 112000 272115 4
# generating big-batches for subgraph-based model 114000 272115 4
# generating big-batches for subgraph-based model 116000 272115 4
# generating big-batches for subgraph-based model 118000 272115 4
# generating big-batches for subgraph-based model 120000 272115 4
# generating big-batches for subgraph-based model 122000 272115 4
# generating big-batches for subgraph-based model 124000 272115 4
# generating big-batches for subgraph-based model 126000 272115 4
# generating big-batches for subgraph-based model 128000 272115 4
# generating big-batches for subgraph-based model 130000 272115 4
# generating big-batches for subgraph-based model 132000 272115 4
# generating big-batches for subgraph-based model 134000 272115 4
# generating big-batches for subgraph-based model 136000 272115 4
# generating big-batches for subgraph-based model 138000 272115 4
# generating big-batches for subgraph-based model 140000 272115 4
# generating big-batches for subgraph-based model 142000 272115 4
# generating big-batches for subgraph-based model 144000 272115 4
# generating big-batches for subgraph-based model 146000 272115 4
# generating big-batches for subgraph-based model 148000 272115 4
# generating big-batches for subgraph-based model 150000 272115 4
# generating big-batches for subgraph-based model 152000 272115 4
# generating big-batches for subgraph-based model 154000 272115 4
# generating big-batches for subgraph-based model 156000 272115 4
# generating big-batches for subgraph-based model 158000 272115 4
# generating big-batches for subgraph-based model 160000 272115 4
# generating big-batches for subgraph-based model 162000 272115 4
# generating big-batches for subgraph-based model 164000 272115 4
# generating big-batches for subgraph-based model 166000 272115 4
# generating big-batches for subgraph-based model 168000 272115 4
# generating big-batches for subgraph-based model 170000 272115 4
# generating big-batches for subgraph-based model 172000 272115 4
# generating big-batches for subgraph-based model 174000 272115 4
# generating big-batches for subgraph-based model 176000 272115 4
# generating big-batches for subgraph-based model 178000 272115 4
# generating big-batches for subgraph-based model 180000 272115 4
# generating big-batches for subgraph-based model 182000 272115 4
# generating big-batches for subgraph-based model 184000 272115 4
# generating big-batches for subgraph-based model 186000 272115 4
# generating big-batches for subgraph-based model 188000 272115 4
# generating big-batches for subgraph-based model 190000 272115 4
# generating big-batches for subgraph-based model 192000 272115 4
# generating big-batches for subgraph-based model 194000 272115 4
# generating big-batches for subgraph-based model 196000 272115 4
# generating big-batches for subgraph-based model 198000 272115 4
# generating big-batches for subgraph-based model 200000 272115 4
# generating big-batches for subgraph-based model 202000 272115 4
# generating big-batches for subgraph-based model 204000 272115 4
# generating big-batches for subgraph-based model 206000 272115 4
# generating big-batches for subgraph-based model 208000 272115 4
# generating big-batches for subgraph-based model 210000 272115 4
# generating big-batches for subgraph-based model 212000 272115 4
# generating big-batches for subgraph-based model 214000 272115 4
# generating big-batches for subgraph-based model 216000 272115 4
# generating big-batches for subgraph-based model 218000 272115 4
# generating big-batches for subgraph-based model 220000 272115 4
# generating big-batches for subgraph-based model 222000 272115 4
# generating big-batches for subgraph-based model 224000 272115 4
# generating big-batches for subgraph-based model 226000 272115 4
# generating big-batches for subgraph-based model 228000 272115 4
# generating big-batches for subgraph-based model 230000 272115 4
# generating big-batches for subgraph-based model 232000 272115 4
# generating big-batches for subgraph-based model 234000 272115 4
# generating big-batches for subgraph-based model 236000 272115 4
# generating big-batches for subgraph-based model 238000 272115 4
# generating big-batches for subgraph-based model 240000 272115 4
# generating big-batches for subgraph-based model 242000 272115 4
# generating big-batches for subgraph-based model 244000 272115 4
# generating big-batches for subgraph-based model 246000 272115 4
# generating big-batches for subgraph-based model 248000 272115 4
# generating big-batches for subgraph-based model 250000 272115 4
# generating big-batches for subgraph-based model 252000 272115 4
# generating big-batches for subgraph-based model 254000 272115 4
# generating big-batches for subgraph-based model 256000 272115 4
# generating big-batches for subgraph-based model 258000 272115 4
# generating big-batches for subgraph-based model 260000 272115 4
# generating big-batches for subgraph-based model 262000 272115 4
# generating big-batches for subgraph-based model 264000 272115 4
# generating big-batches for subgraph-based model 266000 272115 4
# generating big-batches for subgraph-based model 268000 272115 4
# generating big-batches for subgraph-based model 270000 272115 4
# generating big-batches for subgraph-based model 272000 272115 4
# generating big-batches for subgraph-based model 0 17535 0
# generating big-batches for subgraph-based model 2000 17535 0
# generating big-batches for subgraph-based model 4000 17535 0
# generating big-batches for subgraph-based model 6000 17535 0
# generating big-batches for subgraph-based model 8000 17535 0
# generating big-batches for subgraph-based model 10000 17535 0
# generating big-batches for subgraph-based model 12000 17535 0
# generating big-batches for subgraph-based model 14000 17535 0
# generating big-batches for subgraph-based model 16000 17535 0
# generating big-batches for subgraph-based model 0 17535 1
# generating big-batches for subgraph-based model 2000 17535 1
# generating big-batches for subgraph-based model 4000 17535 1
# generating big-batches for subgraph-based model 6000 17535 1
# generating big-batches for subgraph-based model 8000 17535 1
# generating big-batches for subgraph-based model 10000 17535 1
# generating big-batches for subgraph-based model 12000 17535 1
# generating big-batches for subgraph-based model 14000 17535 1
# generating big-batches for subgraph-based model 16000 17535 1
# generating big-batches for subgraph-based model 0 17535 2
# generating big-batches for subgraph-based model 2000 17535 2
# generating big-batches for subgraph-based model 4000 17535 2
# generating big-batches for subgraph-based model 6000 17535 2
# generating big-batches for subgraph-based model 8000 17535 2
# generating big-batches for subgraph-based model 10000 17535 2
# generating big-batches for subgraph-based model 12000 17535 2
# generating big-batches for subgraph-based model 14000 17535 2
# generating big-batches for subgraph-based model 16000 17535 2
# generating big-batches for subgraph-based model 0 17535 3
# generating big-batches for subgraph-based model 2000 17535 3
# generating big-batches for subgraph-based model 4000 17535 3
# generating big-batches for subgraph-based model 6000 17535 3
# generating big-batches for subgraph-based model 8000 17535 3
# generating big-batches for subgraph-based model 10000 17535 3
# generating big-batches for subgraph-based model 12000 17535 3
# generating big-batches for subgraph-based model 14000 17535 3
# generating big-batches for subgraph-based model 16000 17535 3
# generating big-batches for subgraph-based model 0 17535 4
# generating big-batches for subgraph-based model 2000 17535 4
# generating big-batches for subgraph-based model 4000 17535 4
# generating big-batches for subgraph-based model 6000 17535 4
# generating big-batches for subgraph-based model 8000 17535 4
# generating big-batches for subgraph-based model 10000 17535 4
# generating big-batches for subgraph-based model 12000 17535 4
# generating big-batches for subgraph-based model 14000 17535 4
# generating big-batches for subgraph-based model 16000 17535 4
# Epoch 1/10
# 170069/170069 [==============================] - 4715s 28ms/step - loss: 0.5879 - binary_accuracy: 0.8935 - val_loss: 0.5789 - val_binary_accuracy: 0.8942
# Epoch 2/10
# 170069/170069 [==============================] - 6203s 36ms/step - loss: 0.5537 - binary_accuracy: 0.9040 - val_loss: 0.5765 - val_binary_accuracy: 0.8948
# Epoch 3/10
# 170069/170069 [==============================] - 7291s 43ms/step - loss: 0.5510 - binary_accuracy: 0.9049 - val_loss: 0.5736 - val_binary_accuracy: 0.8957
# Epoch 4/10
# 170069/170069 [==============================] - 12651s 74ms/step - loss: 0.5495 - binary_accuracy: 0.9054 - val_loss: 0.5737 - val_binary_accuracy: 0.8952
# Epoch 5/10
# 170069/170069 [==============================] - 4744s 28ms/step - loss: 0.5483 - binary_accuracy: 0.9058 - val_loss: 0.5732 - val_binary_accuracy: 0.8957
# Epoch 6/10
# 170069/170069 [==============================] - 4806s 28ms/step - loss: 0.5473 - binary_accuracy: 0.9062 - val_loss: 0.5741 - val_binary_accuracy: 0.8951
# Epoch 7/10
# 170069/170069 [==============================] - 6616s 39ms/step - loss: 0.5465 - binary_accuracy: 0.9065 - val_loss: 0.5733 - val_binary_accuracy: 0.8959
# Epoch 8/10
# 170069/170069 [==============================] - 6500s 38ms/step - loss: 0.5456 - binary_accuracy: 0.9068 - val_loss: 0.5727 - val_binary_accuracy: 0.8956
# Epoch 9/10
# 170069/170069 [==============================] - 4959s 29ms/step - loss: 0.5450 - binary_accuracy: 0.9071 - val_loss: 0.5737 - val_binary_accuracy: 0.8953
# Epoch 10/10
# 170069/170069 [==============================] - 10625s 62ms/step - loss: 0.5443 - binary_accuracy: 0.9074 - val_loss: 0.5731 - val_binary_accuracy: 0.8955
# Save model

# %% [markdown]
# ### Result on the testset for transductive link prediction
#
# We use the testset for transductive link prediction.

# %%
data_name = 'FB15K237'
model_id = 'main_transductive'

# %%
#difine the names for saving
model_name = 'Model_' + model_id + '_' + data_name
one_hop_model_name = 'One_hop_model_' + model_id + '_' + data_name
ids_name = 'IDs_' + model_id + '_' + data_name

# %%
ids_name
# Out:
# 'IDs_main_transductive_FB15K237'

# %%
one_hop_model_name
# Out:
# 'One_hop_model_main_transductive_FB15K237'

# %%
model_name
# Out:
# 'Model_main_transductive_FB15K237'

# %%
import librosa
import opensmile
import os
import sys
import numpy as np
import random
import pickle

from collections import defaultdict
from copy import deepcopy
from sklearn.utils import shuffle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras import initializers
from tensorflow.keras.utils import plot_model

# %%
class LoadKG:
    
    def __init__(self):
        
        self.x = 'Hello'
        
    def load_train_data(self, data_path, one_hop, data, s_t_r, entity2id, id2entity,
                     relation2id, id2relation):
        
        data_ = set()
    
        ####load the train, valid and test set##########
        with open (data_path, 'r') as f:
            
            data_ini = f.readlines()
                        
            for i in range(len(data_ini)):
            
                x = data_ini[i].split()
                
                x_ = tuple(x)
                
                data_.add(x_)
        
        ####relation dict#################
        index = len(relation2id)
     
        for key in data_:
            
            if key[1] not in relation2id:
                
                relation = key[1]
                
                relation2id[relation] = index
                
                id2relation[index] = relation
                
                index += 1
                
                #the inverse relation
                iv_r = '_inverse_' + relation
                
                relation2id[iv_r] = index
                
                id2relation[index] = iv_r
                
                index += 1
        
        #get the id of the inverse relation, by above definition, initial relation has 
        #always even id, while inverse relation has always odd id.
        def inverse_r(r):
            
            if r % 2 == 0: #initial relation
                
                iv_r = r + 1
            
            else: #inverse relation
                
                iv_r = r - 1
            
            return(iv_r)
        
        ####entity dict###################
        index = len(entity2id)
        
        for key in data_:
            
            source, target = key[0], key[2]
            
            if source not in entity2id:
                                
                entity2id[source] = index
                
                id2entity[index] = source
                
                index += 1
            
            if target not in entity2id:
                
                entity2id[target] = index
                
                id2entity[index] = target
                
                index += 1
                
        #create the set of triples using id instead of string        
        for ele in data_:
            
            s = entity2id[ele[0]]
            
            r = relation2id[ele[1]]
            
            t = entity2id[ele[2]]
            
            if (s,r,t) not in data:
                
                data.add((s,r,t))
            
            s_t_r[(s,t)].add(r)
            
            if s not in one_hop:
                
                one_hop[s] = set()
            
            one_hop[s].add((r,t))
            
            if t not in one_hop:
                
                one_hop[t] = set()
            
            r_inv = inverse_r(r)
            
            s_t_r[(t,s)].add(r_inv)
            
            one_hop[t].add((r_inv,s))
            
        #change each set in one_hop to list
        for e in one_hop:
            
            one_hop[e] = list(one_hop[e])

# %%
class ObtainPathsByDynamicProgramming:

    def __init__(self, amount_bd=50, size_bd=50, threshold=20000):
        
        self.amount_bd = amount_bd #how many Tuples we choose in one_hop[node] for next recursion
                        
        self.size_bd = size_bd #size bound limit the number of paths to a target entity t
        
        #number of times paths with specific length been performed for recursion
        self.threshold = threshold
        
    '''
    Given an entity s, the function will find the paths from s to other entities, using recursion.
    
    One may refer to LeetCode Problem 797 for details:
        https://leetcode.com/problems/all-paths-from-source-to-target/
    '''
    def obtain_paths(self, mode, s, t_input, lower_bd, upper_bd, one_hop):

        if type(lower_bd) != type(1) or lower_bd < 1:
            
            raise TypeError("!!! invalid lower bound setting, must >= 1 !!!")
            
        if type(upper_bd) != type(1) or upper_bd < 1:
            
            raise TypeError("!!! invalid upper bound setting, must >= 1 !!!")
            
        if lower_bd > upper_bd:
            
            raise TypeError("!!! lower bound must not exced upper bound !!!")
            
        if s not in one_hop:
            
            raise ValueError('!!! entity not in one_hop. Please work on existing entities')

        #here is the result dict. Its key is each entity t sharing paths from s
        #The value of each t is a set containing the paths from s to t
        #These paths can be either the direct connection r, or a multi-hop path
        res = defaultdict(set)
        
        #qualified_t contains the types of t we want to consider,
        #that is, what t will be added to the result set.
        qualified_t = set()

        #under this mode, we will only consider the direct neighbour of s
        if mode == 'direct_neighbour':
        
            for Tuple in one_hop[s]:
            
                t = Tuple[1]
                
                qualified_t.add(t)
        
        #under this mode, we will only consider one specified entity t
        elif mode == 'target_specified':
            
            qualified_t.add(t_input)
        
        #under this mode, we will consider any entity
        elif mode == 'any_target':
            
            for s_any in one_hop:
                
                qualified_t.add(s_any)
                
        else:
            
            raise ValueError('not a valid mode')
        
        '''
        We use recursion to find the paths
        On current node with the path [r1, ..., rk] and on-path entities {s, e1, ..., ek-1, node}
        from s to this node, we will further find the direct neighbor t' of this node. 
        If t' is not an on-path entity (not among s, e1,...ek-1, node), we recursively proceed to t' 
        '''
        def helper(node, path, on_path_en, res, qualified_t, lower_bd, upper_bd, one_hop, count_dict):

            #when the current path is within lower_bd and upper_bd, 
            #and the node is among the qualified t, and it has not been fill of paths w.r.t size_limit,
            #we will add this path to the node
            if (len(path) >= lower_bd) and (len(path) <= upper_bd) and (
                node in qualified_t) and (len(res[node]) < self.size_bd):
                
                res[node].add(tuple(path))
                    
            #won't start new recursions if the current path length already reaches upper limit
            #or the number of recursions performed on this length has reached the limit
            if (len(path) < upper_bd) and (count_dict[len(path)] <= self.threshold):
                                
                #temp list is the id list for us to go-over one_hop[node]
                temp_list = [i for i in range(len(one_hop[node]))]
                random.shuffle(temp_list) #so we random-shuffle the list
                
                #only take 20 recursions if there are too many (r,t)
                for i in temp_list[:self.amount_bd]:
                    
                    #obtain tuple of (r,t)
                    Tuple = one_hop[node][i]
                    r, t = Tuple[0], Tuple[1]
                    
                    #add to count_dict even if eventually this step not proceed
                    count_dict[len(path)] += 1
                    
                    #if t not on the path and we not exceed the computation threshold, 
                    #then finally proceed to next recursion
                    if (t not in on_path_en) and (count_dict[len(path)] <= self.threshold):

                        helper(t, path + [r], on_path_en.union({t}), res, qualified_t, 
                               lower_bd, upper_bd, one_hop, count_dict)

        length_dict = defaultdict(int)
        count_dict = defaultdict(int)
        
        helper(s, [], {s}, res, qualified_t, lower_bd, upper_bd, one_hop, count_dict)
        
        return(res, count_dict)

# %%
#load the classes
Class_1 = LoadKG()
Class_2 = ObtainPathsByDynamicProgramming()

# %%
#load ids and relation/entity dicts
with open('../weight_bin/' + ids_name + '.pickle', 'rb') as handle:
    Dict = pickle.load(handle)
    
#save training data
one_hop = Dict['one_hop']
data = Dict['data']
s_t_r = Dict['s_t_r']

#save valid data
one_hop_valid = Dict['one_hop_valid']
data_valid = Dict['data_valid']
s_t_r_valid = Dict['s_t_r_valid']

#save shared dictionaries
entity2id = Dict['entity2id']
id2entity = Dict['id2entity']
relation2id = Dict['relation2id']
id2relation = Dict['id2relation']

#we want to keep the initial entity/relation dicts before adding new entities
entity2id_ini = deepcopy(entity2id)
id2entity_ini = deepcopy(id2entity)
relation2id_ini = deepcopy(relation2id)
id2relation_ini = deepcopy(id2relation)

num_r = len(id2relation)
num_r
# Out:
# 474

# %%
test_path = '../data/' + data_name + '/test.txt'

# %%
#define the dictionaries and sets for load KG
one_hop_test = dict() 
data_test = set()
s_t_r_test = defaultdict(set)

#fill in the sets and dicts
Class_1.load_train_data(test_path, one_hop_test, data_test, s_t_r_test,
                        entity2id, id2entity, relation2id, id2relation)

# %%
#load the model
model = keras.models.load_model('../weight_bin/' + model_name + '.h5')
# Out:
# 2023-03-16 22:28:34.214914: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#load the one-hop neighbor model
model_2 = keras.models.load_model('../weight_bin/' + one_hop_model_name + '.h5')

# %%
#the function to do path-based entity scoring
def path_based_entity_scoring(s, r, lower_bd, upper_bd, one_hop, model):
    
    #key is each entity t, value is the score of (s,r,t)
    score_dict = defaultdict(float)
    
    #since we want to take the average score, we need to count how many path-combo 
    #we have added to the same entity t
    count_dict = defaultdict(int)
    
    #if s not in one_hop then directly return empty score dict
    if s not in one_hop:
        return(score_dict)
    
    #hold all connected entities to s, as well as the paths from s to them
    result, length_dict = Class_2.obtain_paths('any_target', s, 'any', lower_bd, upper_bd, one_hop)
    
    #input holder lists for big-batch
    #unlike the relation prediction, we need to mark for each position:
    #which entity it stands for. So another list_mark is needed.
    list_m = list()
    list_1 = list()
    list_2 = list()
    list_3 = list()
    list_r = list()

    #for each entity t, if there are more than three paths from s to it, 
    #we do 10 times path selection
    for t in result:
        
        if len(result[t]) >= 3: #won't proceed if less than three existing paths
            
            count = 0 #iterate
            while count < 10:

                temp_pair = random.sample(list(result[t]), 3)
                path_1, path_2, path_3 = temp_pair[0], temp_pair[1], temp_pair[2]
                
                list_m.append(t)
                list_1.append(list(path_1) + [num_r]*abs(len(path_1)-upper_bd))
                list_2.append(list(path_2) + [num_r]*abs(len(path_2)-upper_bd))
                list_3.append(list(path_3) + [num_r]*abs(len(path_3)-upper_bd))
                list_r.append([r])
                count += 1
    
    #change to arrays
    input_1 = np.array(list_1)
    input_2 = np.array(list_2)
    input_3 = np.array(list_3)
    input_r = np.array(list_r)
    
    pred = model.predict([input_1, input_2, input_3, input_r], verbose = 0)
    
    #add to score dict using list_m as indication on which entity t it is
    for i in range(len(list_m)):
        
        t = list_m[i]
        score_dict[t] += float(pred[i])
        count_dict[t] += 1
        
    for t in score_dict:
        
        score_dict[t] = deepcopy(score_dict[t]/float(count_dict[t]))

    return(score_dict)

# %%
#Again, it is too slow to run the path-finding algorithm again and again on the complete FB15K-237
#Instead, we will find the subgraph for each entity once.
#then in the subgraph based training, the subgraphs are stored and used for multiple times
def store_subgraph_dicts(lower_bd, upper_bd, data, one_hop, s_t_r,
                         relation2id, entity2id, id2relation, id2entity):
    
    #the set of all relation IDs
    relation_id_set = set()
    
    for i in range(len(id2relation)):
        
        if i not in id2relation:
            raise ValueError('error when generaing id2relation')
        
        relation_id_set.add(i)
    
    num_r = len(id2relation)
    
    #in case not all entities in entity2id are in one_hop, 
    #so we need to find out who are indeed in
    existing_ids = set()
    
    for s_1 in one_hop:
        existing_ids.add(s_1)
    
    #the ids to start path finding
    existing_ids = list(existing_ids)
    random.shuffle(existing_ids)
    
    #Dict stores the subgraph for each entity
    Dict_1 = dict()
    
    count = 0
    for s in existing_ids:
        
        path_set = set()
            
        result, length_dict = Class_2.obtain_paths('any_target', s, 'any', lower_bd, upper_bd, one_hop)

        for t_ in result:
            for path in result[t_]:
                path_set.add(path)

        del(result, length_dict)
        
        path_list = list(path_set)
        
        path_select = random.sample(path_list, min(len(path_list), 100))
            
        Dict_1[s] = deepcopy(path_select)
        
        count += 1
        if count % 100 == 0:
            print('generating and storing paths for the path-based model', count, len(existing_ids))
        
    return(Dict_1)

# %%
#subgraph based source entity scoring
def subgraph_source_scoring(r, t, lower_bd, upper_bd, one_hop, Dict, id2entity, model_2):
    
    #final output: the score dict
    score_dict = defaultdict(float)
    count_dict = defaultdict(int)
    
    #if t not in one_hop then directly return empty score dict
    if t not in one_hop:
        return(score_dict)
    
    path_t = list(Dict[t])
    
    #lists holding the input to the network
    #again, we need another list to store which s it is for
    list_s = list()
    list_s_1 = list()
    list_s_2 = list()
    list_s_3 = list()
    list_t_1 = list()
    list_t_2 = list()
    list_t_3 = list()
    list_r = list()
    
    for s in id2entity:
        
        if s in one_hop:#proceed only if s exists in the training dataset
    
            path_s = list(Dict[s])
    
            #see if both path_s and path_t have at least three paths
            if len(path_s) >= 3 and len(path_t) >= 3:

                count = 0
                while count < 10:

                    #randomly obtain three paths
                    temp_s = random.sample(path_s, 3)
                    temp_t = random.sample(path_t, 3)
                    s_p_1, s_p_2, s_p_3 = temp_s[0], temp_s[1], temp_s[2]
                    t_p_1, t_p_2, t_p_3 = temp_t[0], temp_t[1], temp_t[2]

                    #append the paths: note that we add the space holder id at the end of the shorter path
                    list_s_1.append(list(s_p_1) + [num_r]*abs(len(s_p_1)-upper_bd))
                    list_s_2.append(list(s_p_2) + [num_r]*abs(len(s_p_2)-upper_bd))
                    list_s_3.append(list(s_p_3) + [num_r]*abs(len(s_p_3)-upper_bd))

                    list_t_1.append(list(t_p_1) + [num_r]*abs(len(t_p_1)-upper_bd))
                    list_t_2.append(list(t_p_2) + [num_r]*abs(len(t_p_2)-upper_bd))
                    list_t_3.append(list(t_p_3) + [num_r]*abs(len(t_p_3)-upper_bd))

                    list_r.append([r])
                    list_s.append(s)
                    count += 1

    #change to arrays
    input_s_1 = np.array(list_s_1)
    input_s_2 = np.array(list_s_2)
    input_s_3 = np.array(list_s_3)
    input_t_1 = np.array(list_t_1)
    input_t_2 = np.array(list_t_2)
    input_t_3 = np.array(list_t_3)
    input_r = np.array(list_r)
    
    #make prediction
    pred = model_2.predict([input_s_1, input_s_2, input_s_3,
                            input_t_1, input_t_2, input_t_3, input_r], verbose = 0)
    #add to dictionary
    for i in range(len(list_s)):
        s = list_s[i]
        score_dict[s] += float(pred[i])
        count_dict[s] += 1
        
    #average the score
    for s in score_dict:
        score_dict[s] = deepcopy(score_dict[s]/float(count_dict[s]))
        
    print(len(score_dict))
        
    return(score_dict)

# %%
#subgraph based source entity scoring
def subgraph_target_scoring(s, r, lower_bd, upper_bd, one_hop, Dict, id2entity, model_2):
    
    #final output: the score dict
    score_dict = defaultdict(float)
    count_dict = defaultdict(int)
    
    #if s not in one_hop then directly return empty score dict
    if s not in one_hop:
        return(score_dict)
    
    path_s = list(Dict[s])
    
    #lists holding the input to the network
    #again, we need another list to store which t it is for
    list_t = list()
    list_s_1 = list()
    list_s_2 = list()
    list_s_3 = list()
    list_t_1 = list()
    list_t_2 = list()
    list_t_3 = list()
    list_r = list()
    
    for t in id2entity:
        
        if t in one_hop:#proceed only if s exists in the training dataset
    
            path_t = list(Dict[t])
    
            #see if both path_s and path_t have at least three paths
            if len(path_s) >= 3 and len(path_t) >= 3:

                count = 0
                while count < 10:

                    #randomly obtain three paths
                    temp_s = random.sample(path_s, 3)
                    temp_t = random.sample(path_t, 3)
                    s_p_1, s_p_2, s_p_3 = temp_s[0], temp_s[1], temp_s[2]
                    t_p_1, t_p_2, t_p_3 = temp_t[0], temp_t[1], temp_t[2]

                    #append the paths: note that we add the space holder id at the end of the shorter path
                    list_s_1.append(list(s_p_1) + [num_r]*abs(len(s_p_1)-upper_bd))
                    list_s_2.append(list(s_p_2) + [num_r]*abs(len(s_p_2)-upper_bd))
                    list_s_3.append(list(s_p_3) + [num_r]*abs(len(s_p_3)-upper_bd))

                    list_t_1.append(list(t_p_1) + [num_r]*abs(len(t_p_1)-upper_bd))
                    list_t_2.append(list(t_p_2) + [num_r]*abs(len(t_p_2)-upper_bd))
                    list_t_3.append(list(t_p_3) + [num_r]*abs(len(t_p_3)-upper_bd))

                    list_r.append([r])
                    list_t.append(t)
                    count += 1

    #change to arrays
    input_s_1 = np.array(list_s_1)
    input_s_2 = np.array(list_s_2)
    input_s_3 = np.array(list_s_3)
    input_t_1 = np.array(list_t_1)
    input_t_2 = np.array(list_t_2)
    input_t_3 = np.array(list_t_3)
    input_r = np.array(list_r)
    
    #make prediction
    pred = model_2.predict([input_s_1, input_s_2, input_s_3,
                            input_t_1, input_t_2, input_t_3, input_r], verbose = 0)
    #add to dictionary
    for i in range(len(list_t)):
        t = list_t[i]
        score_dict[t] += float(pred[i])
        count_dict[t] += 1
        
    #average the score
    for t in score_dict:
        score_dict[t] = deepcopy(score_dict[t]/float(count_dict[t]))
        
    print(len(score_dict))
        
    return(score_dict)

# %%
#obtain the subgraph Dict
#Dict_train = store_subgraph_dicts(1, 3, data, one_hop, s_t_r,
#                         relation2id, entity2id, id2relation, id2entity)

# %%
############################################
####source entity prediction################

#we select all the triples in the inductive test set
selected = list(data_test)

###Hit at 1#############################
#generate the negative samples by randomly replace relation with all the other relaiton
Hits_at_1 = 0
Hits_at_3 = 0
Hits_at_10 = 0
MRR_raw = 0.

for i in range(len(selected)):
    
    s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
    
    r_true_inv = r_true + 1
    
    #run the path-based scoring
    score_dict = path_based_entity_scoring(t_true, r_true_inv, 1, 10, one_hop, model)
    
    #[... [score, r], ...]
    temp_list = list()
    
    for e in id2entity:

        if e in score_dict:

            temp_list.append([score_dict[e], e])

        else:

            temp_list.append([0.0, e])

    sorted_list = sorted(temp_list, key = lambda x: x[0], reverse=True)
    
    p = 0
    exist_tri = 0
    
    while p < len(sorted_list) and sorted_list[p][1] != s_true:
        
        #moreover, we want to remove existing triples
        if ((sorted_list[p][1], r_true, t_true) in data_test) or (
            (sorted_list[p][1], r_true, t_true) in data_valid) or (
            (sorted_list[p][1], r_true, t_true) in data):
            
            exist_tri += 1
            
        p += 1
    
    if p - exist_tri == 0:
        
        Hits_at_1 += 1
        
    if p - exist_tri < 3:
        
        Hits_at_3 += 1
        
    if p - exist_tri < 10:
        
        Hits_at_10 += 1
        
    MRR_raw += 1./float(p - exist_tri + 1.) 
        
    print('checkcorrect', s_true, sorted_list[p][1],
          'real score', sorted_list[p][0],
          'Hits@1', Hits_at_1/(i+1),
          'Hits@3', Hits_at_3/(i+1),
          'Hits@10', Hits_at_10/(i+1),
          'MRR', MRR_raw/(i+1),
          'cur_rank', p - exist_tri,
          'abs_cur_rank', p,
          'total_num', i, len(selected))
# Out:
# checkcorrect 3241 3241 real score 0.7750978827476501 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.0007434944237918215 cur_rank 1344 abs_cur_rank 1454 total_num 0 20466
# checkcorrect 2382 2382 real score 0.0 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.0006395565316602385 cur_rank 1866 abs_cur_rank 3699 total_num 1 20466
# checkcorrect 6498 6498 real score 0.9808678388595581 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.004171689373166751 cur_rank 88 abs_cur_rank 90 total_num 2 20466
# checkcorrect 2298 2298 real score 0.6329669773578643 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.003551778874206704 cur_rank 590 abs_cur_rank 2861 total_num 3 20466
# checkcorrect 13682 13682 real score 0.9968073487281799 Hits@1 0.2 Hits@3 0.2 Hits@10 0.2 MRR 0.20284142309936537 cur_rank 0 abs_cur_rank 0 total_num 4 20466
# checkcorrect 10895 10895 real score 0.8823171377182006 Hits@1 0.16666666666666666 Hits@3 0.16666666666666666 Hits@10 0.16666666666666666 MRR 0.1695975823125342 cur_rank 295 abs_cur_rank 302 total_num 5 20466
# checkcorrect 3303 3303 real score 0.3113603115081787 Hits@1 0.14285714285714285 Hits@3 0.14285714285714285 Hits@10 0.14285714285714285 MRR 0.14546897770642 cur_rank 1433 abs_cur_rank 1782 total_num 6 20466
# checkcorrect 4178 4178 real score 0.6093429803848267 Hits@1 0.125 Hits@3 0.125 Hits@10 0.125 MRR 0.12777748147736948 cur_rank 253 abs_cur_rank 257 total_num 7 20466
# checkcorrect 12877 12877 real score 0.0 Hits@1 0.1111111111111111 Hits@3 0.1111111111111111 Hits@10 0.1111111111111111 MRR 0.11359957294148876 cur_rank 5671 abs_cur_rank 5710 total_num 8 20466
# checkcorrect 816 816 real score 0.662926834821701 Hits@1 0.015184381778741865 Hits@3 0.04338394793926247 Hits@10 0.11496746203904555 MRR 0.05229678996328893 cur_rank 750 abs_cur_rank 2934 total_num 460 20466
# checkcorrect 6831 6831 real score 0.8011524915695191 Hits@1 0.015151515151515152 Hits@3 0.04329004329004329 Hits@10 0.11471861471861472 MRR 0.052187862683255336 cur_rank 506 abs_cur_rank 520 total_num 461 20466
# checkcorrect 5967 5967 real score 0.7125543355941772 Hits@1 0.01511879049676026 Hits@3 0.04319654427645788 Hits@10 0.11447084233261338 MRR 0.05208305737219648 cur_rank 272 abs_cur_rank 953 total_num 462 20466
# checkcorrect 1831 1831 real score 0.9859106183052063 Hits@1 0.015086206896551725 Hits@3 0.04310344827586207 Hits@10 0.11422413793103449 MRR 0.05204264848418169 cur_rank 29 abs_cur_rank 30 total_num 463 20466
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_16262/2898971935.py in <module>
#      19
#      20     #run the path-based scoring
# ---> 21     score_dict = path_based_entity_scoring(t_true, r_true_inv, 1, 10, one_hop, model)
#      22
#      23     #[... [score, r], ...]
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_16262/868037427.py in path_based_entity_scoring(s, r, lower_bd, upper_bd, one_hop, model)
#      50     input_r = np.array(list_r)
#      51
# ---> 52     pred = model.predict([input_1, input_2, input_3, input_r], verbose = 0)
#      53
#      54     #add to score dict using list_m as indication on which entity t it is
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2031           for step in data_handler.steps():
#    2032             callbacks.on_predict_batch_begin(step)
# -> 2033             tmp_batch_outputs = self.predict_function(iterator)
#    2034             if data_handler.should_sync:
#    2035               context.async_wait()
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
############################################
####target entity prediction################

#we select all the triples in the inductive test set
selected = list(data_test)

###Hit at 1#############################
#generate the negative samples by randomly replace relation with all the other relaiton
Hits_at_1 = 0
Hits_at_3 = 0
Hits_at_10 = 0
MRR_raw = 0.

for i in range(len(selected)):
    
    s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
        
    #first run the path-based scoring
    score_dict = path_based_entity_scoring(s_true, r_true, 1, 10, one_hop, model)
    
    #[... [score, r], ...]
    temp_list = list()
    
    for e in id2entity:

        if e in score_dict:

            temp_list.append([score_dict[e], e])

        else:

            temp_list.append([0.0, e])

    sorted_list = sorted(temp_list, key = lambda x: x[0], reverse=True)
    
    p = 0
    exist_tri = 0
    
    while p < len(sorted_list) and sorted_list[p][1] != t_true:
        
        #moreover, we want to remove existing triples
        if ((s_true, r_true, sorted_list[p][1]) in data_test) or (
            (s_true, r_true, sorted_list[p][1]) in data_valid) or (
            (s_true, r_true, sorted_list[p][1]) in data):
            
            exist_tri += 1
            
        p += 1
    
    if p - exist_tri == 0:
        
        Hits_at_1 += 1
        
    if p - exist_tri < 3:
        
        Hits_at_3 += 1
        
    if p - exist_tri < 10:
        
        Hits_at_10 += 1
        
    MRR_raw += 1./float(p - exist_tri + 1.) 
        
    print('checkcorrect', t_true, sorted_list[p][1],
          'real score', sorted_list[p][0],
          'Hits@1', Hits_at_1/(i+1),
          'Hits@3', Hits_at_3/(i+1),
          'Hits@10', Hits_at_10/(i+1),
          'MRR', MRR_raw/(i+1),
          'cur_rank', p - exist_tri,
          'abs_cur_rank', p,
          'total_num', i, len(selected))

# %% [markdown]
# **bin**

# %%
#obtain the subgraph Dict
Dict_train = store_subgraph_dicts(1, 3, data, one_hop, s_t_r,
                         relation2id, entity2id, id2relation, id2entity)

# %%
############################################
####source entity prediction################

#we select all the triples in the inductive test set
selected = list(data_test)

###Hit at 1#############################
#generate the negative samples by randomly replace relation with all the other relaiton
Hits_at_1 = 0
Hits_at_3 = 0
Hits_at_10 = 0
MRR_raw = 0.

for i in range(len(selected)):
    
    s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
    
    r_true_inv = r_true + 1
    
    #first run the path-based scoring
    score_dict_path = path_based_entity_scoring(t_true, r_true_inv, 1, 10, one_hop, model)
    
    #then run the subgraph scoring
    score_dict_subg = subgraph_source_scoring(r_true, t_true, 1, 3, one_hop, Dict_train, id2entity, model_2)
    
    #final score dict
    score_dict = defaultdict(float)
    
    for s in score_dict_path:
        score_dict[s] += score_dict_path[s]
    for s in score_dict_subg:
        score_dict[s] += score_dict_subg[s]
    
    #[... [score, r], ...]
    temp_list = list()
    
    for e in id2entity:

        if e in score_dict:

            temp_list.append([score_dict[e], e])

        else:

            temp_list.append([0.0, e])

    sorted_list = sorted(temp_list, key = lambda x: x[0], reverse=True)
    
    p = 0
    exist_tri = 0
    
    while p < len(sorted_list) and sorted_list[p][1] != s_true:
        
        #moreover, we want to remove existing triples
        if ((sorted_list[p][1], r_true, t_true) in data_test) or (
            (sorted_list[p][1], r_true, t_true) in data_valid) or (
            (sorted_list[p][1], r_true, t_true) in data):
            
            exist_tri += 1
            
        p += 1
    
    if p - exist_tri == 0:
        
        Hits_at_1 += 1
        
    if p - exist_tri < 3:
        
        Hits_at_3 += 1
        
    if p - exist_tri < 10:
        
        Hits_at_10 += 1
        
    MRR_raw += 1./float(p - exist_tri + 1.) 
        
    print('checkcorrect', s_true, sorted_list[p][1],
          'real score', sorted_list[p][0],
          'Hits@1', Hits_at_1/(i+1),
          'Hits@3', Hits_at_3/(i+1),
          'Hits@10', Hits_at_10/(i+1),
          'MRR', MRR_raw/(i+1),
          'cur_rank', p - exist_tri,
          'abs_cur_rank', p,
          'total_num', i, len(selected))
# Out:
# 14496
# checkcorrect 2382 2382 real score 1.5545192778110504 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.001869158878504673 cur_rank 534 abs_cur_rank 1658 total_num 0 20466
# 14496
# checkcorrect 3241 3241 real score 1.743541157245636 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.002537143541816439 cur_rank 311 abs_cur_rank 351 total_num 1 20466
# 14496
# checkcorrect 6498 6498 real score 1.8224830389022828 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.008937805839471829 cur_rank 45 abs_cur_rank 46 total_num 2 20466
# 14496
# checkcorrect 2298 2298 real score 1.4572955012321471 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.00702427864147807 cur_rank 778 abs_cur_rank 3221 total_num 3 20466
# 14496
# checkcorrect 13682 13682 real score 1.7605762034654617 Hits@1 0.0 Hits@3 0.0 Hits@10 0.2 MRR 0.04561942291318245 cur_rank 4 abs_cur_rank 4 total_num 4 20466
# 14496
# checkcorrect 10895 10895 real score 1.7302967727184297 Hits@1 0.0 Hits@3 0.0 Hits@10 0.16666666666666666 MRR 0.042182852427652046 cur_rank 39 abs_cur_rank 39 total_num 5 20466
# 14496
# checkcorrect 3303 3303 real score 1.4508471369743348 Hits@1 0.0 Hits@3 0.0 Hits@10 0.14285714285714285 MRR 0.0363174248512126 cur_rank 888 abs_cur_rank 1216 total_num 6 20466
# 14496
# checkcorrect 4178 4178 real score 0.3893768787384033 Hits@1 0.0 Hits@3 0.0 Hits@10 0.125 MRR 0.03184208024970037 cur_rank 1942 abs_cur_rank 1947 total_num 7 20466
# 14496
# checkcorrect 12877 12877 real score 0.8738848268985748 Hits@1 0.0 Hits@3 0.0 Hits@10 0.1111111111111111 MRR 0.028468924613647282 cur_rank 673 abs_cur_rank 702 total_num 8 20466
# 14496
# checkcorrect 5013 5013 real score 1.64079350233078 Hits@1 0.0 Hits@3 0.0 Hits@10 0.1 MRR 0.027234935378089003 cur_rank 61 abs_cur_rank 228 total_num 9 20466
# 14496
# checkcorrect 1087 1087 real score 1.8244634330272675 Hits@1 0.0 Hits@3 0.0 Hits@10 0.09090909090909091 MRR 0.02930448670735364 cur_rank 19 abs_cur_rank 21 total_num 10 20466
# 14496
# checkcorrect 10406 10406 real score 0.8655060112476349 Hits@1 0.0 Hits@3 0.0 Hits@10 0.08333333333333333 MRR 0.02689214441402879 cur_rank 2805 abs_cur_rank 3638 total_num 11 20466
# 14496
# checkcorrect 7590 7590 real score 1.7559728562831878 Hits@1 0.0 Hits@3 0.0 Hits@10 0.07692307692307693 MRR 0.025037193134317175 cur_rank 359 abs_cur_rank 367 total_num 12 20466
# 14496
# checkcorrect 9543 9543 real score 1.5975909531116486 Hits@1 0.0 Hits@3 0.0 Hits@10 0.07142857142857142 MRR 0.02370378124983683 cur_rank 156 abs_cur_rank 718 total_num 13 20466
# 14496
# checkcorrect 791 791 real score 1.9330991744995116 Hits@1 0.0 Hits@3 0.0 Hits@10 0.06666666666666667 MRR 0.023832930875916085 cur_rank 38 abs_cur_rank 38 total_num 14 20466
# 14496
# checkcorrect 3061 3061 real score 1.1400864526629448 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0625 MRR 0.0224000877596922 cur_rank 1101 abs_cur_rank 3155 total_num 15 20466
# 14496
# checkcorrect 6810 6810 real score 1.8864690363407135 Hits@1 0.0 Hits@3 0.0 Hits@10 0.058823529411764705 MRR 0.02248299576262347 cur_rank 41 abs_cur_rank 47 total_num 16 20466
# 14496
# checkcorrect 7439 7439 real score 1.8136481404304505 Hits@1 0.0 Hits@3 0.0 Hits@10 0.05555555555555555 MRR 0.024501914298686873 cur_rank 16 abs_cur_rank 101 total_num 17 20466
# 14496
# checkcorrect 2759 2759 real score 1.8460639774799348 Hits@1 0.0 Hits@3 0.05263157894736842 Hits@10 0.10526315789473684 MRR 0.04952812933559809 cur_rank 1 abs_cur_rank 1 total_num 18 20466
# 14496
# checkcorrect 1374 1374 real score 1.4134879648685454 Hits@1 0.0 Hits@3 0.05 Hits@10 0.1 MRR 0.04715152326801979 cur_rank 500 abs_cur_rank 1839 total_num 19 20466
# 14496
# checkcorrect 10215 10215 real score 1.7487141132354735 Hits@1 0.0 Hits@3 0.047619047619047616 Hits@10 0.09523809523809523 MRR 0.045586484745052856 cur_rank 69 abs_cur_rank 221 total_num 20 20466
# 14496
# checkcorrect 2311 2311 real score 1.6227799117565156 Hits@1 0.0 Hits@3 0.045454545454545456 Hits@10 0.09090909090909091 MRR 0.04513774842547253 cur_rank 27 abs_cur_rank 28 total_num 21 20466
# 14496
# checkcorrect 5717 5717 real score 0.778143721818924 Hits@1 0.0 Hits@3 0.043478260869565216 Hits@10 0.08695652173913043 MRR 0.04318565657017609 cur_rank 4172 abs_cur_rank 4189 total_num 22 20466
# 14496
# checkcorrect 3152 3152 real score 1.7572346329689026 Hits@1 0.0 Hits@3 0.041666666666666664 Hits@10 0.08333333333333333 MRR 0.043990420879752086 cur_rank 15 abs_cur_rank 15 total_num 23 20466
# 14496
# checkcorrect 1509 1509 real score 1.87841756939888 Hits@1 0.0 Hits@3 0.04 Hits@10 0.08 MRR 0.04325644507020303 cur_rank 38 abs_cur_rank 38 total_num 24 20466
# 14496
# checkcorrect 7978 7978 real score 1.5461110055446625 Hits@1 0.0 Hits@3 0.038461538461538464 Hits@10 0.07692307692307693 MRR 0.041692895900836247 cur_rank 383 abs_cur_rank 694 total_num 25 20466
# 14496
# checkcorrect 4154 4154 real score 1.66907359957695 Hits@1 0.0 Hits@3 0.037037037037037035 Hits@10 0.07407407407407407 MRR 0.04058963167875942 cur_rank 83 abs_cur_rank 153 total_num 26 20466
# 14496
# checkcorrect 5950 5950 real score 1.7610203206539152 Hits@1 0.0 Hits@3 0.03571428571428571 Hits@10 0.10714285714285714 MRR 0.042711430547375154 cur_rank 9 abs_cur_rank 17 total_num 27 20466
# 14496
# checkcorrect 6778 6778 real score 1.659392523765564 Hits@1 0.0 Hits@3 0.034482758620689655 Hits@10 0.10344827586206896 MRR 0.041456867905191555 cur_rank 157 abs_cur_rank 198 total_num 28 20466
# 14496
# checkcorrect 8268 8268 real score 1.8552366137504577 Hits@1 0.0 Hits@3 0.06666666666666667 Hits@10 0.13333333333333333 MRR 0.0567416389750185 cur_rank 1 abs_cur_rank 1 total_num 29 20466
# 14496
# checkcorrect 7347 7347 real score 1.7714309871196747 Hits@1 0.0 Hits@3 0.06451612903225806 Hits@10 0.12903225806451613 MRR 0.055717715137114675 cur_rank 39 abs_cur_rank 94 total_num 30 20466
# 14496
# checkcorrect 1313 1313 real score 1.8774765551090242 Hits@1 0.0 Hits@3 0.0625 Hits@10 0.125 MRR 0.05431621045212332 cur_rank 91 abs_cur_rank 96 total_num 31 20466
# 14496
# checkcorrect 2909 2909 real score 1.2106674432754516 Hits@1 0.0 Hits@3 0.06060606060606061 Hits@10 0.12121212121212122 MRR 0.05271562849866576 cur_rank 667 abs_cur_rank 670 total_num 32 20466
# 14496
# checkcorrect 7908 7908 real score 1.687525326013565 Hits@1 0.0 Hits@3 0.058823529411764705 Hits@10 0.11764705882352941 MRR 0.0513258888626555 cur_rank 182 abs_cur_rank 659 total_num 33 20466
# 14496
# checkcorrect 12801 12801 real score 1.2473133736290039 Hits@1 0.0 Hits@3 0.05714285714285714 Hits@10 0.11428571428571428 MRR 0.05012897667412681 cur_rank 105 abs_cur_rank 106 total_num 34 20466
# 14496
# checkcorrect 2316 2316 real score 1.226689226925373 Hits@1 0.0 Hits@3 0.05555555555555555 Hits@10 0.1111111111111111 MRR 0.048749657456747864 cur_rank 2111 abs_cur_rank 2998 total_num 35 20466
# 14496
# checkcorrect 5866 5866 real score 1.8195913314819336 Hits@1 0.0 Hits@3 0.05405405405405406 Hits@10 0.10810810810810811 MRR 0.04968435139935828 cur_rank 11 abs_cur_rank 12 total_num 36 20466
# 14496
# checkcorrect 4311 4311 real score 0.8745799481868743 Hits@1 0.0 Hits@3 0.05263157894736842 Hits@10 0.10526315789473684 MRR 0.048400013401370255 cur_rank 1136 abs_cur_rank 3449 total_num 37 20466
# 14496
# checkcorrect 2041 2041 real score 1.755594053864479 Hits@1 0.0 Hits@3 0.05128205128205128 Hits@10 0.10256410256410256 MRR 0.0475725523464137 cur_rank 61 abs_cur_rank 321 total_num 38 20466
# 14496
# checkcorrect 240 240 real score 1.689652717113495 Hits@1 0.0 Hits@3 0.05 Hits@10 0.1 MRR 0.0464480053771316 cur_rank 385 abs_cur_rank 410 total_num 39 20466
# 14496
# checkcorrect 8814 8814 real score 1.766337838023901 Hits@1 0.0 Hits@3 0.04878048780487805 Hits@10 0.0975609756097561 MRR 0.04667014074733706 cur_rank 17 abs_cur_rank 23 total_num 40 20466
# 14496
# checkcorrect 1397 1397 real score 1.6454319775104522 Hits@1 0.0 Hits@3 0.047619047619047616 Hits@10 0.09523809523809523 MRR 0.04581496330506815 cur_rank 92 abs_cur_rank 220 total_num 41 20466
# 14496
# checkcorrect 3099 3099 real score 1.8059242159128188 Hits@1 0.0 Hits@3 0.046511627906976744 Hits@10 0.09302325581395349 MRR 0.044912127111764406 cur_rank 142 abs_cur_rank 221 total_num 42 20466
# 14496
# checkcorrect 7590 7590 real score 1.7856257140636442 Hits@1 0.0 Hits@3 0.045454545454545456 Hits@10 0.09090909090909091 MRR 0.04415262996998711 cur_rank 86 abs_cur_rank 122 total_num 43 20466
# 14496
# checkcorrect 2733 2733 real score 1.933617603778839 Hits@1 0.022222222222222223 Hits@3 0.06666666666666667 Hits@10 0.1111111111111111 MRR 0.06539368263732073 cur_rank 0 abs_cur_rank 0 total_num 44 20466
# 14496
# checkcorrect 2929 2929 real score 1.3325686648488044 Hits@1 0.021739130434782608 Hits@3 0.06521739130434782 Hits@10 0.10869565217391304 MRR 0.06398536070062191 cur_rank 1636 abs_cur_rank 1705 total_num 45 20466
# 14496
# checkcorrect 4841 4841 real score 1.5733115732669831 Hits@1 0.02127659574468085 Hits@3 0.06382978723404255 Hits@10 0.10638297872340426 MRR 0.06267276957894169 cur_rank 435 abs_cur_rank 437 total_num 46 20466
# 14496
# checkcorrect 1360 1360 real score 1.4202022314071656 Hits@1 0.020833333333333332 Hits@3 0.0625 Hits@10 0.10416666666666667 MRR 0.06143607142684177 cur_rank 301 abs_cur_rank 305 total_num 47 20466
# 14496
# checkcorrect 5029 5029 real score 1.7455645203590393 Hits@1 0.02040816326530612 Hits@3 0.061224489795918366 Hits@10 0.10204081632653061 MRR 0.060283304561998166 cur_rank 201 abs_cur_rank 1572 total_num 48 20466
# 14496
# checkcorrect 5161 5161 real score -0.2713398814201355 Hits@1 0.02 Hits@3 0.06 Hits@10 0.1 MRR 0.05907918849788368 cur_rank 12902 abs_cur_rank 13346 total_num 49 20466
# 14496
# checkcorrect 7319 7319 real score 1.8032573640346528 Hits@1 0.0196078431372549 Hits@3 0.058823529411764705 Hits@10 0.09803921568627451 MRR 0.05855328410608457 cur_rank 30 abs_cur_rank 38 total_num 50 20466
# 14496
# checkcorrect 13011 13011 real score 0.6881496578454971 Hits@1 0.019230769230769232 Hits@3 0.057692307692307696 Hits@10 0.09615384615384616 MRR 0.05743167418887884 cur_rank 4355 abs_cur_rank 4377 total_num 51 20466
# 14496
# checkcorrect 6 6 real score 1.9536368668079376 Hits@1 0.018867924528301886 Hits@3 0.05660377358490566 Hits@10 0.11320754716981132 MRR 0.058706548260786785 cur_rank 7 abs_cur_rank 7 total_num 52 20466
# 14496
# checkcorrect 1172 1172 real score 1.5770385250449181 Hits@1 0.018518518518518517 Hits@3 0.05555555555555555 Hits@10 0.1111111111111111 MRR 0.05768459601078265 cur_rank 283 abs_cur_rank 358 total_num 53 20466
# 14496
# checkcorrect 8692 8692 real score 1.0454627180472016 Hits@1 0.01818181818181818 Hits@3 0.05454545454545454 Hits@10 0.10909090909090909 MRR 0.0566440308967544 cur_rank 2204 abs_cur_rank 2234 total_num 54 20466
# 14496
# checkcorrect 8621 8621 real score 1.8775776982307435 Hits@1 0.017857142857142856 Hits@3 0.05357142857142857 Hits@10 0.10714285714285714 MRR 0.05614273442665929 cur_rank 34 abs_cur_rank 47 total_num 55 20466
# 14496
# checkcorrect 11026 11026 real score 0.8472676694393158 Hits@1 0.017543859649122806 Hits@3 0.05263157894736842 Hits@10 0.10526315789473684 MRR 0.055162400718826124 cur_rank 3791 abs_cur_rank 3911 total_num 56 20466
# 14496
# checkcorrect 5560 5560 real score 1.3495417714118958 Hits@1 0.017241379310344827 Hits@3 0.05172413793103448 Hits@10 0.10344827586206896 MRR 0.05467730806896752 cur_rank 36 abs_cur_rank 36 total_num 57 20466
# 14496
# checkcorrect 11650 11650 real score 0.6392971754074097 Hits@1 0.01694915254237288 Hits@3 0.05084745762711865 Hits@10 0.1016949152542373 MRR 0.053754319702970406 cur_rank 4524 abs_cur_rank 4528 total_num 58 20466
# 14496
# checkcorrect 3427 3427 real score 1.8119478464126586 Hits@1 0.016666666666666666 Hits@3 0.05 Hits@10 0.1 MRR 0.053615990132163324 cur_rank 21 abs_cur_rank 39 total_num 59 20466
# 14496
# checkcorrect 5709 5709 real score 1.0034755349159241 Hits@1 0.01639344262295082 Hits@3 0.04918032786885246 Hits@10 0.09836065573770492 MRR 0.05274679747582029 cur_rank 1679 abs_cur_rank 3931 total_num 60 20466
# 14496
# checkcorrect 10387 10387 real score 0.9881760723888875 Hits@1 0.016129032258064516 Hits@3 0.04838709677419355 Hits@10 0.0967741935483871 MRR 0.05194692290576661 cur_rank 316 abs_cur_rank 398 total_num 61 20466
# 14496
# checkcorrect 7468 7468 real score 1.87124844789505 Hits@1 0.015873015873015872 Hits@3 0.047619047619047616 Hits@10 0.09523809523809523 MRR 0.05225615542200161 cur_rank 13 abs_cur_rank 13 total_num 62 20466
# 14496
# checkcorrect 1791 1791 real score 1.6883918404579163 Hits@1 0.015625 Hits@3 0.046875 Hits@10 0.09375 MRR 0.05165369408942325 cur_rank 72 abs_cur_rank 75 total_num 63 20466
# 14496
# checkcorrect 1080 1080 real score 1.6367035984992981 Hits@1 0.015384615384615385 Hits@3 0.046153846153846156 Hits@10 0.09230769230769231 MRR 0.05094263391279667 cur_rank 183 abs_cur_rank 188 total_num 64 20466
# 14496
# checkcorrect 156 156 real score 1.9652127265930175 Hits@1 0.015151515151515152 Hits@3 0.045454545454545456 Hits@10 0.10606060606060606 MRR 0.052064715217148234 cur_rank 7 abs_cur_rank 10 total_num 65 20466
# 14496
# checkcorrect 4981 4981 real score 1.4267335772514342 Hits@1 0.014925373134328358 Hits@3 0.04477611940298507 Hits@10 0.1044776119402985 MRR 0.051315475760799624 cur_rank 535 abs_cur_rank 926 total_num 66 20466
# 14496
# checkcorrect 8550 8550 real score 1.272372916340828 Hits@1 0.014705882352941176 Hits@3 0.04411764705882353 Hits@10 0.10294117647058823 MRR 0.05058546938014149 cur_rank 596 abs_cur_rank 2283 total_num 67 20466
# 14496
# checkcorrect 523 523 real score 1.733159875869751 Hits@1 0.014492753623188406 Hits@3 0.043478260869565216 Hits@10 0.10144927536231885 MRR 0.04989048546082594 cur_rank 379 abs_cur_rank 525 total_num 68 20466
# 14496
# checkcorrect 6 6 real score 1.947355020046234 Hits@1 0.014285714285714285 Hits@3 0.04285714285714286 Hits@10 0.1 MRR 0.05013014519233795 cur_rank 14 abs_cur_rank 16 total_num 69 20466
# 14496
# checkcorrect 2570 2570 real score 1.4986366659402846 Hits@1 0.014084507042253521 Hits@3 0.04225352112676056 Hits@10 0.09859154929577464 MRR 0.049438758170849625 cur_rank 959 abs_cur_rank 1052 total_num 70 20466
# 14496
# checkcorrect 8272 8272 real score 1.4302021741867066 Hits@1 0.013888888888888888 Hits@3 0.041666666666666664 Hits@10 0.09722222222222222 MRR 0.04877126583993265 cur_rank 724 abs_cur_rank 2940 total_num 71 20466
# 14496
# checkcorrect 4926 4926 real score 1.8746011972427368 Hits@1 0.0136986301369863 Hits@3 0.0410958904109589 Hits@10 0.0958904109589041 MRR 0.04854505760262027 cur_rank 30 abs_cur_rank 32 total_num 72 20466
# 14496
# checkcorrect 2412 2412 real score 1.6730084002017973 Hits@1 0.013513513513513514 Hits@3 0.04054054054054054 Hits@10 0.0945945945945946 MRR 0.047998909274217474 cur_rank 122 abs_cur_rank 296 total_num 73 20466
# 14496
# checkcorrect 1156 1156 real score 1.7141937397420406 Hits@1 0.013333333333333334 Hits@3 0.04 Hits@10 0.09333333333333334 MRR 0.047729294187598276 cur_rank 35 abs_cur_rank 35 total_num 74 20466
# 14496
# checkcorrect 3991 3991 real score 1.5020121872425078 Hits@1 0.013157894736842105 Hits@3 0.039473684210526314 Hits@10 0.09210526315789473 MRR 0.047137826866416425 cur_rank 359 abs_cur_rank 365 total_num 75 20466
# 14496
# checkcorrect 3015 3015 real score 1.807347047328949 Hits@1 0.012987012987012988 Hits@3 0.03896103896103896 Hits@10 0.09090909090909091 MRR 0.04669003986617857 cur_rank 78 abs_cur_rank 157 total_num 76 20466
# 14496
# checkcorrect 4054 4054 real score 1.6896463572978973 Hits@1 0.01282051282051282 Hits@3 0.038461538461538464 Hits@10 0.08974358974358974 MRR 0.046115684985435786 cur_rank 528 abs_cur_rank 556 total_num 77 20466
# 14496
# checkcorrect 5535 5535 real score 1.902308279275894 Hits@1 0.012658227848101266 Hits@3 0.0379746835443038 Hits@10 0.08860759493670886 MRR 0.045874056403683784 cur_rank 36 abs_cur_rank 38 total_num 78 20466
# 14496
# checkcorrect 9492 9492 real score 1.8256869852542876 Hits@1 0.0125 Hits@3 0.0375 Hits@10 0.0875 MRR 0.0453348772739802 cur_rank 364 abs_cur_rank 372 total_num 79 20466
# 14496
# checkcorrect 6470 6470 real score 1.4365495502948762 Hits@1 0.012345679012345678 Hits@3 0.037037037037037035 Hits@10 0.08641975308641975 MRR 0.04478433237850811 cur_rank 1349 abs_cur_rank 1379 total_num 80 20466
# 14496
# checkcorrect 6114 6114 real score 1.6797592878341674 Hits@1 0.012195121951219513 Hits@3 0.036585365853658534 Hits@10 0.08536585365853659 MRR 0.044252247868251736 cur_rank 866 abs_cur_rank 1274 total_num 81 20466
# 14496
# checkcorrect 3530 3530 real score 0.5251914024353027 Hits@1 0.012048192771084338 Hits@3 0.03614457831325301 Hits@10 0.08433734939759036 MRR 0.043871597024635466 cur_rank 78 abs_cur_rank 78 total_num 82 20466
# 14496
# checkcorrect 7369 7369 real score 1.7404395282268523 Hits@1 0.011904761904761904 Hits@3 0.03571428571428571 Hits@10 0.08333333333333333 MRR 0.04336248509208344 cur_rank 903 abs_cur_rank 1014 total_num 83 20466
# 14496
# checkcorrect 114 114 real score 1.6133213579654693 Hits@1 0.011764705882352941 Hits@3 0.03529411764705882 Hits@10 0.08235294117647059 MRR 0.042914257713291125 cur_rank 189 abs_cur_rank 195 total_num 84 20466
# 14496
# checkcorrect 6696 6696 real score 1.199754573404789 Hits@1 0.011627906976744186 Hits@3 0.03488372093023256 Hits@10 0.08139534883720931 MRR 0.0424191540818083 cur_rank 2981 abs_cur_rank 3018 total_num 85 20466
# 14496
# checkcorrect 5676 5676 real score 1.6874215111136437 Hits@1 0.011494252873563218 Hits@3 0.034482758620689655 Hits@10 0.08045977011494253 MRR 0.04197561688114982 cur_rank 260 abs_cur_rank 427 total_num 86 20466
# 14496
# checkcorrect 1132 1132 real score 1.9611951053142547 Hits@1 0.011363636363636364 Hits@3 0.03409090909090909 Hits@10 0.09090909090909091 MRR 0.04339256062871251 cur_rank 5 abs_cur_rank 8 total_num 87 20466
# 14496
# checkcorrect 5713 5713 real score 1.5829115450382232 Hits@1 0.011235955056179775 Hits@3 0.033707865168539325 Hits@10 0.0898876404494382 MRR 0.04291246456124574 cur_rank 1505 abs_cur_rank 1547 total_num 88 20466
# 14496
# checkcorrect 10389 10389 real score 1.8206190764904022 Hits@1 0.011111111111111112 Hits@3 0.03333333333333333 Hits@10 0.1 MRR 0.043546770510565234 cur_rank 9 abs_cur_rank 11 total_num 89 20466
# 14496
# checkcorrect 12071 12071 real score 1.9026255011558533 Hits@1 0.01098901098901099 Hits@3 0.03296703296703297 Hits@10 0.0989010989010989 MRR 0.04315085871366321 cur_rank 132 abs_cur_rank 287 total_num 90 20466
# 14496
# checkcorrect 6014 6014 real score 1.7609070628881454 Hits@1 0.010869565217391304 Hits@3 0.03260869565217391 Hits@10 0.09782608695652174 MRR 0.04278735740008076 cur_rank 102 abs_cur_rank 188 total_num 91 20466
# 14496
# checkcorrect 6387 6387 real score 1.8698275268077849 Hits@1 0.010752688172043012 Hits@3 0.03225806451612903 Hits@10 0.0967741935483871 MRR 0.04268570122732003 cur_rank 29 abs_cur_rank 31 total_num 92 20466
# 14496
# checkcorrect 441 441 real score 1.749237135052681 Hits@1 0.010638297872340425 Hits@3 0.031914893617021274 Hits@10 0.09574468085106383 MRR 0.0424215676276373 cur_rank 55 abs_cur_rank 160 total_num 93 20466
# 14496
# checkcorrect 2577 2577 real score 1.591477394104004 Hits@1 0.010526315789473684 Hits@3 0.031578947368421054 Hits@10 0.09473684210526316 MRR 0.04201943964505901 cur_rank 236 abs_cur_rank 238 total_num 94 20466
# 14496
# checkcorrect 7643 7643 real score 1.7275983035564422 Hits@1 0.010416666666666666 Hits@3 0.03125 Hits@10 0.09375 MRR 0.041730546672565844 cur_rank 69 abs_cur_rank 93 total_num 95 20466
# 14496
# checkcorrect 2052 2052 real score 1.5157027512788772 Hits@1 0.010309278350515464 Hits@3 0.030927835051546393 Hits@10 0.09278350515463918 MRR 0.041327899766574895 cur_rank 373 abs_cur_rank 1632 total_num 96 20466
# 14496
# checkcorrect 9401 9401 real score 1.7396800220012665 Hits@1 0.01020408163265306 Hits@3 0.030612244897959183 Hits@10 0.09183673469387756 MRR 0.04094528260186006 cur_rank 260 abs_cur_rank 507 total_num 97 20466
# 14496
# checkcorrect 2849 2849 real score 1.7790614187717437 Hits@1 0.010101010101010102 Hits@3 0.030303030303030304 Hits@10 0.09090909090909091 MRR 0.04065639771711749 cur_rank 80 abs_cur_rank 104 total_num 98 20466
# 14496
# checkcorrect 2126 2126 real score 1.9633781909942627 Hits@1 0.01 Hits@3 0.03 Hits@10 0.1 MRR 0.04136094485105742 cur_rank 8 abs_cur_rank 11 total_num 99 20466
# 14496
# checkcorrect 7281 7281 real score 1.6856427252292634 Hits@1 0.009900990099009901 Hits@3 0.0297029702970297 Hits@10 0.09900990099009901 MRR 0.0409769485613205 cur_rank 387 abs_cur_rank 405 total_num 100 20466
# 14496
# checkcorrect 3078 3078 real score 1.5789203584194182 Hits@1 0.00980392156862745 Hits@3 0.029411764705882353 Hits@10 0.09803921568627451 MRR 0.04060283045197865 cur_rank 354 abs_cur_rank 361 total_num 101 20466
# 14496
# checkcorrect 2050 2050 real score 1.4901185631752014 Hits@1 0.009708737864077669 Hits@3 0.02912621359223301 Hits@10 0.0970873786407767 MRR 0.040406765722010955 cur_rank 48 abs_cur_rank 48 total_num 102 20466
# 14496
# checkcorrect 321 321 real score 1.5216236054897307 Hits@1 0.009615384615384616 Hits@3 0.028846153846153848 Hits@10 0.09615384615384616 MRR 0.04002387534460006 cur_rank 1705 abs_cur_rank 1786 total_num 103 20466
# 14496
# checkcorrect 11524 11524 real score 1.4363241016864778 Hits@1 0.009523809523809525 Hits@3 0.02857142857142857 Hits@10 0.09523809523809523 MRR 0.0396506586308547 cur_rank 1195 abs_cur_rank 1476 total_num 104 20466
# 14496
# checkcorrect 9012 9012 real score 1.6368108928203582 Hits@1 0.009433962264150943 Hits@3 0.02830188679245283 Hits@10 0.09433962264150944 MRR 0.03931463598400245 cur_rank 247 abs_cur_rank 358 total_num 105 20466
# 14496
# checkcorrect 2007 2007 real score 1.761657214164734 Hits@1 0.009345794392523364 Hits@3 0.028037383177570093 Hits@10 0.09345794392523364 MRR 0.03901493262725096 cur_rank 137 abs_cur_rank 1048 total_num 106 20466
# 14496
# checkcorrect 10840 10840 real score 1.3171358913183213 Hits@1 0.009259259259259259 Hits@3 0.027777777777777776 Hits@10 0.09259259259259259 MRR 0.03867482311239522 cur_rank 437 abs_cur_rank 439 total_num 107 20466
# 14496
# checkcorrect 2306 2306 real score 1.9586432576179504 Hits@1 0.009174311926605505 Hits@3 0.027522935779816515 Hits@10 0.09174311926605505 MRR 0.038507239077100824 cur_rank 48 abs_cur_rank 60 total_num 108 20466
# 14496
# checkcorrect 12988 12988 real score 0.6366271448321641 Hits@1 0.00909090909090909 Hits@3 0.02727272727272727 Hits@10 0.09090909090909091 MRR 0.03815919661676168 cur_rank 4492 abs_cur_rank 4571 total_num 109 20466
# 14496
# checkcorrect 3244 3244 real score 1.6239855349063874 Hits@1 0.009009009009009009 Hits@3 0.02702702702702703 Hits@10 0.09009009009009009 MRR 0.03791779517303984 cur_rank 87 abs_cur_rank 88 total_num 110 20466
# 14496
# checkcorrect 4972 4972 real score 1.7354136765003205 Hits@1 0.008928571428571428 Hits@3 0.026785714285714284 Hits@10 0.08928571428571429 MRR 0.037613716679182375 cur_rank 258 abs_cur_rank 916 total_num 111 20466
# 14496
# checkcorrect 5020 5020 real score 1.548832967877388 Hits@1 0.008849557522123894 Hits@3 0.02654867256637168 Hits@10 0.08849557522123894 MRR 0.03738141508346958 cur_rank 87 abs_cur_rank 87 total_num 112 20466
# 14496
# checkcorrect 10638 10638 real score 1.7827104449272155 Hits@1 0.008771929824561403 Hits@3 0.02631578947368421 Hits@10 0.08771929824561403 MRR 0.037145844037031014 cur_rank 94 abs_cur_rank 165 total_num 113 20466
# 14496
# checkcorrect 2990 2990 real score 1.6966274976730347 Hits@1 0.008695652173913044 Hits@3 0.02608695652173913 Hits@10 0.08695652173913043 MRR 0.03683073465595633 cur_rank 1100 abs_cur_rank 1132 total_num 114 20466
# 14496
# checkcorrect 12259 12259 real score 0.8749239683151245 Hits@1 0.008620689655172414 Hits@3 0.02586206896551724 Hits@10 0.08620689655172414 MRR 0.036538583292289366 cur_rank 339 abs_cur_rank 1128 total_num 115 20466
# 14496
# checkcorrect 219 219 real score 1.2965896815061568 Hits@1 0.008547008547008548 Hits@3 0.02564102564102564 Hits@10 0.08547008547008547 MRR 0.0362860569991331 cur_rank 142 abs_cur_rank 452 total_num 116 20466
# 14496
# checkcorrect 8457 8457 real score 1.3511690258979798 Hits@1 0.00847457627118644 Hits@3 0.025423728813559324 Hits@10 0.0847457627118644 MRR 0.03598862482661581 cur_rank 840 abs_cur_rank 3458 total_num 117 20466
# 14496
# checkcorrect 4809 4809 real score 1.9323629498481751 Hits@1 0.008403361344537815 Hits@3 0.03361344537815126 Hits@10 0.09243697478991597 MRR 0.038487319856084015 cur_rank 2 abs_cur_rank 6 total_num 118 20466
# 14496
# checkcorrect 10777 10777 real score 1.5678283482789994 Hits@1 0.008333333333333333 Hits@3 0.041666666666666664 Hits@10 0.1 MRR 0.04094436996839443 cur_rank 2 abs_cur_rank 3 total_num 119 20466
# 14496
# checkcorrect 8205 8205 real score 1.8697903871536254 Hits@1 0.008264462809917356 Hits@3 0.04132231404958678 Hits@10 0.10743801652892562 MRR 0.041639044596754805 cur_rank 7 abs_cur_rank 9 total_num 120 20466
# 14496
# checkcorrect 2781 2781 real score 0.9247049733996391 Hits@1 0.00819672131147541 Hits@3 0.040983606557377046 Hits@10 0.10655737704918032 MRR 0.041304399540099505 cur_rank 1230 abs_cur_rank 1230 total_num 121 20466
# 14496
# checkcorrect 10373 10373 real score 1.612452006340027 Hits@1 0.008130081300813009 Hits@3 0.04065040650406504 Hits@10 0.10569105691056911 MRR 0.04104602075947927 cur_rank 104 abs_cur_rank 458 total_num 122 20466
# 14496
# checkcorrect 7587 7587 real score 1.622475701570511 Hits@1 0.008064516129032258 Hits@3 0.04032258064516129 Hits@10 0.11290322580645161 MRR 0.041521456075935076 cur_rank 9 abs_cur_rank 247 total_num 123 20466
# 14496
# checkcorrect 14363 14363 real score 1.8736393332481385 Hits@1 0.008 Hits@3 0.04 Hits@10 0.112 MRR 0.04152261776066093 cur_rank 23 abs_cur_rank 24 total_num 124 20466
# 14496
# checkcorrect 3131 3131 real score 1.8916177451610565 Hits@1 0.007936507936507936 Hits@3 0.03968253968253968 Hits@10 0.1111111111111111 MRR 0.04130179246206033 cur_rank 72 abs_cur_rank 75 total_num 125 20466
# 14496
# checkcorrect 12537 12537 real score 1.5409196615219116 Hits@1 0.007874015748031496 Hits@3 0.03937007874015748 Hits@10 0.11023622047244094 MRR 0.0412915421277134 cur_rank 24 abs_cur_rank 25 total_num 126 20466
# 14496
# checkcorrect 10915 10915 real score 0.8439805388450623 Hits@1 0.0078125 Hits@3 0.0390625 Hits@10 0.109375 MRR 0.04097156483109482 cur_rank 2989 abs_cur_rank 4035 total_num 127 20466
# 14496
# checkcorrect 7964 7964 real score 0.8505736768245697 Hits@1 0.007751937984496124 Hits@3 0.03875968992248062 Hits@10 0.10852713178294573 MRR 0.04074735264458311 cur_rank 82 abs_cur_rank 83 total_num 128 20466
# 14496
# checkcorrect 10356 10356 real score 1.7167907238006592 Hits@1 0.007692307692307693 Hits@3 0.038461538461538464 Hits@10 0.1076923076923077 MRR 0.04060113555066157 cur_rank 45 abs_cur_rank 184 total_num 129 20466
# 14496
# checkcorrect 2 2 real score 1.8995381295681 Hits@1 0.007633587786259542 Hits@3 0.03816793893129771 Hits@10 0.10687022900763359 MRR 0.04060926937597459 cur_rank 23 abs_cur_rank 30 total_num 130 20466
# 14496
# checkcorrect 1751 1751 real score 1.8379240572452544 Hits@1 0.007575757575757576 Hits@3 0.03787878787878788 Hits@10 0.10606060606060606 MRR 0.04074725619442754 cur_rank 16 abs_cur_rank 17 total_num 131 20466
# 14496
# checkcorrect 12399 12399 real score 1.4339060902595522 Hits@1 0.007518796992481203 Hits@3 0.03759398496240601 Hits@10 0.10526315789473684 MRR 0.040450134059883895 cur_rank 812 abs_cur_rank 3084 total_num 132 20466
# 14496
# checkcorrect 3352 3352 real score 1.4709482580423354 Hits@1 0.007462686567164179 Hits@3 0.03731343283582089 Hits@10 0.1044776119402985 MRR 0.04015650434868612 cur_rank 905 abs_cur_rank 917 total_num 133 20466
# 14496
# checkcorrect 4117 4117 real score 1.6016821086406707 Hits@1 0.007407407407407408 Hits@3 0.037037037037037035 Hits@10 0.1037037037037037 MRR 0.03989449090162337 cur_rank 208 abs_cur_rank 241 total_num 134 20466
# 14496
# checkcorrect 8690 8690 real score 1.5573583543300629 Hits@1 0.007352941176470588 Hits@3 0.03676470588235294 Hits@10 0.10294117647058823 MRR 0.03960924700959602 cur_rank 907 abs_cur_rank 958 total_num 135 20466
# 14496
# checkcorrect 9197 9197 real score -0.21507635712623596 Hits@1 0.0072992700729927005 Hits@3 0.0364963503649635 Hits@10 0.10218978102189781 MRR 0.039321100746788226 cur_rank 7506 abs_cur_rank 8055 total_num 136 20466
# 14496
# checkcorrect 436 436 real score 1.8467274725437166 Hits@1 0.007246376811594203 Hits@3 0.036231884057971016 Hits@10 0.10144927536231885 MRR 0.039094136248623096 cur_rank 124 abs_cur_rank 132 total_num 137 20466
# 14496
# checkcorrect 1565 1565 real score 1.4740303695201873 Hits@1 0.007194244604316547 Hits@3 0.03597122302158273 Hits@10 0.10071942446043165 MRR 0.03882618151903221 cur_rank 540 abs_cur_rank 2241 total_num 138 20466
# 14496
# checkcorrect 9257 9257 real score 1.7554826080799102 Hits@1 0.007142857142857143 Hits@3 0.03571428571428571 Hits@10 0.1 MRR 0.0385721182866836 cur_rank 306 abs_cur_rank 364 total_num 139 20466
# 14496
# checkcorrect 11249 11249 real score 1.8384614527225493 Hits@1 0.0070921985815602835 Hits@3 0.03546099290780142 Hits@10 0.09929078014184398 MRR 0.03834815295835965 cur_rank 142 abs_cur_rank 194 total_num 140 20466
# 14496
# checkcorrect 11275 11275 real score 1.975676017999649 Hits@1 0.007042253521126761 Hits@3 0.035211267605633804 Hits@10 0.1056338028169014 MRR 0.039251804463347736 cur_rank 5 abs_cur_rank 19 total_num 141 20466
# 14496
# checkcorrect 7737 7737 real score 1.8475042521953582 Hits@1 0.006993006993006993 Hits@3 0.03496503496503497 Hits@10 0.1048951048951049 MRR 0.039058630355049806 cur_rank 85 abs_cur_rank 97 total_num 142 20466
# 14496
# checkcorrect 213 213 real score 1.5556745290756226 Hits@1 0.006944444444444444 Hits@3 0.034722222222222224 Hits@10 0.10416666666666667 MRR 0.03880090045877744 cur_rank 513 abs_cur_rank 2086 total_num 143 20466
# 14496
# checkcorrect 5469 5469 real score 1.8847985446453095 Hits@1 0.006896551724137931 Hits@3 0.034482758620689655 Hits@10 0.10344827586206896 MRR 0.0388617152667793 cur_rank 20 abs_cur_rank 20 total_num 144 20466
# 14496
# checkcorrect 13842 13842 real score 1.820037066936493 Hits@1 0.0136986301369863 Hits@3 0.0410958904109589 Hits@10 0.1095890410958904 MRR 0.04544485420330821 cur_rank 0 abs_cur_rank 0 total_num 145 20466
# 14496
# checkcorrect 413 413 real score 1.3328611582517624 Hits@1 0.013605442176870748 Hits@3 0.04081632653061224 Hits@10 0.10884353741496598 MRR 0.0451387195897948 cur_rank 2256 abs_cur_rank 2497 total_num 146 20466
# 14496
# checkcorrect 7347 7347 real score 1.6024347364902498 Hits@1 0.013513513513513514 Hits@3 0.04054054054054054 Hits@10 0.10810810810810811 MRR 0.045051688136594346 cur_rank 30 abs_cur_rank 96 total_num 147 20466
# 14496
# checkcorrect 8471 8471 real score 1.4179584309458733 Hits@1 0.013422818791946308 Hits@3 0.040268456375838924 Hits@10 0.10738255033557047 MRR 0.04475911120915091 cur_rank 685 abs_cur_rank 688 total_num 148 20466
# 14496
# checkcorrect 2733 2733 real score 1.9681776642799378 Hits@1 0.02 Hits@3 0.04666666666666667 Hits@10 0.11333333333333333 MRR 0.0511273838010899 cur_rank 0 abs_cur_rank 0 total_num 149 20466
# 14496
# checkcorrect 1739 1739 real score 1.7943923234939576 Hits@1 0.019867549668874173 Hits@3 0.046357615894039736 Hits@10 0.11258278145695365 MRR 0.050972750648617636 cur_rank 35 abs_cur_rank 311 total_num 150 20466
# 14496
# checkcorrect 6523 6523 real score 1.7345814108848572 Hits@1 0.019736842105263157 Hits@3 0.046052631578947366 Hits@10 0.1118421052631579 MRR 0.050652492933703386 cur_rank 435 abs_cur_rank 557 total_num 151 20466
# 14496
# checkcorrect 3813 3813 real score 1.547401574254036 Hits@1 0.0196078431372549 Hits@3 0.0457516339869281 Hits@10 0.1111111111111111 MRR 0.050325440672257714 cur_rank 1629 abs_cur_rank 1824 total_num 152 20466
# 14496
# checkcorrect 7788 7788 real score 1.7139812886714936 Hits@1 0.01948051948051948 Hits@3 0.045454545454545456 Hits@10 0.11038961038961038 MRR 0.050015133077411816 cur_rank 393 abs_cur_rank 413 total_num 153 20466
# 14496
# checkcorrect 982 982 real score 1.5804181903600694 Hits@1 0.01935483870967742 Hits@3 0.04516129032258064 Hits@10 0.10967741935483871 MRR 0.04981192911251573 cur_rank 53 abs_cur_rank 174 total_num 154 20466
# 14496
# checkcorrect 2028 2028 real score 1.7369970202445986 Hits@1 0.019230769230769232 Hits@3 0.04487179487179487 Hits@10 0.10897435897435898 MRR 0.049504762511755625 cur_rank 527 abs_cur_rank 781 total_num 155 20466
# 14496
# checkcorrect 8926 8926 real score 1.7968483507633208 Hits@1 0.01910828025477707 Hits@3 0.044585987261146494 Hits@10 0.11464968152866242 MRR 0.05078180224098011 cur_rank 3 abs_cur_rank 25 total_num 156 20466
# 14496
# checkcorrect 5717 5717 real score 0.5191298931837083 Hits@1 0.0189873417721519 Hits@3 0.04430379746835443 Hits@10 0.11392405063291139 MRR 0.050464692265097706 cur_rank 1473 abs_cur_rank 1794 total_num 157 20466
# 14496
# checkcorrect 10075 10075 real score 0.8769816935062409 Hits@1 0.018867924528301886 Hits@3 0.0440251572327044 Hits@10 0.11320754716981132 MRR 0.05015339855429874 cur_rank 1031 abs_cur_rank 3623 total_num 158 20466
# 14496
# checkcorrect 4425 4425 real score 0.6437965720891953 Hits@1 0.01875 Hits@3 0.04375 Hits@10 0.1125 MRR 0.05008993981333437 cur_rank 24 abs_cur_rank 34 total_num 159 20466
# 14496
# checkcorrect 2137 2137 real score 1.7853183269500732 Hits@1 0.018633540372670808 Hits@3 0.043478260869565216 Hits@10 0.11180124223602485 MRR 0.04983633310181838 cur_rank 107 abs_cur_rank 154 total_num 160 20466
# 14496
# checkcorrect 1045 1045 real score 1.4689353346824645 Hits@1 0.018518518518518517 Hits@3 0.043209876543209874 Hits@10 0.1111111111111111 MRR 0.04953536035829829 cur_rank 926 abs_cur_rank 1017 total_num 161 20466
# 14496
# checkcorrect 2022 2022 real score 1.8878040075302125 Hits@1 0.018404907975460124 Hits@3 0.04294478527607362 Hits@10 0.1165644171779141 MRR 0.05045845630702038 cur_rank 4 abs_cur_rank 5 total_num 162 20466
# 14496
# checkcorrect 8618 8618 real score 1.8677910268306732 Hits@1 0.018292682926829267 Hits@3 0.042682926829268296 Hits@10 0.11585365853658537 MRR 0.05017379245701209 cur_rank 264 abs_cur_rank 305 total_num 163 20466
# 14496
# checkcorrect 10649 10649 real score 0.8772981464862823 Hits@1 0.01818181818181818 Hits@3 0.04242424242424243 Hits@10 0.11515151515151516 MRR 0.04987505803323079 cur_rank 1132 abs_cur_rank 3884 total_num 164 20466
# 14496
# checkcorrect 8540 8540 real score 1.79371035695076 Hits@1 0.018072289156626505 Hits@3 0.04216867469879518 Hits@10 0.1144578313253012 MRR 0.04990927789782311 cur_rank 17 abs_cur_rank 18 total_num 165 20466
# 14496
# checkcorrect 4445 4445 real score 1.5892368614673615 Hits@1 0.017964071856287425 Hits@3 0.041916167664670656 Hits@10 0.11377245508982035 MRR 0.049666910738340043 cur_rank 105 abs_cur_rank 122 total_num 166 20466
# 14496
# checkcorrect 9626 9626 real score 1.3667500019073486 Hits@1 0.017857142857142856 Hits@3 0.041666666666666664 Hits@10 0.1130952380952381 MRR 0.04937412922386751 cur_rank 2084 abs_cur_rank 2962 total_num 167 20466
# 14496
# checkcorrect 2280 2280 real score 1.6544793784618377 Hits@1 0.01775147928994083 Hits@3 0.04142011834319527 Hits@10 0.11242603550295859 MRR 0.049110422496552855 cur_rank 207 abs_cur_rank 241 total_num 168 20466
# 14496
# checkcorrect 10468 10468 real score 1.2873541980981826 Hits@1 0.01764705882352941 Hits@3 0.041176470588235294 Hits@10 0.11176470588235295 MRR 0.04883075764727386 cur_rank 637 abs_cur_rank 638 total_num 169 20466
# 14496
# checkcorrect 362 362 real score 1.9045142590999604 Hits@1 0.017543859649122806 Hits@3 0.04093567251461988 Hits@10 0.1111111111111111 MRR 0.04879945649652702 cur_rank 22 abs_cur_rank 22 total_num 170 20466
# 14496
# checkcorrect 9508 9508 real score 0.8197827901691198 Hits@1 0.01744186046511628 Hits@3 0.040697674418604654 Hits@10 0.11046511627906977 MRR 0.04859027659143392 cur_rank 77 abs_cur_rank 283 total_num 171 20466
# 14496
# checkcorrect 266 266 real score 1.105892178416252 Hits@1 0.017341040462427744 Hits@3 0.04046242774566474 Hits@10 0.10982658959537572 MRR 0.048311174550280445 cur_rank 3271 abs_cur_rank 3282 total_num 172 20466
# 14496
# checkcorrect 286 286 real score 1.7164649724960328 Hits@1 0.017241379310344827 Hits@3 0.040229885057471264 Hits@10 0.10919540229885058 MRR 0.04809532118029058 cur_rank 92 abs_cur_rank 93 total_num 173 20466
# 14496
# checkcorrect 2418 2418 real score 0.7343928456306458 Hits@1 0.017142857142857144 Hits@3 0.04 Hits@10 0.10857142857142857 MRR 0.0478243181584853 cur_rank 1492 abs_cur_rank 4508 total_num 174 20466
# 14496
# checkcorrect 10395 10395 real score 1.906470274925232 Hits@1 0.017045454545454544 Hits@3 0.03977272727272727 Hits@10 0.10795454545454546 MRR 0.04768172130944432 cur_rank 43 abs_cur_rank 45 total_num 175 20466
# 14496
# checkcorrect 3039 3039 real score 1.890272319316864 Hits@1 0.021052631578947368 Hits@3 0.042105263157894736 Hits@10 0.11052631578947368 MRR 0.05132541938626903 cur_rank 0 abs_cur_rank 0 total_num 189 20466
# 14496
# checkcorrect 4941 4941 real score 1.913059449195862 Hits@1 0.020942408376963352 Hits@3 0.041884816753926704 Hits@10 0.11518324607329843 MRR 0.05210382033189065 cur_rank 4 abs_cur_rank 28 total_num 190 20466
# 14496
# checkcorrect 2350 2350 real score 1.6804071009159087 Hits@1 0.020833333333333332 Hits@3 0.041666666666666664 Hits@10 0.11458333333333333 MRR 0.05223308729330308 cur_rank 12 abs_cur_rank 19 total_num 191 20466
# 14496
# checkcorrect 1843 1843 real score 1.7874756544828414 Hits@1 0.02072538860103627 Hits@3 0.04145077720207254 Hits@10 0.11398963730569948 MRR 0.052010424971883164 cur_rank 107 abs_cur_rank 112 total_num 192 20466
# 14496
# checkcorrect 931 931 real score 1.5918031215667723 Hits@1 0.020618556701030927 Hits@3 0.041237113402061855 Hits@10 0.1134020618556701 MRR 0.051749489218878036 cur_rank 719 abs_cur_rank 735 total_num 193 20466
# 14496
# checkcorrect 9968 9968 real score 1.6630877375602722 Hits@1 0.020512820512820513 Hits@3 0.041025641025641026 Hits@10 0.11282051282051282 MRR 0.051510678233910756 cur_rank 192 abs_cur_rank 380 total_num 194 20466
# 14496
# checkcorrect 6620 6620 real score 1.2003212735056876 Hits@1 0.02040816326530612 Hits@3 0.04081632653061224 Hits@10 0.11224489795918367 MRR 0.05129425084032402 cur_rank 109 abs_cur_rank 109 total_num 195 20466
# 14496
# checkcorrect 2766 2766 real score 1.5640615791082382 Hits@1 0.02030456852791878 Hits@3 0.04060913705583756 Hits@10 0.1116751269035533 MRR 0.0510427950961817 cur_rank 568 abs_cur_rank 572 total_num 196 20466
# 14496
# checkcorrect 3713 3713 real score 0.6668659597635269 Hits@1 0.020202020202020204 Hits@3 0.04040404040404041 Hits@10 0.1111111111111111 MRR 0.051121703538456874 cur_rank 14 abs_cur_rank 16 total_num 197 20466
# 14496
# checkcorrect 10818 10818 real score 1.733398550748825 Hits@1 0.020100502512562814 Hits@3 0.04020100502512563 Hits@10 0.11055276381909548 MRR 0.051321640158409815 cur_rank 10 abs_cur_rank 12 total_num 198 20466
# 14496
# checkcorrect 3658 3658 real score 1.8737075626850128 Hits@1 0.02 Hits@3 0.04 Hits@10 0.11 MRR 0.051118223446979465 cur_rank 93 abs_cur_rank 140 total_num 199 20466
# 14496
# checkcorrect 6911 6911 real score 1.8842824041843413 Hits@1 0.01990049751243781 Hits@3 0.03980099502487562 Hits@10 0.11442786069651742 MRR 0.0513614163651537 cur_rank 9 abs_cur_rank 69 total_num 200 20466
# 14496
# checkcorrect 3785 3785 real score 1.1779333353042603 Hits@1 0.019801980198019802 Hits@3 0.039603960396039604 Hits@10 0.11386138613861387 MRR 0.05111835214274657 cur_rank 441 abs_cur_rank 808 total_num 201 20466
# 14496
# checkcorrect 1841 1841 real score 1.6323628067970275 Hits@1 0.019704433497536946 Hits@3 0.03940886699507389 Hits@10 0.11330049261083744 MRR 0.0509178512290713 cur_rank 95 abs_cur_rank 329 total_num 202 20466
# 14496
# checkcorrect 835 835 real score 1.266238847374916 Hits@1 0.0196078431372549 Hits@3 0.0392156862745098 Hits@10 0.11274509803921569 MRR 0.05067155935458294 cur_rank 1482 abs_cur_rank 1487 total_num 203 20466
# 14496
# checkcorrect 3058 3058 real score 1.6953365862369538 Hits@1 0.01951219512195122 Hits@3 0.03902439024390244 Hits@10 0.11219512195121951 MRR 0.05050434902906278 cur_rank 60 abs_cur_rank 63 total_num 204 20466
# 14496
# checkcorrect 4651 4651 real score 1.9013964414596556 Hits@1 0.019417475728155338 Hits@3 0.038834951456310676 Hits@10 0.11165048543689321 MRR 0.050501900732805194 cur_rank 19 abs_cur_rank 19 total_num 205 20466
# 14496
# checkcorrect 1033 1033 real score 1.6141491025686263 Hits@1 0.01932367149758454 Hits@3 0.03864734299516908 Hits@10 0.1111111111111111 MRR 0.05026977068285037 cur_rank 407 abs_cur_rank 505 total_num 206 20466
# 14496
# checkcorrect 6774 6774 real score 1.836655056476593 Hits@1 0.019230769230769232 Hits@3 0.038461538461538464 Hits@10 0.11538461538461539 MRR 0.050629050631490514 cur_rank 7 abs_cur_rank 7 total_num 207 20466
# 14496
# checkcorrect 6194 6194 real score 1.8182243287563324 Hits@1 0.019138755980861243 Hits@3 0.03827751196172249 Hits@10 0.11483253588516747 MRR 0.050668258663932014 cur_rank 16 abs_cur_rank 16 total_num 208 20466
# 14496
# checkcorrect 3319 3319 real score 0.7737477660179138 Hits@1 0.01904761904761905 Hits@3 0.0380952380952381 Hits@10 0.11428571428571428 MRR 0.05042848341988115 cur_rank 3169 abs_cur_rank 3170 total_num 209 20466
# 14496
# checkcorrect 8422 8422 real score 1.8880826532840729 Hits@1 0.023696682464454975 Hits@3 0.04265402843601896 Hits@10 0.11848341232227488 MRR 0.05492882236101915 cur_rank 0 abs_cur_rank 2 total_num 210 20466
# 14496
# checkcorrect 1313 1313 real score 1.9010804176330565 Hits@1 0.02358490566037736 Hits@3 0.04716981132075472 Hits@10 0.12264150943396226 MRR 0.056242051186360255 cur_rank 2 abs_cur_rank 2 total_num 211 20466
# 14496
# checkcorrect 339 339 real score 1.6973224401474 Hits@1 0.028169014084507043 Hits@3 0.051643192488262914 Hits@10 0.1267605633802817 MRR 0.06067283967844307 cur_rank 0 abs_cur_rank 0 total_num 212 20466
# 14496
# checkcorrect 10230 10230 real score 1.2708400249481202 Hits@1 0.028037383177570093 Hits@3 0.0514018691588785 Hits@10 0.1261682242990654 MRR 0.06039134113843888 cur_rank 2313 abs_cur_rank 2316 total_num 213 20466
# 14496
# checkcorrect 3456 3456 real score 1.7130492210388184 Hits@1 0.027906976744186046 Hits@3 0.05116279069767442 Hits@10 0.13023255813953488 MRR 0.06077490300689796 cur_rank 6 abs_cur_rank 6 total_num 214 20466
# 14496
# checkcorrect 6818 6818 real score 1.4984987676143646 Hits@1 0.027777777777777776 Hits@3 0.05092592592592592 Hits@10 0.12962962962962962 MRR 0.06051282783865615 cur_rank 239 abs_cur_rank 343 total_num 215 20466
# 14496
# checkcorrect 5540 5540 real score 1.6137070804834366 Hits@1 0.027649769585253458 Hits@3 0.05069124423963134 Hits@10 0.1336405529953917 MRR 0.06081000374723377 cur_rank 7 abs_cur_rank 7 total_num 216 20466
# 14496
# checkcorrect 503 503 real score 1.6846965849399567 Hits@1 0.027522935779816515 Hits@3 0.05045871559633028 Hits@10 0.13302752293577982 MRR 0.06055742174122253 cur_rank 173 abs_cur_rank 192 total_num 217 20466
# 14496
# checkcorrect 12604 12604 real score 1.3460720211267472 Hits@1 0.0273972602739726 Hits@3 0.0502283105022831 Hits@10 0.1324200913242009 MRR 0.060289313060331785 cur_rank 542 abs_cur_rank 1762 total_num 218 20466
# 14496
# checkcorrect 5696 5696 real score 0.880960100889206 Hits@1 0.02727272727272727 Hits@3 0.05 Hits@10 0.1318181818181818 MRR 0.060017422932096116 cur_rank 2111 abs_cur_rank 2217 total_num 219 20466
# 14496
# checkcorrect 4430 4430 real score 1.5684367716312408 Hits@1 0.027149321266968326 Hits@3 0.049773755656108594 Hits@10 0.13122171945701358 MRR 0.059757573387494455 cur_rank 385 abs_cur_rank 1609 total_num 220 20466
# 14496
# checkcorrect 3422 3422 real score 1.8471759974956514 Hits@1 0.02702702702702703 Hits@3 0.04954954954954955 Hits@10 0.13063063063063063 MRR 0.059629160894758 cur_rank 31 abs_cur_rank 38 total_num 221 20466
# 14496
# checkcorrect 605 605 real score 1.595723807811737 Hits@1 0.026905829596412557 Hits@3 0.04932735426008968 Hits@10 0.13004484304932734 MRR 0.05943409305333784 cur_rank 61 abs_cur_rank 241 total_num 222 20466
# 14496
# checkcorrect 538 538 real score 1.7994134804233908 Hits@1 0.026785714285714284 Hits@3 0.049107142857142856 Hits@10 0.12946428571428573 MRR 0.05919998106199708 cur_rank 142 abs_cur_rank 188 total_num 223 20466
# 14496
# checkcorrect 6197 6197 real score 1.672224760055542 Hits@1 0.02666666666666667 Hits@3 0.04888888888888889 Hits@10 0.1288888888888889 MRR 0.05894708714872026 cur_rank 434 abs_cur_rank 478 total_num 224 20466
# 14496
# checkcorrect 3545 3545 real score 1.2495263904333114 Hits@1 0.02654867256637168 Hits@3 0.048672566371681415 Hits@10 0.12831858407079647 MRR 0.05869098665721431 cur_rank 935 abs_cur_rank 3075 total_num 225 20466
# 14496
# checkcorrect 441 441 real score 1.8001155853271484 Hits@1 0.02643171806167401 Hits@3 0.048458149779735685 Hits@10 0.1277533039647577 MRR 0.058503489060742285 cur_rank 61 abs_cur_rank 125 total_num 226 20466
# 14496
# checkcorrect 3989 3989 real score 1.9139463126659393 Hits@1 0.02631578947368421 Hits@3 0.04824561403508772 Hits@10 0.13157894736842105 MRR 0.05873422424517372 cur_rank 8 abs_cur_rank 43 total_num 227 20466
# 14496
# checkcorrect 4313 4313 real score 1.5672779470682143 Hits@1 0.026200873362445413 Hits@3 0.048034934497816595 Hits@10 0.13100436681222707 MRR 0.05850724840461295 cur_rank 147 abs_cur_rank 519 total_num 228 20466
# 14496
# checkcorrect 4526 4526 real score 1.8748972594738007 Hits@1 0.02608695652173913 Hits@3 0.04782608695652174 Hits@10 0.13043478260869565 MRR 0.0582959168467625 cur_rank 100 abs_cur_rank 104 total_num 229 20466
# 14496
# checkcorrect 11159 11159 real score 1.4613745093345643 Hits@1 0.025974025974025976 Hits@3 0.047619047619047616 Hits@10 0.12987012987012986 MRR 0.05804739815680742 cur_rank 1125 abs_cur_rank 1132 total_num 230 20466
# 14496
# ...
# 14496
# checkcorrect 2227 2227 real score 1.7701385140419008 Hits@1 0.027083333333333334 Hits@3 0.05416666666666667 Hits@10 0.12916666666666668 MRR 0.06203396610888972 cur_rank 65 abs_cur_rank 286 total_num 479 20466
# 14496
# checkcorrect 663 663 real score 1.7576316952705384 Hits@1 0.02702702702702703 Hits@3 0.05405405405405406 Hits@10 0.13097713097713098 MRR 0.06242474788413112 cur_rank 3 abs_cur_rank 3 total_num 480 20466
# 14496
# checkcorrect 2085 2085 real score 1.9828518152236938 Hits@1 0.026970954356846474 Hits@3 0.05394190871369295 Hits@10 0.13070539419087138 MRR 0.062433548545505674 cur_rank 14 abs_cur_rank 18 total_num 481 20466
# 14496
# checkcorrect 10837 10837 real score 1.541266793012619 Hits@1 0.026915113871635612 Hits@3 0.053830227743271224 Hits@10 0.13043478260869565 MRR 0.062307874743657905 cur_rank 576 abs_cur_rank 628 total_num 482 20466
# 14496
# checkcorrect 5852 5852 real score 1.565218161046505 Hits@1 0.026859504132231406 Hits@3 0.05371900826446281 Hits@10 0.13016528925619836 MRR 0.062185180739245775 cur_rank 341 abs_cur_rank 424 total_num 483 20466
# 14496
# checkcorrect 1216 1216 real score 1.882312077283859 Hits@1 0.026804123711340205 Hits@3 0.05360824742268041 Hits@10 0.12989690721649486 MRR 0.06209191057801511 cur_rank 58 abs_cur_rank 75 total_num 484 20466
# 14496
# checkcorrect 12090 12090 real score 0.9164936423301697 Hits@1 0.026748971193415638 Hits@3 0.053497942386831275 Hits@10 0.12962962962962962 MRR 0.06196700724120621 cur_rank 719 abs_cur_rank 1199 total_num 485 20466
# 14496
# checkcorrect 2733 2733 real score 1.926894563436508 Hits@1 0.028747433264887063 Hits@3 0.055441478439425054 Hits@10 0.13141683778234087 MRR 0.06389315301689162 cur_rank 0 abs_cur_rank 0 total_num 486 20466
# 14496
# checkcorrect 71 71 real score 1.7731026887893675 Hits@1 0.028688524590163935 Hits@3 0.055327868852459015 Hits@10 0.13319672131147542 MRR 0.06417206049021766 cur_rank 4 abs_cur_rank 4 total_num 487 20466
# 14496
# checkcorrect 8934 8934 real score 1.7417903661727905 Hits@1 0.028629856850715747 Hits@3 0.05521472392638037 Hits@10 0.1329243353783231 MRR 0.06404460930073969 cur_rank 540 abs_cur_rank 580 total_num 488 20466
# 14496
# checkcorrect 1786 1786 real score 1.7498637795448304 Hits@1 0.02857142857142857 Hits@3 0.05510204081632653 Hits@10 0.1326530612244898 MRR 0.06391582768907632 cur_rank 1061 abs_cur_rank 1163 total_num 489 20466
# 14496
# checkcorrect 2139 2139 real score 1.7100912898778915 Hits@1 0.028513238289205704 Hits@3 0.054989816700611 Hits@10 0.13238289205702647 MRR 0.06379503841665636 cur_rank 216 abs_cur_rank 263 total_num 490 20466
# 14496
# checkcorrect 8912 8912 real score 1.6347953736782075 Hits@1 0.028455284552845527 Hits@3 0.054878048780487805 Hits@10 0.13211382113821138 MRR 0.06366760479150224 cur_rank 910 abs_cur_rank 990 total_num 491 20466
# 14496
# checkcorrect 69 69 real score 1.5094656944274902 Hits@1 0.028397565922920892 Hits@3 0.05476673427991886 Hits@10 0.13184584178498987 MRR 0.06355508778647176 cur_rank 121 abs_cur_rank 121 total_num 492 20466
# 14496
# checkcorrect 4990 4990 real score 1.842429518699646 Hits@1 0.02834008097165992 Hits@3 0.05465587044534413 Hits@10 0.13157894736842105 MRR 0.06345710484591517 cur_rank 65 abs_cur_rank 67 total_num 493 20466
# 14496
# checkcorrect 1558 1558 real score 1.814444011449814 Hits@1 0.028282828282828285 Hits@3 0.05454545454545454 Hits@10 0.13131313131313133 MRR 0.0634037309715538 cur_rank 26 abs_cur_rank 26 total_num 494 20466
# 14496
# checkcorrect 11136 11136 real score 1.6584773123264314 Hits@1 0.028225806451612902 Hits@3 0.05443548387096774 Hits@10 0.1310483870967742 MRR 0.063302084362714 cur_rank 76 abs_cur_rank 420 total_num 495 20466
# 14496
# checkcorrect 1483 1483 real score 1.9868120014667512 Hits@1 0.028169014084507043 Hits@3 0.05432595573440644 Hits@10 0.13078470824949698 MRR 0.06335763165958799 cur_rank 10 abs_cur_rank 14 total_num 496 20466
# 14496
# checkcorrect 807 807 real score 1.7756847798824311 Hits@1 0.028112449799196786 Hits@3 0.05421686746987952 Hits@10 0.13052208835341367 MRR 0.06329125695806881 cur_rank 32 abs_cur_rank 33 total_num 497 20466
# 14496
# checkcorrect 585 585 real score 1.7716552674770356 Hits@1 0.028056112224448898 Hits@3 0.05410821643286573 Hits@10 0.13026052104208416 MRR 0.0631773498557545 cur_rank 154 abs_cur_rank 162 total_num 498 20466
# 14496
# checkcorrect 9495 9495 real score 1.668787068128586 Hits@1 0.028 Hits@3 0.054 Hits@10 0.13 MRR 0.06305500317207505 cur_rank 498 abs_cur_rank 1338 total_num 499 20466
# 14496
# checkcorrect 532 532 real score 1.572131645679474 Hits@1 0.027944111776447105 Hits@3 0.05389221556886228 Hits@10 0.12974051896207583 MRR 0.0629403584103106 cur_rank 177 abs_cur_rank 842 total_num 500 20466
# 14496
# checkcorrect 8863 8863 real score 1.6890004634857179 Hits@1 0.027888446215139442 Hits@3 0.053784860557768925 Hits@10 0.1294820717131474 MRR 0.06281833845459447 cur_rank 592 abs_cur_rank 594 total_num 501 20466
# 14496
# checkcorrect 1658 1658 real score 1.8820819914340974 Hits@1 0.027833001988071572 Hits@3 0.0536779324055666 Hits@10 0.12922465208747516 MRR 0.06275192379505429 cur_rank 33 abs_cur_rank 33 total_num 502 20466
# 14496
# checkcorrect 2971 2971 real score 1.7755299847573043 Hits@1 0.027777777777777776 Hits@3 0.05357142857142857 Hits@10 0.12896825396825398 MRR 0.06263958856793148 cur_rank 162 abs_cur_rank 286 total_num 503 20466
# 14496
# checkcorrect 10298 10298 real score 0.8860576391220093 Hits@1 0.027722772277227723 Hits@3 0.053465346534653464 Hits@10 0.12871287128712872 MRR 0.06254061557640705 cur_rank 78 abs_cur_rank 78 total_num 504 20466
# 14496
# checkcorrect 5863 5863 real score 1.875363901257515 Hits@1 0.02766798418972332 Hits@3 0.0533596837944664 Hits@10 0.12845849802371542 MRR 0.06243113384037237 cur_rank 139 abs_cur_rank 176 total_num 505 20466
# 14496
# checkcorrect 1505 1505 real score 1.967299336194992 Hits@1 0.027613412228796843 Hits@3 0.05325443786982249 Hits@10 0.1282051282051282 MRR 0.06241757254198023 cur_rank 17 abs_cur_rank 28 total_num 506 20466
# 14496
# checkcorrect 10657 10657 real score 0.753061842918396 Hits@1 0.027559055118110236 Hits@3 0.0531496062992126 Hits@10 0.1279527559055118 MRR 0.0622960915303184 cur_rank 1417 abs_cur_rank 4387 total_num 507 20466
# 14496
# checkcorrect 10528 10528 real score 1.769784677773714 Hits@1 0.0275049115913556 Hits@3 0.05304518664047151 Hits@10 0.12770137524557956 MRR 0.062225403314097115 cur_rank 37 abs_cur_rank 575 total_num 508 20466
# 14496
# checkcorrect 7886 7886 real score 1.7375894248485566 Hits@1 0.027450980392156862 Hits@3 0.052941176470588235 Hits@10 0.12745098039215685 MRR 0.062111955096279425 cur_rank 228 abs_cur_rank 267 total_num 509 20466
# 14496
# checkcorrect 6654 6654 real score 1.5783430971205235 Hits@1 0.0273972602739726 Hits@3 0.05283757338551859 Hits@10 0.12720156555772993 MRR 0.062022486383024385 cur_rank 60 abs_cur_rank 114 total_num 510 20466
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_11771/566845177.py in <module>
#      19
#      20     #first run the path-based scoring
# ---> 21     score_dict_path = path_based_entity_scoring(t_true, r_true_inv, 1, 10, one_hop, model)
#      22
#      23     #then run the subgraph scoring
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_11771/868037427.py in path_based_entity_scoring(s, r, lower_bd, upper_bd, one_hop, model)
#      50     input_r = np.array(list_r)
#      51
# ---> 52     pred = model.predict([input_1, input_2, input_3, input_r], verbose = 0)
#      53
#      54     #add to score dict using list_m as indication on which entity t it is
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2031           for step in data_handler.steps():
#    2032             callbacks.on_predict_batch_begin(step)
# -> 2033             tmp_batch_outputs = self.predict_function(iterator)
#    2034             if data_handler.should_sync:
#    2035               context.async_wait()
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2450     with self._lock:
#    2451       (graph_function,
# -> 2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2687           f"hashable.  Original error: {e}.")
#    2688
# -> 2689     graph_function = self._function_cache.lookup(cache_key, True)
#    2690     if graph_function is not None:
#    2691       return graph_function, filtered_flat_args
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/core/function/polymorphism/function_cache.py in lookup(self, key, use_function_subtyping)
#     119     dispatch_key = self._dispatch_table.dispatch(key)
#     120     if dispatch_key is not None:
# --> 121       return self._primary[dispatch_key]
#     122
#     123     return None
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/core/function/polymorphism/function_cache.py in __eq__(self, other)
#      84
#      85     return (self.call_context == other.call_context and
# ---> 86             self.function_signature == other.function_signature)
#      87
#      88   def __repr__(self) -> str:
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/core/function/trace_type/default_types.py in __eq__(self, other)
#     131       return False
#     132
# --> 133     return self.components == other.components
#     134
#     135   def __hash__(self) -> int:
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/core/function/trace_type/default_types.py in __eq__(self, other)
#     131       return False
#     132
# --> 133     return self.components == other.components
#     134
#     135   def __hash__(self) -> int:
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/core/function/trace_type/default_types.py in __eq__(self, other)
#     330     return isinstance(
#     331         other, Reference
# --> 332     ) and self.identifier == other.identifier and self.base == other.base
#     333
#     334   def __hash__(self) -> int:
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in __eq__(self, other)
#     439     # pylint: disable=protected-access
#     440     return (type(other) is type(self) and
# --> 441             self.__get_cmp_key() == other.__get_cmp_key())
#     442
#     443   def __ne__(self, other) -> bool:
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in __get_cmp_key(self)
#     497     """Returns a hashable eq-comparable key for `self`."""
#     498     # TODO(b/133606651): Decide whether to cache this value.
# --> 499     return (type(self), self.__make_cmp_key(self._serialize()))
#     500
#     501   def __make_cmp_key(self, value):
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in __make_cmp_key(self, value)
#     515       ])
#     516     if isinstance(value, tuple):
# --> 517       return tuple([self.__make_cmp_key(v) for v in value])
#     518     if isinstance(value, list):
#     519       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in <listcomp>(.0)
#     515       ])
#     516     if isinstance(value, tuple):
# --> 517       return tuple([self.__make_cmp_key(v) for v in value])
#     518     if isinstance(value, list):
#     519       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in __make_cmp_key(self, value)
#     515       ])
#     516     if isinstance(value, tuple):
# --> 517       return tuple([self.__make_cmp_key(v) for v in value])
#     518     if isinstance(value, list):
#     519       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in <listcomp>(.0)
#     515       ])
#     516     if isinstance(value, tuple):
# --> 517       return tuple([self.__make_cmp_key(v) for v in value])
#     518     if isinstance(value, list):
#     519       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in __make_cmp_key(self, value)
#     515       ])
#     516     if isinstance(value, tuple):
# --> 517       return tuple([self.__make_cmp_key(v) for v in value])
#     518     if isinstance(value, list):
#     519       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in <listcomp>(.0)
#     515       ])
#     516     if isinstance(value, tuple):
# --> 517       return tuple([self.__make_cmp_key(v) for v in value])
#     518     if isinstance(value, list):
#     519       return (list, tuple([self.__make_cmp_key(v) for v in value]))
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/site-packages/tensorflow/python/framework/type_spec.py in __make_cmp_key(self, value)
#     501   def __make_cmp_key(self, value):
#     502     """Converts `value` to a hashable key."""
# --> 503     if isinstance(value, (int, float, bool, np.generic, dtypes.DType, TypeSpec,
#     504                           tensor_shape.TensorShape)):
#     505       return value
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/abc.py in __instancecheck__(cls, instance)
#      94             return _abc_register(cls, subclass)
#      95
# ---> 96         def __instancecheck__(cls, instance):
#      97             """Override for isinstance(instance, cls)."""
#      98             return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
############################################
####target entity prediction################

#we select all the triples in the inductive test set
selected = list(data_test)

###Hit at 1#############################
#generate the negative samples by randomly replace relation with all the other relaiton
Hits_at_1 = 0
Hits_at_3 = 0
Hits_at_10 = 0
MRR_raw = 0.

for i in range(len(selected)):
    
    s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
        
    #first run the path-based scoring
    score_dict_path = path_based_entity_scoring(s_true, r_true, 1, 10, one_hop, model)
    
    #then run the subgraph scoring
    score_dict_subg = subgraph_target_scoring(s_true, r_true, 1, 3, one_hop, Dict_train, id2entity, model_2)
    
    #final score dict
    score_dict = defaultdict(float)
    
    for t in score_dict_path:
        score_dict[t] += score_dict_path[t]
    for t in score_dict_subg:
        score_dict[t] += score_dict_subg[t]
    
    #[... [score, r], ...]
    temp_list = list()
    
    for e in id2entity:

        if e in score_dict:

            temp_list.append([score_dict[e], e])

        else:

            temp_list.append([0.0, e])

    sorted_list = sorted(temp_list, key = lambda x: x[0], reverse=True)
    
    p = 0
    exist_tri = 0
    
    while p < len(sorted_list) and sorted_list[p][1] != t_true:
        
        #moreover, we want to remove existing triples
        if ((s_true, r_true, sorted_list[p][1]) in data_test) or (
            (s_true, r_true, sorted_list[p][1]) in data_valid) or (
            (s_true, r_true, sorted_list[p][1]) in data):
            
            exist_tri += 1
            
        p += 1
    
    if p - exist_tri == 0:
        
        Hits_at_1 += 1
        
    if p - exist_tri < 3:
        
        Hits_at_3 += 1
        
    if p - exist_tri < 10:
        
        Hits_at_10 += 1
        
    MRR_raw += 1./float(p - exist_tri + 1.) 
        
    print('checkcorrect', t_true, sorted_list[p][1],
          'real score', sorted_list[p][0],
          'Hits@1', Hits_at_1/(i+1),
          'Hits@3', Hits_at_3/(i+1),
          'Hits@10', Hits_at_10/(i+1),
          'MRR', MRR_raw/(i+1),
          'cur_rank', p - exist_tri,
          'abs_cur_rank', p,
          'total_num', i, len(selected))
