# %%
data_name = 'nell_v4'
model_id = 'main_7'

# %%
#difine the names for saving
model_name = 'Model_' + model_id + '_' + data_name
ids_name = 'IDs_' + model_id + '_' + data_name

# %%
import librosa
import opensmile
import os
import sys
import numpy as np
import random
from collections import defaultdict
from copy import deepcopy
from sklearn.utils import shuffle
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras import initializers
from tensorflow.keras.utils import plot_model

# %%
class LoadKG:
    
    def __init__(self):
        
        self.x = 'Hello'
        
    def load_train_data(self, data_path, one_hop, data, s_t_r, entity2id, id2entity,
                     relation2id, id2relation):
        
        data_ = set()
    
        ####load the train, valid and test set##########
        with open (data_path, 'r') as f:
            
            data_ini = f.readlines()
                        
            for i in range(len(data_ini)):
            
                x = data_ini[i].split()
                
                x_ = tuple(x)
                
                data_.add(x_)
        
        ####relation dict#################
        index = len(relation2id)
     
        for key in data_:
            
            if key[1] not in relation2id:
                
                relation = key[1]
                
                relation2id[relation] = index
                
                id2relation[index] = relation
                
                index += 1
                
                #the inverse relation
                iv_r = '_inverse_' + relation
                
                relation2id[iv_r] = index
                
                id2relation[index] = iv_r
                
                index += 1
        
        #get the id of the inverse relation, by above definition, initial relation has 
        #always even id, while inverse relation has always odd id.
        def inverse_r(r):
            
            if r % 2 == 0: #initial relation
                
                iv_r = r + 1
            
            else: #inverse relation
                
                iv_r = r - 1
            
            return(iv_r)
        
        ####entity dict###################
        index = len(entity2id)
        
        for key in data_:
            
            source, target = key[0], key[2]
            
            if source not in entity2id:
                                
                entity2id[source] = index
                
                id2entity[index] = source
                
                index += 1
            
            if target not in entity2id:
                
                entity2id[target] = index
                
                id2entity[index] = target
                
                index += 1
                
        #create the set of triples using id instead of string        
        for ele in data_:
            
            s = entity2id[ele[0]]
            
            r = relation2id[ele[1]]
            
            t = entity2id[ele[2]]
            
            if (s,r,t) not in data:
                
                data.add((s,r,t))
            
            s_t_r[(s,t)].add(r)
            
            if s not in one_hop:
                
                one_hop[s] = dict()
            
            if r not in one_hop[s]:
                
                one_hop[s][r] = set()
            
            one_hop[s][r].add(t)
            
            if t not in one_hop:
                
                one_hop[t] = dict()
            
            r_inv = inverse_r(r)
            
            s_t_r[(t,s)].add(r_inv)
            
            if r_inv not in one_hop[t]:
                
                one_hop[t][r_inv] = set()
            
            one_hop[t][r_inv].add(s)

# %%
class ObtainPathsByDynamicProgramming:

    def __init__(self, size_bd=50, threshold=100000):
                
        self.size_bd = size_bd
        
        self.threshold = threshold
    
    '''
    Given an entity s, here is the function to find:
      1. any else entity t that is directely connected to s
      2. most of the paths from s to each t with length L
    
    One may refer to LeetCode Problem 797 for details:
        https://leetcode.com/problems/all-paths-from-source-to-target/
    '''
    def obtain_paths(self, mode, s, t_input, lower_bd, upper_bd, one_hop):

        if type(lower_bd) != type(1) or lower_bd < 1:
            
            raise TypeError("!!! invalid lower bound setting, must >= 1 !!!")
            
        if type(upper_bd) != type(1) or upper_bd < 1:
            
            raise TypeError("!!! invalid upper bound setting, must >= 1 !!!")
            
        if lower_bd > upper_bd:
            
            raise TypeError("!!! lower bound must not exced upper bound !!!")
            
        if s not in one_hop:
            
            raise ValueError('!!! entity not in one_hop. Please work on active entities for validation')
        
        #here is the result dict. Its key is each entity t that is directly connected to s
        #The value of each t is a set containing the paths from s to t
        #These paths can be either the direct connection r, or a multi-hop path
        res = defaultdict(set)
        
        #direct_nb contains all the direct neighbour of s
        direct_nb = set()
        
        if mode == 'direct_neighbour':
        
            for r in one_hop[s]:
            
                for t in one_hop[s][r]:
                
                    direct_nb.add(t)
                    
        elif mode == 'target_specified':
            
            direct_nb.add(t_input)
            
        elif mode == 'any_target':
            
            for s_any in one_hop:
                
                direct_nb.add(s_any)
                
        else:
            
            raise ValueError('not a valid mode')
        
        '''
        We use recursion to find the paths
        On current node with the path [r1, ..., rk] and on-path entities {e1, ..., ek-1, node}
        from s to this node, we further find the direct neighbor t' of this node. 
        If t' is not a on-path entity (not among e1,...ek-1), we recursively proceed to t' 
        '''
        def helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict):
            
            #when the current path is within lower_bd and upper_bd and its corresponding
            #length still within the size_bd and its tail node is within the note dict, 
            #we will then intend to add this path
            if (len(path) >= lower_bd) and (len(path) <= upper_bd) and (
                node in direct_nb) and (length_dict[len(path)] < self.size_bd):
                
                #if this path already exists between the source entity and the current target node,
                #we will not count it.
                #here is an interesting situation: this path may exist between s and some other node t,
                #however, it does not exist between s and this node t. Then, we still count it: length_dict[len(path)] += 1
                #That is, each path may be counted for multiple times.
                #We count how many paths we "actually" found between entity pairs
                #Same type of path between different entity pairs are count separately.
                if tuple(path) not in res[node]:
                
                    res[node].add(tuple(path))
                
                    length_dict[len(path)] += 1
                
            #For some rare entities, we may face such a case: so many paths are evaluated,
            #but no entities on the paths are direct neighbors of the rare entity.
            #In this case, the recursion cannot be bounded and stoped by the size threshold.
            #In order to cure this, we count how many times the recursion happens on a specific length, using the count_dict.
            #Its key is length, value counts the recursion occurred to that length. 
            #The recursion is forced to stop for that length (and hence for longer lengths) once reach the threshold.
            if (len(path) < upper_bd) and (length_dict[len(path) + 1] < self.size_bd) and (
                count_dict[len(path)] <= self.threshold):
                
                #we randomly shuffle relation r so that the reading in order is not fixed
                temp_list = list()
                
                for r in one_hop[node]:
                    
                    temp_list.append(r)
                
                for i_0 in range(len(temp_list)):
                    
                    if count_dict[len(path)] > self.threshold:
                        break
                    
                    r = random.choice(temp_list)
                    
                    for i_1 in range(len(one_hop[node][r])):
                        
                        if count_dict[len(path)] > self.threshold:
                            break
                        
                        t = random.choice(list(one_hop[node][r]))
                        
                        if t not in on_path_en:
                                
                            count_dict[len(path)] += 1

                            helper(t, path + [r], on_path_en.union({t}), res, direct_nb, 
                                   lower_bd, upper_bd, one_hop, length_dict, count_dict)
        
        length_dict = defaultdict(int)
        count_dict = defaultdict(int)
        
        helper(s, [], {s}, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
        
        return(res, length_dict)

# %%
train_path = '../data/' + data_name + '/train.txt'

# %%
#load the classes
Class_1 = LoadKG()
Class_2 = ObtainPathsByDynamicProgramming()

# %%
#define the dictionaries and sets for load KG
one_hop = dict() 
data = set()
s_t_r = defaultdict(set)
entity2id = dict()
id2entity = dict()
relation2id = dict()
id2relation = dict()

#fill in the sets and dicts
Class_1.load_train_data(train_path, one_hop, data, s_t_r,
                        entity2id, id2entity, relation2id, id2relation)

# %% [markdown]
# ### Build the deep neural network structure
#
# We use biLSTM to train on the input path embedding sequence to predict the output embedding or the relation.

# %%
# Input layer, using integer to represent each relation type
#note that inputs_path is the path inputs, while inputs_out_re is the output relation inputs
fst_path = keras.Input(shape=(None,), dtype="int32")
scd_path = keras.Input(shape=(None,), dtype="int32")
thd_path = keras.Input(shape=(None,), dtype="int32")

#the relation input layer (for output embedding)
id_rela = keras.Input(shape=(None,), dtype="int32")

# Embed each integer in a 300-dimensional vector as input,
# note that we add another "space holder" embedding, 
# which hold the spaces if the initial length of two paths are not the same
in_embd_var = layers.Embedding(len(relation2id)+1, 300)

# Obtain the embedding
fst_p_embd = in_embd_var(fst_path)
scd_p_embd = in_embd_var(scd_path)
thd_p_embd = in_embd_var(thd_path)

# Embed each integer in a 300-dimensional vector as output
rela_embd = layers.Embedding(len(relation2id)+1, 300)(id_rela)

#add 2 layer bi-directional LSTM
lstm_layer_1 = layers.Bidirectional(layers.LSTM(150, return_sequences=True))
lstm_layer_2 = layers.Bidirectional(layers.LSTM(150, return_sequences=True))

#first LSTM layer
fst_lstm_mid = lstm_layer_1(fst_p_embd)
scd_lstm_mid = lstm_layer_1(scd_p_embd)
thd_lstm_mid = lstm_layer_1(thd_p_embd)

#second LSTM layer
fst_lstm_out = lstm_layer_2(fst_lstm_mid)
scd_lstm_out = lstm_layer_2(scd_lstm_mid)
thd_lstm_out = lstm_layer_2(thd_lstm_mid)

#reduce max
fst_reduce_max = tf.reduce_sum(fst_lstm_out, axis=1)
scd_reduce_max = tf.reduce_sum(scd_lstm_out, axis=1)
thd_reduce_max = tf.reduce_sum(thd_lstm_out, axis=1)

#concatenate the output vector from both siamese tunnel: (Batch, 900)
path_concat = layers.concatenate([fst_reduce_max, scd_reduce_max, thd_reduce_max], axis=-1)

#multiply into output embd size by dense layer: (Batch, 300)
path_out_vect = layers.Dense(300, activation='tanh')(path_concat)

#remove the time dimension from the output embd since there is only one step
rela_out_embd = tf.reduce_sum(rela_embd, axis=1)

# Normalize the vectors to have unit length
path_out_vect_norm = tf.math.l2_normalize(path_out_vect, axis=-1)
rela_out_embd_norm = tf.math.l2_normalize(rela_out_embd, axis=-1)

# Calculate the dot product
dot_product = layers.Dot(axes=-1)([path_out_vect_norm, rela_out_embd_norm])

#put together the model
model = keras.Model([fst_path, scd_path, thd_path, id_rela], dot_product)
# Out:
# 2023-01-24 23:18:26.087583: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#config the Adam optimizer 
opt = keras.optimizers.Adam(learning_rate=0.0005, decay=1e-6)

#compile the model
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['binary_accuracy'])

# %% [markdown]
# ### Build the batches
# We build each big-batch for each path combination with length (i,j). Then, we iteratively train the siamese network on different big-batches. The length of each big-batch is N.
#
# To be specific:
# * If we allow the length difference between two paths in a combination to be d, then the combination with path length i and path length j, denoted as (i,j), will be like (2,2), (2,3), (2,4), (3,3), (3,4), (3,5), ...
# * We will first build all the big-batches before fitting the NN model.
# * That is, we will perform the ObtainPathsByDynamicProgramming class function for some randomly chosen source entities. Then, for each target entity, we will further have two for loops:
# * for path_1 in all the
# * Do this until all the slots in all big-batchs are filled.
# * In every epoch, big-batchs will be re-filled.
#
# Then, in the training, we will use negative sampling: In each batch (actual batch, not the big-batch), we will include K true output relation embeddings and K random selected output relation embeddings. The true label is [1,0], while the false label is [0,1].

# %%
#function to build all the big batches
def build_big_batches(holder_len, lower_bd, upper_bd, Class_2, one_hop, s_t_r,
                      x_p_list, x_r_list, y_list,
                      relation2id, entity2id, id2relation, id2entity):
    
    if holder_len % 10 != 0:
        raise ValueError('We would like to take 10X as a big-batch size')
    
    #the set of all relation IDs
    relation_id_set = set()
    for i in range(len(id2relation)):
        
        if i not in id2relation:
            raise ValueError('error when generaing id2relation')
        
        relation_id_set.add(i)
    
    num_r = len(id2relation)
    
    #count how many appending has performed
    count = 0

    #in case not all entities in entity2id are in one_hop, 
    #so we need to find out who are indeed in
    existing_ids = set()
    
    for s_1 in one_hop:
        existing_ids.add(s_1)
        
    existing_ids = list(existing_ids)
    
    carry_on = True
    
    while carry_on:

        #obtain paths by dynamic programming
        source_id = random.choice(existing_ids)

        result, length_dict = Class_2.obtain_paths('direct_neighbour', source_id, 
                                                   'not_specified', lower_bd, upper_bd, one_hop)
        
        #We want to increase the diversity of paths and targets.
        #So we abandon one sub-graph from a source_id, if we sampled more than K1 path pairs
        #Note that we mean "sampled", not "appended"! 
        #We do not care whether the pair is actually appended.
        threshold_0 = 1000
        count_0 = 0
        
        for target_id in result:

            if (not carry_on) or (count_0 > threshold_0):
                break
            
            #we want to make sure s, t are indeed directly connected, 
            #otherwise there is no relation for positive sample
            #also, we want to make sure s and t and not connected by all relations, 
            #although this situation is rare. 
            #But in that case, there is no relation for negative samples
            #Also, we want at least two different paths here between s and t
            if ((source_id, target_id) in s_t_r) and (
                len(s_t_r[(source_id, target_id)]) < len(id2relation)) and (
                len(result[target_id]) >= 3):
                
                dir_r = list(s_t_r[(source_id, target_id)])
                
                non_dir_r = list(relation_id_set.difference(dir_r))
                
                if len(dir_r) <= 0:
                    
                    raise ValueError('errors when creating s_t_r !!')
                    
                temp_path_list = list(result[target_id])
                    
                #futhermore, we will abandon one targed_id if we sampled more than K2 times
                threshold_1 = 50
                count_1 = 0
                
                while count_1 <= threshold_1 and count_0 <= threshold_0:
                
                    temp_pair = random.sample(temp_path_list, 3)
                    
                    path_1, path_2, path_3 = temp_pair[0], temp_pair[1], temp_pair[2]                         

                    #proceed when the entire length not yet reached,
                    #and whether this path pair is new, and whether the two paths are different
                    #But it is optional to require the path to be new. 
                    #We may remove this requirment, especially for short paths
                    '''remember to cancel the comment below when using path_comb'''
                    if (carry_on) and (path_1 != path_2) and (path_2 != path_3) and (
                        path_1 != path_3):

                        #####positive#####################
                        #we randomly choose one direction relation as the target relation
                        relation_id = random.choice(dir_r)

                        #append the paths: note that we add the space holder id at the end
                        #of the shorter path
                        x_p_list['1'].append(list(path_1) + [num_r]*abs(len(path_1)-upper_bd))
                        x_p_list['2'].append(list(path_2) + [num_r]*abs(len(path_2)-upper_bd))
                        x_p_list['3'].append(list(path_3) + [num_r]*abs(len(path_3)-upper_bd))

                        #append relation
                        x_r_list.append([relation_id])
                        y_list.append(1.)

                        #####negative#####################
                        relation_id = random.choice(non_dir_r)

                        #append the paths: note that we add the space holder id at the end
                        #of the shorter path
                        x_p_list['1'].append(list(path_1) + [num_r]*abs(len(path_1)-upper_bd))
                        x_p_list['2'].append(list(path_2) + [num_r]*abs(len(path_2)-upper_bd))
                        x_p_list['3'].append(list(path_3) + [num_r]*abs(len(path_3)-upper_bd))

                        #append relation
                        x_r_list.append([relation_id])
                        y_list.append(0.)

                        ######add to path combinations#####
                        #here is the tricky part: we have to add both (path_s, path_l)
                        #and (path_l, path_s). This is because when the length are the same
                        #adding only one situation won't guarantee that 
                        #the same path with different order is also considered.
                        #in other words: path combination don't have order, but our dict does.
                        #so we have to add both situations.
                        '''remember to cancel the comment here when using path_comb'''
                        #path_comb[(len(path_s), len(path_l))].add((path_s, path_l))
                        #path_comb[(len(path_s), len(path_l))].add((path_l, path_s))

                        count += 2

                        if count % 20000 == 0:
                            print('generating big-batches', count, holder_len)

                    if len(y_list) >= holder_len:

                        carry_on = False
                        
                    count_1 += 1
                    count_0 += 1

# %% [markdown]
# ### Start Training: load the KG and call classes
#
# Here, we use the validation set to see the training efficiency. That is, we use the validation to check whether the true relation between entities can be predicted by paths.
#
# The trick is: in validation, we have to use the same relation ID and entity ID as in the training. But we don't want to use the links in training anymore. That is, in validation, we want to use (and update if necessary) entity2id, id2entity, relation2id and id2relation. But we want to use new one_hop, data, data_ and s_t_r for validation set. Then, path-finding will also be based on new one_hop.

# %%
model_name
# Out:
# 'Model_main_7_nell_v4'

# %%
ids_name
# Out:
# 'IDs_main_7_nell_v4'

# %%
#first, we save the relation and ids
Dict = dict()
Dict['one_hop'] = one_hop
Dict['data'] = data
Dict['s_t_r'] = s_t_r
Dict['entity2id'] = entity2id
Dict['id2entity'] = id2entity
Dict['relation2id'] = relation2id
Dict['id2relation'] = id2relation

with open('../weight_bin/' + ids_name + '.pickle', 'wb') as handle:
    pickle.dump(Dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
holder_len = 1000000
lower_bd = 2
upper_bd = 8
num_epoch = 10
batch_size = 32

#90% to be train, 10% to be validation
train_len = 9*int(holder_len/10)
    
######################################
###pre-define the lists###############

#define the lists
x_p_list, x_r_list, y_list = {'1': [], '2': [], '3': []}, list(), list()

#######################################
###build the big-batches###############      

#fill in the training array list
build_big_batches(holder_len, lower_bd, upper_bd, Class_2, one_hop, s_t_r,
                      x_p_list, x_r_list, y_list,
                      relation2id, entity2id, id2relation, id2entity)

#######################################
###do the training#####################

#generate the input arrays
x_train_1 = np.asarray(x_p_list['1'][:train_len], dtype='int')
x_train_2 = np.asarray(x_p_list['2'][:train_len], dtype='int')
x_train_3 = np.asarray(x_p_list['3'][:train_len], dtype='int')
x_train_r = np.asarray(x_r_list[:train_len], dtype='int')
y_train = np.asarray(y_list[:train_len], dtype='int')

#random shuffle the training batches
x_train_1, x_train_2, x_train_3, x_train_r, y_train = shuffle(
           x_train_1, x_train_2, x_train_3, x_train_r, y_train, random_state=None)

#generate the validation arrays
x_valid_1 = np.asarray(x_p_list['1'][train_len:], dtype='int')
x_valid_2 = np.asarray(x_p_list['2'][train_len:], dtype='int')
x_valid_3 = np.asarray(x_p_list['3'][train_len:], dtype='int')
x_valid_r = np.asarray(x_r_list[train_len:], dtype='int')
y_valid = np.asarray(y_list[train_len:], dtype='int')

#random shuffle the validation batches
x_valid_1, x_valid_2, x_valid_3, x_valid_r, y_valid = shuffle(
           x_valid_1, x_valid_2, x_valid_3, x_valid_r, y_valid, random_state=None)

model.fit([x_train_1, x_train_2, x_train_3, x_train_r], y_train, 
          validation_data=([x_valid_1, x_valid_2, x_valid_3, x_valid_r], y_valid),
          batch_size=batch_size, epochs=num_epoch)

# Save model and weights
add_h5 = model_name + '.h5'
save_dir = os.path.join(os.getcwd(), '../weight_bin')

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, add_h5)
model.save(model_path)
print('Save model')
del(model)

del(x_train_1, x_train_2, x_train_3, x_train_r, y_train)
del(x_valid_1, x_valid_2, x_valid_3, x_valid_r, y_valid)

del(x_p_list, x_r_list, y_list)
# Out:
# generating big-batches 20000 1000000
# generating big-batches 40000 1000000
# generating big-batches 60000 1000000
# generating big-batches 80000 1000000
# generating big-batches 100000 1000000
# generating big-batches 120000 1000000
# generating big-batches 140000 1000000
# generating big-batches 160000 1000000
# generating big-batches 180000 1000000
# generating big-batches 200000 1000000
# generating big-batches 220000 1000000
# generating big-batches 240000 1000000
# generating big-batches 260000 1000000
# generating big-batches 280000 1000000
# generating big-batches 300000 1000000
# generating big-batches 320000 1000000
# generating big-batches 340000 1000000
# generating big-batches 360000 1000000
# generating big-batches 380000 1000000
# generating big-batches 400000 1000000
# generating big-batches 420000 1000000
# generating big-batches 440000 1000000
# generating big-batches 460000 1000000
# generating big-batches 480000 1000000
# generating big-batches 500000 1000000
# generating big-batches 520000 1000000
# generating big-batches 540000 1000000
# generating big-batches 560000 1000000
# generating big-batches 580000 1000000
# generating big-batches 600000 1000000
# generating big-batches 620000 1000000
# generating big-batches 640000 1000000
# generating big-batches 660000 1000000
# generating big-batches 680000 1000000
# generating big-batches 700000 1000000
# generating big-batches 720000 1000000
# generating big-batches 740000 1000000
# generating big-batches 760000 1000000
# generating big-batches 780000 1000000
# generating big-batches 800000 1000000
# generating big-batches 820000 1000000
# generating big-batches 840000 1000000
# generating big-batches 860000 1000000
# generating big-batches 880000 1000000
# generating big-batches 900000 1000000
# generating big-batches 920000 1000000
# generating big-batches 940000 1000000
# generating big-batches 960000 1000000
# generating big-batches 980000 1000000
# generating big-batches 1000000 1000000
# Epoch 1/10
# 28125/28125 [==============================] - 1235s 44ms/step - loss: 0.5599 - binary_accuracy: 0.9133 - val_loss: 0.3622 - val_binary_accuracy: 0.9349
# Epoch 2/10
# 28125/28125 [==============================] - 3084s 110ms/step - loss: 0.2086 - binary_accuracy: 0.9582 - val_loss: 0.3129 - val_binary_accuracy: 0.9304
# Epoch 3/10
# 28125/28125 [==============================] - 1356s 48ms/step - loss: 0.0869 - binary_accuracy: 0.9749 - val_loss: 0.3531 - val_binary_accuracy: 0.9266
# Epoch 4/10
# 28125/28125 [==============================] - 1442s 51ms/step - loss: 0.0637 - binary_accuracy: 0.9809 - val_loss: 0.4028 - val_binary_accuracy: 0.9182
# Epoch 5/10
# 28125/28125 [==============================] - 4027s 143ms/step - loss: 0.0543 - binary_accuracy: 0.9837 - val_loss: 0.4714 - val_binary_accuracy: 0.9197
# Epoch 6/10
# 28125/28125 [==============================] - 1385s 49ms/step - loss: 0.0486 - binary_accuracy: 0.9853 - val_loss: 0.3997 - val_binary_accuracy: 0.9199
# Epoch 7/10
# 28125/28125 [==============================] - 1496s 53ms/step - loss: 0.0447 - binary_accuracy: 0.9864 - val_loss: 0.4382 - val_binary_accuracy: 0.9165
# Epoch 8/10
# 28125/28125 [==============================] - 2817s 100ms/step - loss: 0.0417 - binary_accuracy: 0.9872 - val_loss: 0.4719 - val_binary_accuracy: 0.9137
# Epoch 9/10
# 28125/28125 [==============================] - 1467s 52ms/step - loss: 0.0396 - binary_accuracy: 0.9878 - val_loss: 0.5130 - val_binary_accuracy: 0.9156
# Epoch 10/10
# 28125/28125 [==============================] - 2429s 86ms/step - loss: 0.0379 - binary_accuracy: 0.9884 - val_loss: 0.4511 - val_binary_accuracy: 0.9098
# Save model
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/1978735830.py in <module>
#      62 del(model)
#      63
# ---> 64 del(x_train_s, x_train_l, x_train_r, y_train)
#      65 del(x_valid_s, x_valid_l, x_valid_r, y_valid)
#      66
#
# NameError: name 'x_train_s' is not defined

# %% [markdown]
# ### Result on the testset for inductive link prediction
#
# We use the testset for inductive link prediction.

# %%
import librosa
import opensmile
import os
import sys
import numpy as np
import random
from collections import defaultdict
from copy import deepcopy
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.utils import plot_model

# %%
class LoadKG:
    
    def __init__(self):
        
        self.x = 'Hello'
        
    def load_train_data(self, data_path, one_hop, data, s_t_r, entity2id, id2entity,
                     relation2id, id2relation):
        
        data_ = set()
    
        ####load the train, valid and test set##########
        with open (data_path, 'r') as f:
            
            data_ini = f.readlines()
                        
            for i in range(len(data_ini)):
            
                x = data_ini[i].split()
                
                x_ = tuple(x)
                
                data_.add(x_)
        
        ####relation dict#################
        index = len(relation2id)
     
        for key in data_:
            
            if key[1] not in relation2id:
                
                relation = key[1]
                
                relation2id[relation] = index
                
                id2relation[index] = relation
                
                index += 1
                
                #the inverse relation
                iv_r = '_inverse_' + relation
                
                relation2id[iv_r] = index
                
                id2relation[index] = iv_r
                
                index += 1
        
        #get the id of the inverse relation, by above definition, initial relation has 
        #always even id, while inverse relation has always odd id.
        def inverse_r(r):
            
            if r % 2 == 0: #initial relation
                
                iv_r = r + 1
            
            else: #inverse relation
                
                iv_r = r - 1
            
            return(iv_r)
        
        ####entity dict###################
        index = len(entity2id)
        
        for key in data_:
            
            source, target = key[0], key[2]
            
            if source not in entity2id:
                                
                entity2id[source] = index
                
                id2entity[index] = source
                
                index += 1
            
            if target not in entity2id:
                
                entity2id[target] = index
                
                id2entity[index] = target
                
                index += 1
                
        #create the set of triples using id instead of string        
        for ele in data_:
            
            s = entity2id[ele[0]]
            
            r = relation2id[ele[1]]
            
            t = entity2id[ele[2]]
            
            if (s,r,t) not in data:
                
                data.add((s,r,t))
            
            s_t_r[(s,t)].add(r)
            
            if s not in one_hop:
                
                one_hop[s] = dict()
            
            if r not in one_hop[s]:
                
                one_hop[s][r] = set()
            
            one_hop[s][r].add(t)
            
            if t not in one_hop:
                
                one_hop[t] = dict()
            
            r_inv = inverse_r(r)
            
            s_t_r[(t,s)].add(r_inv)
            
            if r_inv not in one_hop[t]:
                
                one_hop[t][r_inv] = set()
            
            one_hop[t][r_inv].add(s)

# %%
class ObtainPathsByDynamicProgramming:

    def __init__(self, size_bd=50, threshold=100000):
                
        self.size_bd = size_bd
        
        self.threshold = threshold
    
    '''
    Given an entity s, here is the function to find:
      1. any else entity t that is directely connected to s
      2. most of the paths from s to each t with length L
    
    One may refer to LeetCode Problem 797 for details:
        https://leetcode.com/problems/all-paths-from-source-to-target/
    '''
    def obtain_paths(self, mode, s, t_input, lower_bd, upper_bd, one_hop):

        if type(lower_bd) != type(1) or lower_bd < 1:
            
            raise TypeError("!!! invalid lower bound setting, must >= 1 !!!")
            
        if type(upper_bd) != type(1) or upper_bd < 1:
            
            raise TypeError("!!! invalid upper bound setting, must >= 1 !!!")
            
        if lower_bd > upper_bd:
            
            raise TypeError("!!! lower bound must not exced upper bound !!!")
            
        if s not in one_hop:
            
            raise ValueError('!!! entity not in one_hop. Please work on active entities for validation')
        
        #here is the result dict. Its key is each entity t that is directly connected to s
        #The value of each t is a set containing the paths from s to t
        #These paths can be either the direct connection r, or a multi-hop path
        res = defaultdict(set)
        
        #direct_nb contains all the direct neighbour of s
        direct_nb = set()
        
        if mode == 'direct_neighbour':
        
            for r in one_hop[s]:
            
                for t in one_hop[s][r]:
                
                    direct_nb.add(t)
                    
        elif mode == 'target_specified':
            
            direct_nb.add(t_input)
            
        elif mode == 'any_target':
            
            for s_any in one_hop:
                
                direct_nb.add(s_any)
                
        else:
            
            raise ValueError('not a valid mode')
        
        '''
        We use recursion to find the paths
        On current node with the path [r1, ..., rk] and on-path entities {e1, ..., ek-1, node}
        from s to this node, we further find the direct neighbor t' of this node. 
        If t' is not a on-path entity (not among e1,...ek-1), we recursively proceed to t' 
        '''
        def helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict):
            
            #when the current path is within lower_bd and upper_bd and its corresponding
            #length still within the size_bd and its tail node is within the note dict, 
            #we will then intend to add this path
            if (len(path) >= lower_bd) and (len(path) <= upper_bd) and (
                node in direct_nb) and (length_dict[len(path)] < self.size_bd):
                
                #if this path already exists between the source entity and the current target node,
                #we will not count it.
                #here is an interesting situation: this path may exist between s and some other node t,
                #however, it does not exist between s and this node t. Then, we still count it: length_dict[len(path)] += 1
                #That is, each path may be counted for multiple times.
                #We count how many paths we "actually" found between entity pairs
                #Same type of path between different entity pairs are count separately.
                if tuple(path) not in res[node]:
                
                    res[node].add(tuple(path))
                
                    length_dict[len(path)] += 1
                
            #For some rare entities, we may face such a case: so many paths are evaluated,
            #but no entities on the paths are direct neighbors of the rare entity.
            #In this case, the recursion cannot be bounded and stoped by the size threshold.
            #In order to cure this, we count how many times the recursion happens on a specific length, using the count_dict.
            #Its key is length, value counts the recursion occurred to that length. 
            #The recursion is forced to stop for that length (and hence for longer lengths) once reach the threshold.
            if (len(path) < upper_bd) and (length_dict[len(path) + 1] < self.size_bd) and (
                count_dict[len(path)] <= self.threshold):
                
                #we randomly shuffle relation r so that the reading in order is not fixed
                temp_list = list()
                
                for r in one_hop[node]:
                    
                    temp_list.append(r)
                
                for i_0 in range(len(temp_list)):
                    
                    if count_dict[len(path)] > self.threshold:
                        break
                    
                    r = random.choice(temp_list)
                    
                    for i_1 in range(len(one_hop[node][r])):
                        
                        if count_dict[len(path)] > self.threshold:
                            break
                        
                        t = random.choice(list(one_hop[node][r]))
                        
                        if t not in on_path_en:
                                
                            count_dict[len(path)] += 1

                            helper(t, path + [r], on_path_en.union({t}), res, direct_nb, 
                                   lower_bd, upper_bd, one_hop, length_dict, count_dict)
        
        length_dict = defaultdict(int)
        count_dict = defaultdict(int)
        
        helper(s, [], {s}, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
        
        return(res, length_dict)

# %%
#load the classes
Class_1 = LoadKG()
Class_2 = ObtainPathsByDynamicProgramming()

# %%
#load ids and relation/entity dicts
with open('../weight_bin/' + ids_name + '.pickle', 'rb') as handle:
    Dict = pickle.load(handle)

one_hop = Dict['one_hop']
data = Dict['data']
s_t_r = Dict['s_t_r']
entity2id = Dict['entity2id']
id2entity = Dict['id2entity']
relation2id = Dict['relation2id']
id2relation = Dict['id2relation']

#we want to keep the initial entity/relation dicts
entity2id_ini = deepcopy(entity2id)
id2entity_ini = deepcopy(id2entity)
relation2id_ini = deepcopy(relation2id)
id2relation_ini = deepcopy(id2relation)

num_r = len(id2relation)
num_r
# Out:
# 152

# %%
ids_name
# Out:
# 'IDs_main_7_nell_v4'

# %%
model_name
# Out:
# 'Model_main_7_nell_v4'

# %%
#load the model
model = keras.models.load_model('../weight_bin/' + model_name + '.h5')

# %%
ind_train_path = '../data/' + data_name + '_ind/train.txt'
ind_valid_path = '../data/' + data_name + '_ind/valid.txt'
ind_test_path = '../data/' + data_name + '_ind/test.txt'

# %%
#load the test dataset
one_hop_ind = dict() 
data_ind = set()
s_t_r_ind = defaultdict(set)

len_0 = len(relation2id)
size_0 = len(entity2id)

#fill in the sets and dicts
Class_1.load_train_data(ind_train_path, 
                        one_hop_ind, data_ind, s_t_r_ind,
                        entity2id, id2entity, relation2id, id2relation)

len_1 = len(relation2id)
size_1 = len(entity2id)

if len_0 != len_1:
    raise ValueError('unseen relation!')

# %%
print(size_0, size_1, len(data_ind))
# Out:
# 2092 4886 7073

# %%
#load the test dataset
one_hop_test = dict() 
data_test = set()
s_t_r_test = defaultdict(set)

len_0 = len(relation2id)
size_0 = len(entity2id)

#fill in the sets and dicts
Class_1.load_train_data(ind_test_path, 
                        one_hop_test, data_test, s_t_r_test,
                        entity2id, id2entity, relation2id, id2relation)


len_1 = len(relation2id)
size_1 = len(entity2id)

if len_0 != len_1:
    raise ValueError('unseen relation!')

# %%
print(size_0, size_1, len(data_test))
# Out:
# 4886 4886 731

# %%
#load the validation for existing triple removal when ranking
one_hop_valid = dict() 
data_valid = set()
s_t_r_valid = defaultdict(set)

len_0 = len(relation2id)
size_0 = len(entity2id)

#fill in the sets and dicts
Class_1.load_train_data(ind_valid_path, 
                        one_hop_valid, data_valid, s_t_r_valid,
                        entity2id, id2entity, relation2id, id2relation)

len_1 = len(relation2id)
size_1 = len(entity2id)

if len_0 != len_1:
    raise ValueError('unseen relation!')

# %%
print(size_0, size_1, len(data_valid))
# Out:
# 4886 4886 716

# %%
print(len(entity2id), len(entity2id_ini))
# Out:
# 4886 2092

# %%
valid_path = '../data/' + data_name + '/valid.txt'
test_path = '../data/' + data_name + '/test.txt'

# %%
#load the test dataset
one_hop_train_test = dict() 
data_train_test = set()
s_t_r_train_test = defaultdict(set)

len_0 = len(relation2id)
size_0 = len(entity2id)

#fill in the sets and dicts
Class_1.load_train_data(test_path, 
                        one_hop_train_test, data_train_test, s_t_r_train_test,
                        entity2id, id2entity, relation2id, id2relation)


len_1 = len(relation2id)
size_1 = len(entity2id)

if len_0 != len_1:
    raise ValueError('unseen relation!')

# %%
#load the validation for existing triple removal when ranking
one_hop_train_valid = dict() 
data_train_valid = set()
s_t_r_train_valid = defaultdict(set)

len_0 = len(relation2id)
size_0 = len(entity2id)

#fill in the sets and dicts
Class_1.load_train_data(valid_path, 
                        one_hop_train_valid, data_train_valid, s_t_r_train_valid,
                        entity2id, id2entity, relation2id, id2relation)

len_1 = len(relation2id)
size_1 = len(entity2id)

if len_0 != len_1:
    raise ValueError('unseen relation!')

# %%
#we want to check whether there are overlapping 
#between the entities of train triples and inductive test and valid triples
overlapping = 0

for ele in data_test:
    
    s, r, t = ele[0], ele[1], ele[2]
    
    if s in id2entity_ini or t in id2entity_ini:
        
        overlapping += 1
        
overlapping
# Out:
# 11

# %%
overlapping = 0

for ele in data_valid:
    
    s, r, t = ele[0], ele[1], ele[2]
    
    if s in id2entity_ini or t in id2entity_ini:
        
        overlapping += 1
        
overlapping
# Out:
# 17

# %%
#we want to check whether there are overlapping 
#between the entities of train triples and inductive test and valid triples
overlapping = 0

for ele in data_ind:
    
    s, r, t = ele[0], ele[1], ele[2]
    
    if s in id2entity_ini or t in id2entity_ini:
        
        overlapping += 1
        
overlapping
# Out:
# 110

# %%
def relation_ranking(s, t, lower_bd, upper_bd, one_hop, id2relation, model):
    
    path_holder = set()
    
    for iteration in range(20):
    
        result, length_dict = Class_2.obtain_paths('target_specified', 
                                                   s, t, lower_bd, upper_bd, one_hop)
        if t in result:
            
            for path in result[t]:
                
                path_holder.add(path)
    
    path_holder = list(path_holder)
    random.shuffle(path_holder)
    
    score_dict = defaultdict(float)
    
    count = 0
    
    if len(path_holder) >= 3:
    
        #iterate over path_1
        while count <= 50:

            temp_pair = random.sample(path_holder, 3)

            path_1, path_2, path_3 = temp_pair[0], temp_pair[1], temp_pair[2]

            list_1 = list()
            list_2 = list()
            list_3 = list()
            list_r = list()

            for i in range(len(id2relation)):

                if i not in id2relation:

                    raise ValueError ('error when generating id2relation')

                list_1.append(list(path_1) + [num_r]*abs(len(path_1)-upper_bd))
                list_2.append(list(path_2) + [num_r]*abs(len(path_2)-upper_bd))
                list_3.append(list(path_3) + [num_r]*abs(len(path_3)-upper_bd))
                list_r.append([i])

            input_1 = np.array(list_1)
            input_2 = np.array(list_2)
            input_3 = np.array(list_3)
            input_r = np.array(list_r)

            pred = model.predict([input_1, input_2, input_3, input_r], verbose = 0)

            for i in range(pred.shape[0]):

                score_dict[i] += float(pred[i])

            count += 1
    
    count_abv = 0
    
    for key in score_dict:
        
        if score_dict[key] >= 0.8:
            
            count_abv += 1
    
    print(len(score_dict), count_abv, len(path_holder))

    return(score_dict)

# %%
########################################################
#obtain the precision-recall area under curve (AUC-PR)##

#randomly select 10% of the triples
selected = random.sample(list(data_test), min(len(data_test), 500))

random.shuffle(selected)

###Hit at 1#############################
#generate the negative samples by randomly replace relation with all the other relaiton
Hits_at_1 = 0
Hits_at_3 = 0
Hits_at_10 = 0
MRR_raw = 0.

for i in range(len(selected)):
    
    s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
    
    score_dict = relation_ranking(s_true, t_true, 2, 8, one_hop_ind, id2relation, model)
    
    #[... [score, r], ...]
    temp_list = list()
    
    for r in id2relation:
        
        if r in score_dict:
            
            temp_list.append([score_dict[r], r])
            
        else:
            
            temp_list.append([0.0, r])
        
    sorted_list = sorted(temp_list, key = lambda x: x[0], reverse=True)
    
    p = 0
    exist_tri = 0
    
    while p < len(sorted_list) and sorted_list[p][1] != r_true:
        
        #moreover, we want to remove existing triples
        if ((s_true, sorted_list[p][1], t_true) in data_test) or (
            (s_true, sorted_list[p][1], t_true) in data_valid) or (
            (s_true, sorted_list[p][1], t_true) in data_ind) or (
            (s_true, sorted_list[p][1], t_true) in data) or (
            (s_true, sorted_list[p][1], t_true) in data_train_valid) or (
            (s_true, sorted_list[p][1], t_true) in data_train_test):
            
            exist_tri += 1
            
        p += 1
    
    if p - exist_tri == 0:
        
        Hits_at_1 += 1
        
    if p - exist_tri < 3:
        
        Hits_at_3 += 1
        
    if p - exist_tri < 10:
        
        Hits_at_10 += 1
        
    MRR_raw += 1./float(p - exist_tri + 1.) 
        
    print('checkcorrect', r_true, sorted_list[p][1],
          'real score', sorted_list[p][0],
          'Hits@1', Hits_at_1/(i+1),
          'Hits@3', Hits_at_3/(i+1),
          'Hits@10', Hits_at_10/(i+1),
          'MRR', MRR_raw/(i+1),
          'cur_rank', p - exist_tri,
          'abs_cur_rank', p,
          'total_num', i, len(selected))
# Out:
# 152 45 1140
# checkcorrect 124 124 real score 1.7071497396100312 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.045454545454545456 cur_rank 21 abs_cur_rank 21 total_num 0 500
# 0 0 1
# checkcorrect 60 60 real score 0.0 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.03092399403874814 cur_rank 60 abs_cur_rank 60 total_num 1 500
# 152 4 818
# checkcorrect 10 10 real score 50.99950700998306 Hits@1 0.3333333333333333 Hits@3 0.3333333333333333 Hits@10 0.3333333333333333 MRR 0.3539493293591654 cur_rank 0 abs_cur_rank 0 total_num 2 500
# 152 51 999
# checkcorrect 124 124 real score 2.048174860421568 Hits@1 0.25 Hits@3 0.25 Hits@10 0.25 MRR 0.2750773816347587 cur_rank 25 abs_cur_rank 25 total_num 3 500
# 152 48 718
# checkcorrect 124 124 real score 2.670605568215251 Hits@1 0.2 Hits@3 0.2 Hits@10 0.2 MRR 0.2318266111901599 cur_rank 16 abs_cur_rank 16 total_num 4 500
# 152 18 1641
# checkcorrect 124 124 real score -1.498010371113196 Hits@1 0.16666666666666666 Hits@3 0.16666666666666666 Hits@10 0.16666666666666666 MRR 0.1966610648806888 cur_rank 47 abs_cur_rank 47 total_num 5 500
# 152 34 330
# checkcorrect 24 24 real score -1.9286297308281064 Hits@1 0.14285714285714285 Hits@3 0.14285714285714285 Hits@10 0.14285714285714285 MRR 0.17019000366396703 cur_rank 87 abs_cur_rank 87 total_num 6 500
# 0 0 0
# checkcorrect 14 14 real score 0.0 Hits@1 0.125 Hits@3 0.125 Hits@10 0.125 MRR 0.1572495865393045 cur_rank 14 abs_cur_rank 14 total_num 7 500
# 152 23 1035
# checkcorrect 124 124 real score -0.5817579310387373 Hits@1 0.1111111111111111 Hits@3 0.1111111111111111 Hits@10 0.1111111111111111 MRR 0.14242291290266218 cur_rank 41 abs_cur_rank 41 total_num 8 500
# 152 52 449
# checkcorrect 124 124 real score 1.311964055057615 Hits@1 0.1 Hits@3 0.1 Hits@10 0.1 MRR 0.13056157399334833 cur_rank 41 abs_cur_rank 41 total_num 9 500
# 152 37 849
# checkcorrect 134 134 real score 0.7126746876165271 Hits@1 0.09090909090909091 Hits@3 0.09090909090909091 Hits@10 0.09090909090909091 MRR 0.12102334232495536 cur_rank 38 abs_cur_rank 38 total_num 10 500
# 152 67 991
# checkcorrect 124 124 real score 3.567050292622298 Hits@1 0.08333333333333333 Hits@3 0.08333333333333333 Hits@10 0.08333333333333333 MRR 0.11371584157565352 cur_rank 29 abs_cur_rank 29 total_num 11 500
# 152 19 1175
# checkcorrect 124 124 real score -0.8493395801633596 Hits@1 0.07692307692307693 Hits@3 0.07692307692307693 Hits@10 0.07692307692307693 MRR 0.10650693068521865 cur_rank 49 abs_cur_rank 49 total_num 12 500
# 152 37 1191
# checkcorrect 30 30 real score 37.506889313459396 Hits@1 0.07142857142857142 Hits@3 0.07142857142857142 Hits@10 0.14285714285714285 MRR 0.11318500706484588 cur_rank 4 abs_cur_rank 4 total_num 13 500
# 152 26 518
# checkcorrect 0 0 real score 50.730795443058014 Hits@1 0.13333333333333333 Hits@3 0.13333333333333333 Hits@10 0.2 MRR 0.17230600659385614 cur_rank 0 abs_cur_rank 0 total_num 14 500
# 152 28 2565
# checkcorrect 124 124 real score 1.0361502037849277 Hits@1 0.125 Hits@3 0.125 Hits@10 0.1875 MRR 0.1641410478484068 cur_rank 23 abs_cur_rank 23 total_num 15 500
# 0 0 0
# checkcorrect 30 30 real score 0.0 Hits@1 0.11764705882352941 Hits@3 0.11764705882352941 Hits@10 0.17647058823529413 MRR 0.15644647640634365 cur_rank 29 abs_cur_rank 30 total_num 16 500
# 152 38 112
# checkcorrect 90 90 real score -4.51274018548429 Hits@1 0.1111111111111111 Hits@3 0.1111111111111111 Hits@10 0.16666666666666666 MRR 0.14818235592223053 cur_rank 129 abs_cur_rank 129 total_num 17 500
# 152 37 606
# checkcorrect 18 18 real score 11.2632816612022 Hits@1 0.10526315789473684 Hits@3 0.10526315789473684 Hits@10 0.15789473684210525 MRR 0.14367275824211315 cur_rank 15 abs_cur_rank 16 total_num 18 500
# 152 16 2826
# checkcorrect 124 124 real score -1.1348733701743186 Hits@1 0.1 Hits@3 0.1 Hits@10 0.15 MRR 0.1373982112390984 cur_rank 54 abs_cur_rank 54 total_num 19 500
# 152 26 257
# checkcorrect 60 60 real score 28.510078102350235 Hits@1 0.09523809523809523 Hits@3 0.09523809523809523 Hits@10 0.19047619047619047 MRR 0.1427602011800937 cur_rank 3 abs_cur_rank 3 total_num 20 500
# 152 31 1151
# checkcorrect 124 124 real score 1.044662156375125 Hits@1 0.09090909090909091 Hits@3 0.09090909090909091 Hits@10 0.18181818181818182 MRR 0.13795460280995478 cur_rank 26 abs_cur_rank 26 total_num 21 500
# 152 40 282
# checkcorrect 120 120 real score 0.9380966505268589 Hits@1 0.08695652173913043 Hits@3 0.08695652173913043 Hits@10 0.17391304347826086 MRR 0.13307140380261 cur_rank 38 abs_cur_rank 38 total_num 22 500
# 152 37 177
# checkcorrect 124 124 real score -2.474601960973814 Hits@1 0.08333333333333333 Hits@3 0.08333333333333333 Hits@10 0.16666666666666666 MRR 0.12812200007273936 cur_rank 69 abs_cur_rank 69 total_num 23 500
# 152 43 465
# checkcorrect 134 134 real score 0.9870251365937293 Hits@1 0.08 Hits@3 0.08 Hits@10 0.16 MRR 0.12402276109547081 cur_rank 38 abs_cur_rank 38 total_num 24 500
# 152 46 252
# checkcorrect 0 0 real score 0.3242069990374148 Hits@1 0.07692307692307693 Hits@3 0.07692307692307693 Hits@10 0.15384615384615385 MRR 0.11999229986990537 cur_rank 51 abs_cur_rank 51 total_num 25 500
# 152 26 210
# checkcorrect 38 38 real score 14.901390012353659 Hits@1 0.07407407407407407 Hits@3 0.07407407407407407 Hits@10 0.14814814814814814 MRR 0.11891514398246779 cur_rank 10 abs_cur_rank 11 total_num 26 500
# 0 0 0
# checkcorrect 38 38 real score 0.0 Hits@1 0.07142857142857142 Hits@3 0.07142857142857142 Hits@10 0.14285714285714285 MRR 0.11560802417858265 cur_rank 37 abs_cur_rank 38 total_num 27 500
# 152 19 2454
# checkcorrect 124 124 real score -1.3796328434254974 Hits@1 0.06896551724137931 Hits@3 0.06896551724137931 Hits@10 0.13793103448275862 MRR 0.11216888596114932 cur_rank 62 abs_cur_rank 62 total_num 28 500
# 152 63 1014
# checkcorrect 124 124 real score 3.698191662784666 Hits@1 0.06666666666666667 Hits@3 0.06666666666666667 Hits@10 0.13333333333333333 MRR 0.11001722468307926 cur_rank 20 abs_cur_rank 20 total_num 29 500
# 152 30 1329
# checkcorrect 94 94 real score -2.450830013724044 Hits@1 0.06451612903225806 Hits@3 0.06451612903225806 Hits@10 0.12903225806451613 MRR 0.10692911144445458 cur_rank 69 abs_cur_rank 69 total_num 30 500
# 152 62 395
# checkcorrect 124 124 real score 4.954395995242521 Hits@1 0.0625 Hits@3 0.0625 Hits@10 0.125 MRR 0.10523231355392064 cur_rank 18 abs_cur_rank 18 total_num 31 500
# 152 40 2571
# checkcorrect 34 34 real score 20.590723728761077 Hits@1 0.06060606060606061 Hits@3 0.06060606060606061 Hits@10 0.12121212121212122 MRR 0.10456870809269073 cur_rank 11 abs_cur_rank 11 total_num 32 500
# 152 33 32
# checkcorrect 30 30 real score -1.3484065416269004 Hits@1 0.058823529411764705 Hits@3 0.058823529411764705 Hits@10 0.11764705882352941 MRR 0.10214675262591223 cur_rank 44 abs_cur_rank 44 total_num 33 500
# 152 35 1825
# checkcorrect 6 6 real score 21.38278186507523 Hits@1 0.05714285714285714 Hits@3 0.08571428571428572 Hits@10 0.14285714285714285 MRR 0.10875208350326714 cur_rank 2 abs_cur_rank 2 total_num 34 500
# 152 44 740
# checkcorrect 74 74 real score 18.6395906296093 Hits@1 0.05555555555555555 Hits@3 0.08333333333333333 Hits@10 0.16666666666666666 MRR 0.10969944626309701 cur_rank 6 abs_cur_rank 6 total_num 35 500
# 152 31 293
# checkcorrect 140 140 real score -4.120608326047659 Hits@1 0.05405405405405406 Hits@3 0.08108108108108109 Hits@10 0.16216216216216217 MRR 0.1069441082015132 cur_rank 128 abs_cur_rank 129 total_num 36 500
# 152 62 1470
# checkcorrect 124 124 real score 5.4829558385536075 Hits@1 0.05263157894736842 Hits@3 0.07894736842105263 Hits@10 0.15789473684210525 MRR 0.10577452640673654 cur_rank 15 abs_cur_rank 15 total_num 37 500
# 152 4 1855
# checkcorrect 10 10 real score 50.999507427215576 Hits@1 0.07692307692307693 Hits@3 0.10256410256410256 Hits@10 0.1794871794871795 MRR 0.1287033847039997 cur_rank 0 abs_cur_rank 0 total_num 38 500
# 0 0 0
# checkcorrect 4 4 real score 0.0 Hits@1 0.075 Hits@3 0.1 Hits@10 0.2 MRR 0.1304858000863997 cur_rank 4 abs_cur_rank 4 total_num 39 500
# 152 6 185
# checkcorrect 42 42 real score 49.50861883163452 Hits@1 0.0975609756097561 Hits@3 0.12195121951219512 Hits@10 0.21951219512195122 MRR 0.15169346349892654 cur_rank 0 abs_cur_rank 0 total_num 40 500
# 152 32 653
# checkcorrect 124 124 real score -0.25111859338358045 Hits@1 0.09523809523809523 Hits@3 0.11904761904761904 Hits@10 0.21428571428571427 MRR 0.1485485677760296 cur_rank 50 abs_cur_rank 50 total_num 41 500
# 152 68 1094
# checkcorrect 94 94 real score 0.7811224139295518 Hits@1 0.09302325581395349 Hits@3 0.11627906976744186 Hits@10 0.20930232558139536 MRR 0.1454309907027077 cur_rank 68 abs_cur_rank 69 total_num 42 500
# 152 22 130
# checkcorrect 104 104 real score -2.1691303779371083 Hits@1 0.09090909090909091 Hits@3 0.11363636363636363 Hits@10 0.20454545454545456 MRR 0.14268006463906524 cur_rank 40 abs_cur_rank 40 total_num 43 500
# 152 21 889
# checkcorrect 124 124 real score -0.7596410135738552 Hits@1 0.08888888888888889 Hits@3 0.1111111111111111 Hits@10 0.2 MRR 0.13992868374771497 cur_rank 52 abs_cur_rank 52 total_num 44 500
# 152 29 2176
# checkcorrect 124 124 real score -1.5018517160788178 Hits@1 0.08695652173913043 Hits@3 0.10869565217391304 Hits@10 0.1956521739130435 MRR 0.1372318214026128 cur_rank 62 abs_cur_rank 62 total_num 45 500
# 152 21 173
# checkcorrect 30 30 real score -1.7473498624749482 Hits@1 0.0851063829787234 Hits@3 0.10638297872340426 Hits@10 0.19148936170212766 MRR 0.13502121527347918 cur_rank 29 abs_cur_rank 29 total_num 46 500
# 152 29 266
# checkcorrect 132 132 real score -2.54181782156229 Hits@1 0.08333333333333333 Hits@3 0.10416666666666667 Hits@10 0.1875 MRR 0.1323894327089049 cur_rank 114 abs_cur_rank 114 total_num 47 500
# 152 67 1027
# checkcorrect 124 124 real score 6.456389282364398 Hits@1 0.08163265306122448 Hits@3 0.10204081632653061 Hits@10 0.20408163265306123 MRR 0.13172842387811093 cur_rank 9 abs_cur_rank 9 total_num 48 500
# 152 48 165
# checkcorrect 32 32 real score 28.63551839021966 Hits@1 0.1 Hits@3 0.12 Hits@10 0.22 MRR 0.1490938554005487 cur_rank 0 abs_cur_rank 0 total_num 49 500
# 152 55 627
# checkcorrect 20 20 real score 44.79769378900528 Hits@1 0.11764705882352941 Hits@3 0.13725490196078433 Hits@10 0.23529411764705882 MRR 0.1657782896083811 cur_rank 0 abs_cur_rank 0 total_num 50 500
# 152 20 156
# checkcorrect 60 60 real score 20.982049886137247 Hits@1 0.11538461538461539 Hits@3 0.1346153846153846 Hits@10 0.25 MRR 0.16499409173129684 cur_rank 7 abs_cur_rank 8 total_num 51 500
# 152 37 788
# checkcorrect 32 32 real score 6.5269829370081425 Hits@1 0.11320754716981132 Hits@3 0.1320754716981132 Hits@10 0.24528301886792453 MRR 0.16359626152710427 cur_rank 10 abs_cur_rank 10 total_num 52 500
# 152 28 629
# checkcorrect 124 124 real score -2.3323558806441724 Hits@1 0.1111111111111111 Hits@3 0.12962962962962962 Hits@10 0.24074074074074073 MRR 0.16077713883889191 cur_rank 87 abs_cur_rank 87 total_num 53 500
# 152 26 35
# checkcorrect 0 0 real score 50.84393912553787 Hits@1 0.12727272727272726 Hits@3 0.14545454545454545 Hits@10 0.2545454545454545 MRR 0.17603573631454844 cur_rank 0 abs_cur_rank 0 total_num 54 500
# 152 58 949
# checkcorrect 124 124 real score 3.3182251101825386 Hits@1 0.125 Hits@3 0.14285714285714285 Hits@10 0.25 MRR 0.17394266119128443 cur_rank 16 abs_cur_rank 16 total_num 55 500
# 152 21 1394
# checkcorrect 124 124 real score -0.9384647598490119 Hits@1 0.12280701754385964 Hits@3 0.14035087719298245 Hits@10 0.24561403508771928 MRR 0.1712100148226973 cur_rank 54 abs_cur_rank 54 total_num 56 500
# 152 40 2405
# checkcorrect 124 124 real score 1.5608132439665496 Hits@1 0.1206896551724138 Hits@3 0.13793103448275862 Hits@10 0.2413793103448276 MRR 0.1688142915415496 cur_rank 30 abs_cur_rank 30 total_num 57 500
# 152 56 770
# checkcorrect 124 124 real score 3.2861733618192375 Hits@1 0.11864406779661017 Hits@3 0.13559322033898305 Hits@10 0.23728813559322035 MRR 0.166760134864897 cur_rank 20 abs_cur_rank 20 total_num 58 500
# 152 42 612
# checkcorrect 124 124 real score 0.9364782690536231 Hits@1 0.11666666666666667 Hits@3 0.13333333333333333 Hits@10 0.23333333333333334 MRR 0.16439746595048205 cur_rank 39 abs_cur_rank 39 total_num 59 500
# 152 56 1174
# checkcorrect 124 124 real score 2.104921222664416 Hits@1 0.11475409836065574 Hits@3 0.13114754098360656 Hits@10 0.22950819672131148 MRR 0.16233294254902397 cur_rank 25 abs_cur_rank 25 total_num 60 500
# 0 0 0
# checkcorrect 42 42 real score 0.0 Hits@1 0.11290322580645161 Hits@3 0.12903225806451613 Hits@10 0.22580645161290322 MRR 0.1600897630555476 cur_rank 42 abs_cur_rank 42 total_num 61 500
# 0 0 0
# checkcorrect 30 30 real score 0.0 Hits@1 0.1111111111111111 Hits@3 0.12698412698412698 Hits@10 0.2222222222222222 MRR 0.15806068847555682 cur_rank 30 abs_cur_rank 30 total_num 62 500
# 152 31 1079
# checkcorrect 124 124 real score -4.570306348148733 Hits@1 0.109375 Hits@3 0.125 Hits@10 0.21875 MRR 0.15572453722667326 cur_rank 116 abs_cur_rank 116 total_num 63 500
# 152 62 804
# checkcorrect 124 124 real score 4.047859472921118 Hits@1 0.1076923076923077 Hits@3 0.12307692307692308 Hits@10 0.2153846153846154 MRR 0.15429031357703213 cur_rank 15 abs_cur_rank 15 total_num 64 500
# 152 29 1610
# checkcorrect 4 4 real score 25.862110941205174 Hits@1 0.10606060606060606 Hits@3 0.13636363636363635 Hits@10 0.22727272727272727 MRR 0.15952833912889527 cur_rank 1 abs_cur_rank 1 total_num 65 500
# 152 27 236
# checkcorrect 0 0 real score 49.62168210744858 Hits@1 0.11940298507462686 Hits@3 0.14925373134328357 Hits@10 0.23880597014925373 MRR 0.1720726922762252 cur_rank 0 abs_cur_rank 0 total_num 66 500
# 152 68 867
# checkcorrect 124 124 real score 4.357999676838517 Hits@1 0.11764705882352941 Hits@3 0.14705882352941177 Hits@10 0.23529411764705882 MRR 0.17035920497150947 cur_rank 17 abs_cur_rank 17 total_num 67 500
# 152 39 711
# checkcorrect 134 134 real score 1.1821879660710692 Hits@1 0.11594202898550725 Hits@3 0.14492753623188406 Hits@10 0.2318840579710145 MRR 0.16830430966136337 cur_rank 34 abs_cur_rank 34 total_num 68 500
# 152 17 2249
# checkcorrect 124 124 real score -0.9271403448656201 Hits@1 0.11428571428571428 Hits@3 0.14285714285714285 Hits@10 0.22857142857142856 MRR 0.16624009843490853 cur_rank 41 abs_cur_rank 41 total_num 69 500
# 152 18 1826
# checkcorrect 124 124 real score -0.278582620434463 Hits@1 0.11267605633802817 Hits@3 0.14084507042253522 Hits@10 0.22535211267605634 MRR 0.1642693335199617 cur_rank 37 abs_cur_rank 37 total_num 70 500
# 152 41 1433
# checkcorrect 46 46 real score 6.206427913624793 Hits@1 0.1111111111111111 Hits@3 0.1388888888888889 Hits@10 0.2222222222222222 MRR 0.16252200303303915 cur_rank 25 abs_cur_rank 25 total_num 71 500
# 152 19 2891
# checkcorrect 124 124 real score -1.4278512336313725 Hits@1 0.1095890410958904 Hits@3 0.136986301369863 Hits@10 0.2191780821917808 MRR 0.16054474022685805 cur_rank 54 abs_cur_rank 54 total_num 72 500
# 152 64 1010
# checkcorrect 124 124 real score 3.8897714843042195 Hits@1 0.10810810810810811 Hits@3 0.13513513513513514 Hits@10 0.21621621621621623 MRR 0.15917012926989732 cur_rank 16 abs_cur_rank 16 total_num 73 500
# 152 17 1872
# checkcorrect 124 124 real score -0.6492873684037477 Hits@1 0.10666666666666667 Hits@3 0.13333333333333333 Hits@10 0.21333333333333335 MRR 0.15735089118266232 cur_rank 43 abs_cur_rank 43 total_num 74 500
# 152 15 2985
# checkcorrect 124 124 real score -0.868206340353936 Hits@1 0.10526315789473684 Hits@3 0.13157894736842105 Hits@10 0.21052631578947367 MRR 0.15560140898160676 cur_rank 40 abs_cur_rank 40 total_num 75 500
# 152 19 27
# checkcorrect 148 148 real score -2.400015954161063 Hits@1 0.1038961038961039 Hits@3 0.12987012987012986 Hits@10 0.2077922077922078 MRR 0.15383525877583595 cur_rank 50 abs_cur_rank 50 total_num 76 500
# 0 0 0
# checkcorrect 2 2 real score 0.0 Hits@1 0.10256410256410256 Hits@3 0.14102564102564102 Hits@10 0.21794871794871795 MRR 0.15613651614195773 cur_rank 2 abs_cur_rank 2 total_num 77 500
# 152 43 331
# checkcorrect 32 32 real score 49.44726490974426 Hits@1 0.11392405063291139 Hits@3 0.1518987341772152 Hits@10 0.22784810126582278 MRR 0.16681833239332533 cur_rank 0 abs_cur_rank 0 total_num 78 500
# 152 34 415
# checkcorrect 32 32 real score 5.039550682064146 Hits@1 0.1125 Hits@3 0.15 Hits@10 0.225 MRR 0.16539099797525086 cur_rank 18 abs_cur_rank 18 total_num 79 500
# 152 29 522
# checkcorrect 60 60 real score 11.37999469973147 Hits@1 0.1111111111111111 Hits@3 0.14814814814814814 Hits@10 0.2222222222222222 MRR 0.1644714682583847 cur_rank 10 abs_cur_rank 10 total_num 80 500
# 152 25 351
# checkcorrect 12 12 real score 32.26458887755871 Hits@1 0.10975609756097561 Hits@3 0.15853658536585366 Hits@10 0.23170731707317074 MRR 0.1665307592958841 cur_rank 2 abs_cur_rank 2 total_num 81 500
# 152 64 890
# checkcorrect 124 124 real score 3.1452204952947795 Hits@1 0.10843373493975904 Hits@3 0.1566265060240964 Hits@10 0.2289156626506024 MRR 0.16512677424412647 cur_rank 19 abs_cur_rank 19 total_num 82 500
# 152 43 1097
# checkcorrect 66 66 real score 24.838398540392518 Hits@1 0.11904761904761904 Hits@3 0.16666666666666666 Hits@10 0.23809523809523808 MRR 0.17506574121741067 cur_rank 0 abs_cur_rank 0 total_num 83 500
# 152 69 1180
# checkcorrect 124 124 real score 4.641451987903565 Hits@1 0.11764705882352941 Hits@3 0.16470588235294117 Hits@10 0.23529411764705882 MRR 0.17356636835154757 cur_rank 20 abs_cur_rank 20 total_num 84 500
# 152 65 746
# checkcorrect 124 124 real score 3.355307932011783 Hits@1 0.11627906976744186 Hits@3 0.16279069767441862 Hits@10 0.23255813953488372 MRR 0.1721295501149017 cur_rank 19 abs_cur_rank 19 total_num 85 500
# 152 37 288
# checkcorrect 4 4 real score 26.393575608730316 Hits@1 0.12643678160919541 Hits@3 0.1724137931034483 Hits@10 0.2413793103448276 MRR 0.18164530241243154 cur_rank 0 abs_cur_rank 0 total_num 86 500
# 152 23 984
# checkcorrect 124 124 real score -0.6690998449921608 Hits@1 0.125 Hits@3 0.17045454545454544 Hits@10 0.23863636363636365 MRR 0.17982293074575256 cur_rank 46 abs_cur_rank 46 total_num 87 500
# 152 47 1619
# checkcorrect 106 106 real score 10.342918571084738 Hits@1 0.12359550561797752 Hits@3 0.16853932584269662 Hits@10 0.24719101123595505 MRR 0.17940758481441985 cur_rank 6 abs_cur_rank 7 total_num 88 500
# 152 39 616
# checkcorrect 6 6 real score 23.980248535517603 Hits@1 0.12222222222222222 Hits@3 0.17777777777777778 Hits@10 0.25555555555555554 MRR 0.1829697227609263 cur_rank 1 abs_cur_rank 1 total_num 89 500
# 152 7 55
# checkcorrect 10 10 real score 47.22062808461487 Hits@1 0.13186813186813187 Hits@3 0.18681318681318682 Hits@10 0.26373626373626374 MRR 0.19194807745586115 cur_rank 0 abs_cur_rank 0 total_num 90 500
# 152 63 868
# checkcorrect 124 124 real score 3.9260924477130175 Hits@1 0.13043478260869565 Hits@3 0.18478260869565216 Hits@10 0.2608695652173913 MRR 0.19043376768946452 cur_rank 18 abs_cur_rank 18 total_num 91 500
# 152 20 2518
# checkcorrect 124 124 real score -0.9578666398301721 Hits@1 0.12903225806451613 Hits@3 0.1827956989247312 Hits@10 0.25806451612903225 MRR 0.18863047204470978 cur_rank 43 abs_cur_rank 43 total_num 92 500
# 152 19 2422
# checkcorrect 124 124 real score -0.08929709601216018 Hits@1 0.1276595744680851 Hits@3 0.18085106382978725 Hits@10 0.2553191489361702 MRR 0.18691927316952966 cur_rank 35 abs_cur_rank 35 total_num 93 500
# 0 0 0
# checkcorrect 120 120 real score 0.0 Hits@1 0.12631578947368421 Hits@3 0.17894736842105263 Hits@10 0.25263157894736843 MRR 0.18503869621837585 cur_rank 120 abs_cur_rank 120 total_num 94 500
# 152 19 2692
# checkcorrect 124 124 real score -1.1822490289341658 Hits@1 0.125 Hits@3 0.17708333333333334 Hits@10 0.25 MRR 0.18330775067993757 cur_rank 52 abs_cur_rank 52 total_num 95 500
# 152 20 120
# checkcorrect 60 60 real score -2.199927876354195 Hits@1 0.12371134020618557 Hits@3 0.17525773195876287 Hits@10 0.24742268041237114 MRR 0.181689276853069 cur_rank 37 abs_cur_rank 37 total_num 96 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.12244897959183673 Hits@3 0.17346938775510204 Hits@10 0.24489795918367346 MRR 0.18068564477633697 cur_rank 11 abs_cur_rank 12 total_num 97 500
# 152 31 1450
# checkcorrect 124 124 real score 1.1156615787185729 Hits@1 0.12121212121212122 Hits@3 0.1717171717171717 Hits@10 0.24242424242424243 MRR 0.1792346487385663 cur_rank 26 abs_cur_rank 26 total_num 98 500
# 152 21 441
# checkcorrect 18 18 real score 39.06896811723709 Hits@1 0.12 Hits@3 0.18 Hits@10 0.25 MRR 0.18077563558451396 cur_rank 2 abs_cur_rank 2 total_num 99 500
# 152 28 2456
# checkcorrect 124 124 real score 0.3236213375348598 Hits@1 0.1188118811881188 Hits@3 0.1782178217821782 Hits@10 0.24752475247524752 MRR 0.17925337213344975 cur_rank 36 abs_cur_rank 36 total_num 100 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.11764705882352941 Hits@3 0.17647058823529413 Hits@10 0.24509803921568626 MRR 0.17801198200417445 cur_rank 18 abs_cur_rank 18 total_num 101 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.11650485436893204 Hits@3 0.17475728155339806 Hits@10 0.24271844660194175 MRR 0.1766720598487941 cur_rank 24 abs_cur_rank 24 total_num 102 500
# 152 65 1065
# checkcorrect 124 124 real score 4.53676843829453 Hits@1 0.11538461538461539 Hits@3 0.17307692307692307 Hits@10 0.2403846153846154 MRR 0.17557425158101722 cur_rank 15 abs_cur_rank 15 total_num 103 500
# 152 17 2859
# checkcorrect 124 124 real score -0.5459842821583152 Hits@1 0.11428571428571428 Hits@3 0.17142857142857143 Hits@10 0.23809523809523808 MRR 0.17411375606331442 cur_rank 44 abs_cur_rank 44 total_num 104 500
# 152 25 521
# checkcorrect 12 12 real score 32.97243617475033 Hits@1 0.11320754716981132 Hits@3 0.1792452830188679 Hits@10 0.24528301886792453 MRR 0.177188154591019 cur_rank 1 abs_cur_rank 1 total_num 105 500
# 152 70 1151
# checkcorrect 124 124 real score 5.1434548404067755 Hits@1 0.11214953271028037 Hits@3 0.17757009345794392 Hits@10 0.24299065420560748 MRR 0.17615524348892225 cur_rank 14 abs_cur_rank 14 total_num 106 500
# 152 43 727
# checkcorrect 124 124 real score 2.026419263333082 Hits@1 0.1111111111111111 Hits@3 0.17592592592592593 Hits@10 0.24074074074074073 MRR 0.17489454678995073 cur_rank 24 abs_cur_rank 24 total_num 107 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.11009174311926606 Hits@3 0.1743119266055046 Hits@10 0.23853211009174313 MRR 0.1740545356573212 cur_rank 11 abs_cur_rank 12 total_num 108 500
# 152 24 1375
# checkcorrect 124 124 real score -0.7580964236985892 Hits@1 0.10909090909090909 Hits@3 0.17272727272727273 Hits@10 0.23636363636363636 MRR 0.17260996274363208 cur_rank 65 abs_cur_rank 65 total_num 109 500
# 152 4 410
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.11711711711711711 Hits@3 0.18018018018018017 Hits@10 0.24324324324324326 MRR 0.18006392704323898 cur_rank 0 abs_cur_rank 0 total_num 110 500
# 152 22 1437
# checkcorrect 124 124 real score 0.10334521299228072 Hits@1 0.11607142857142858 Hits@3 0.17857142857142858 Hits@10 0.24107142857142858 MRR 0.17871131544974067 cur_rank 34 abs_cur_rank 34 total_num 111 500
# 152 17 1679
# checkcorrect 124 124 real score -1.9801365872845054 Hits@1 0.11504424778761062 Hits@3 0.17699115044247787 Hits@10 0.23893805309734514 MRR 0.17722704726867228 cur_rank 90 abs_cur_rank 90 total_num 112 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.12280701754385964 Hits@3 0.18421052631578946 Hits@10 0.24561403508771928 MRR 0.18444435387157865 cur_rank 0 abs_cur_rank 0 total_num 113 500
# 152 37 704
# checkcorrect 120 120 real score 3.1452958087902516 Hits@1 0.12173913043478261 Hits@3 0.1826086956521739 Hits@10 0.24347826086956523 MRR 0.183202808765449 cur_rank 23 abs_cur_rank 23 total_num 114 500
# 152 19 2123
# checkcorrect 124 124 real score -0.43066778499633074 Hits@1 0.1206896551724138 Hits@3 0.1810344827586207 Hits@10 0.2413793103448276 MRR 0.18184451753161776 cur_rank 38 abs_cur_rank 38 total_num 115 500
# 152 87 92
# checkcorrect 146 146 real score 2.800102410838008 Hits@1 0.11965811965811966 Hits@3 0.1794871794871795 Hits@10 0.23931623931623933 MRR 0.18048022440931524 cur_rank 44 abs_cur_rank 44 total_num 116 500
# 152 56 927
# checkcorrect 124 124 real score 2.795283738989383 Hits@1 0.11864406779661017 Hits@3 0.17796610169491525 Hits@10 0.23728813559322035 MRR 0.17935428223312652 cur_rank 20 abs_cur_rank 20 total_num 117 500
# 152 49 1177
# checkcorrect 124 124 real score 2.1686860115732998 Hits@1 0.11764705882352941 Hits@3 0.17647058823529413 Hits@10 0.23529411764705882 MRR 0.17821246692755038 cur_rank 22 abs_cur_rank 22 total_num 118 500
# 152 44 194
# checkcorrect 72 72 real score 4.309399511665106 Hits@1 0.11666666666666667 Hits@3 0.175 Hits@10 0.23333333333333334 MRR 0.17701471935832655 cur_rank 28 abs_cur_rank 28 total_num 119 500
# 152 26 2494
# checkcorrect 124 124 real score 0.6014218393247575 Hits@1 0.11570247933884298 Hits@3 0.17355371900826447 Hits@10 0.23140495867768596 MRR 0.17581005225619162 cur_rank 31 abs_cur_rank 31 total_num 120 500
# 152 50 625
# checkcorrect 124 124 real score 1.8325076894834638 Hits@1 0.11475409836065574 Hits@3 0.1721311475409836 Hits@10 0.22950819672131148 MRR 0.17467256852488708 cur_rank 26 abs_cur_rank 26 total_num 121 500
# 152 35 707
# checkcorrect 12 12 real score -2.2756300838664174 Hits@1 0.11382113821138211 Hits@3 0.17073170731707318 Hits@10 0.22764227642276422 MRR 0.17335409235801807 cur_rank 79 abs_cur_rank 79 total_num 122 500
# 152 63 1136
# checkcorrect 124 124 real score 5.268470829818398 Hits@1 0.11290322580645161 Hits@3 0.1693548387096774 Hits@10 0.22580645161290322 MRR 0.17253211235052254 cur_rank 13 abs_cur_rank 13 total_num 123 500
# 152 61 1387
# checkcorrect 124 124 real score 4.471054862020537 Hits@1 0.112 Hits@3 0.168 Hits@10 0.224 MRR 0.17157290808329734 cur_rank 18 abs_cur_rank 18 total_num 124 500
# 152 16 586
# checkcorrect 94 94 real score -2.0000068659428507 Hits@1 0.1111111111111111 Hits@3 0.16666666666666666 Hits@10 0.2222222222222222 MRR 0.17032459702141176 cur_rank 69 abs_cur_rank 69 total_num 125 500
# 152 18 516
# checkcorrect 18 18 real score 34.80863322969526 Hits@1 0.11023622047244094 Hits@3 0.16535433070866143 Hits@10 0.2283464566929134 MRR 0.17095196239919594 cur_rank 3 abs_cur_rank 3 total_num 126 500
# 152 19 133
# checkcorrect 14 14 real score 37.37769392132759 Hits@1 0.109375 Hits@3 0.171875 Hits@10 0.234375 MRR 0.17222056685961887 cur_rank 2 abs_cur_rank 2 total_num 127 500
# 152 77 671
# checkcorrect 124 124 real score 5.461581118404865 Hits@1 0.10852713178294573 Hits@3 0.17054263565891473 Hits@10 0.23255813953488372 MRR 0.17129352044169446 cur_rank 18 abs_cur_rank 18 total_num 128 500
# 152 48 117
# checkcorrect 24 24 real score 10.06273930275347 Hits@1 0.1076923076923077 Hits@3 0.16923076923076924 Hits@10 0.23076923076923078 MRR 0.1704032284041088 cur_rank 17 abs_cur_rank 17 total_num 129 500
# 152 47 274
# checkcorrect 124 124 real score 1.1772773587144911 Hits@1 0.10687022900763359 Hits@3 0.16793893129770993 Hits@10 0.22900763358778625 MRR 0.1693033242901361 cur_rank 37 abs_cur_rank 37 total_num 130 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.10606060606060606 Hits@3 0.16666666666666666 Hits@10 0.22727272727272727 MRR 0.16825029175993075 cur_rank 32 abs_cur_rank 32 total_num 131 500
# 152 4 250
# checkcorrect 10 10 real score 50.6090047955513 Hits@1 0.11278195488721804 Hits@3 0.17293233082706766 Hits@10 0.23308270676691728 MRR 0.1745040489647433 cur_rank 0 abs_cur_rank 0 total_num 132 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.11940298507462686 Hits@3 0.1791044776119403 Hits@10 0.23880597014925373 MRR 0.18066446650978252 cur_rank 0 abs_cur_rank 0 total_num 133 500
# 152 44 2802
# checkcorrect 122 122 real score 22.210770272649825 Hits@1 0.11851851851851852 Hits@3 0.17777777777777778 Hits@10 0.24444444444444444 MRR 0.18117806305415451 cur_rank 3 abs_cur_rank 3 total_num 134 500
# 152 24 674
# checkcorrect 124 124 real score 0.4204912497662008 Hits@1 0.11764705882352941 Hits@3 0.17647058823529413 Hits@10 0.2426470588235294 MRR 0.18006868781333743 cur_rank 32 abs_cur_rank 32 total_num 135 500
# 152 40 256
# checkcorrect 120 120 real score -0.035018450464122 Hits@1 0.11678832116788321 Hits@3 0.17518248175182483 Hits@10 0.24087591240875914 MRR 0.1789003032307583 cur_rank 49 abs_cur_rank 49 total_num 136 500
# 0 0 0
# checkcorrect 28 28 real score 0.0 Hits@1 0.11594202898550725 Hits@3 0.17391304347826086 Hits@10 0.2391304347826087 MRR 0.17785379928430856 cur_rank 28 abs_cur_rank 28 total_num 137 500
# 0 0 0
# checkcorrect 94 94 real score 0.0 Hits@1 0.11510791366906475 Hits@3 0.17266187050359713 Hits@10 0.23741007194244604 MRR 0.17665000443902196 cur_rank 94 abs_cur_rank 94 total_num 138 500
# 152 50 473
# checkcorrect 64 64 real score 14.407284196466208 Hits@1 0.11428571428571428 Hits@3 0.17142857142857143 Hits@10 0.24285714285714285 MRR 0.17618186948667974 cur_rank 8 abs_cur_rank 9 total_num 139 500
# 152 21 2782
# checkcorrect 124 124 real score -0.5111694056540728 Hits@1 0.11347517730496454 Hits@3 0.1702127659574468 Hits@10 0.24113475177304963 MRR 0.17512935819796413 cur_rank 35 abs_cur_rank 35 total_num 140 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.11971830985915492 Hits@3 0.176056338028169 Hits@10 0.24647887323943662 MRR 0.1809383063796686 cur_rank 0 abs_cur_rank 0 total_num 141 500
# 152 27 824
# checkcorrect 0 0 real score 50.44035702943802 Hits@1 0.1258741258741259 Hits@3 0.18181818181818182 Hits@10 0.2517482517482518 MRR 0.18666601053085974 cur_rank 0 abs_cur_rank 0 total_num 142 500
# 152 21 949
# checkcorrect 124 124 real score -1.0128567379433662 Hits@1 0.125 Hits@3 0.18055555555555555 Hits@10 0.25 MRR 0.18549155114973656 cur_rank 56 abs_cur_rank 56 total_num 143 500
# 152 57 10
# checkcorrect 32 32 real score -5.3137828963808715 Hits@1 0.12413793103448276 Hits@3 0.1793103448275862 Hits@10 0.2482758620689655 MRR 0.18426534947071982 cur_rank 129 abs_cur_rank 129 total_num 144 500
# 152 56 1338
# checkcorrect 124 124 real score 3.7796098536346108 Hits@1 0.1232876712328767 Hits@3 0.1780821917808219 Hits@10 0.2465753424657534 MRR 0.1834061589223708 cur_rank 16 abs_cur_rank 16 total_num 145 500
# 152 33 278
# checkcorrect 0 0 real score 48.74323374032974 Hits@1 0.1292517006802721 Hits@3 0.1836734693877551 Hits@10 0.25170068027210885 MRR 0.18896121906575605 cur_rank 0 abs_cur_rank 0 total_num 146 500
# 152 24 151
# checkcorrect 60 60 real score 0.8321907194331288 Hits@1 0.12837837837837837 Hits@3 0.18243243243243243 Hits@10 0.25 MRR 0.18796598560360006 cur_rank 23 abs_cur_rank 23 total_num 147 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.12751677852348994 Hits@3 0.18120805369127516 Hits@10 0.2483221476510067 MRR 0.18705770099516897 cur_rank 18 abs_cur_rank 18 total_num 148 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.12666666666666668 Hits@3 0.18 Hits@10 0.24666666666666667 MRR 0.1860126698572214 cur_rank 32 abs_cur_rank 32 total_num 149 500
# 152 41 621
# checkcorrect 30 30 real score 37.569690108299255 Hits@1 0.12582781456953643 Hits@3 0.17880794701986755 Hits@10 0.25165562913907286 MRR 0.18610530118267024 cur_rank 4 abs_cur_rank 4 total_num 150 500
# 152 26 498
# checkcorrect 4 4 real score 39.456226229667664 Hits@1 0.13157894736842105 Hits@3 0.18421052631578946 Hits@10 0.2565789473684211 MRR 0.19145987156962638 cur_rank 0 abs_cur_rank 0 total_num 151 500
# 152 19 2588
# checkcorrect 124 124 real score -0.14243146847002208 Hits@1 0.13071895424836602 Hits@3 0.1830065359477124 Hits@10 0.2549019607843137 MRR 0.19040073361626858 cur_rank 33 abs_cur_rank 33 total_num 152 500
# 152 31 227
# checkcorrect 0 0 real score 1.1659158987458795 Hits@1 0.12987012987012986 Hits@3 0.18181818181818182 Hits@10 0.2532467532467532 MRR 0.18940486545666319 cur_rank 26 abs_cur_rank 26 total_num 153 500
# 152 38 527
# checkcorrect 30 30 real score 39.40870863199234 Hits@1 0.12903225806451613 Hits@3 0.18064516129032257 Hits@10 0.25806451612903225 MRR 0.18947322116339438 cur_rank 4 abs_cur_rank 4 total_num 154 500
# 152 37 792
# checkcorrect 120 120 real score 2.8945077906828374 Hits@1 0.1282051282051282 Hits@3 0.1794871794871795 Hits@10 0.2564102564102564 MRR 0.18852574324995383 cur_rank 23 abs_cur_rank 23 total_num 155 500
# 152 67 892
# checkcorrect 124 124 real score 4.616819383809343 Hits@1 0.12738853503184713 Hits@3 0.17834394904458598 Hits@10 0.25477707006369427 MRR 0.18772303150950825 cur_rank 15 abs_cur_rank 15 total_num 156 500
# 0 0 0
# checkcorrect 34 34 real score 0.0 Hits@1 0.12658227848101267 Hits@3 0.17721518987341772 Hits@10 0.25316455696202533 MRR 0.18671574288331788 cur_rank 34 abs_cur_rank 34 total_num 157 500
# 152 72 834
# checkcorrect 124 124 real score 5.163844258058816 Hits@1 0.12578616352201258 Hits@3 0.1761006289308176 Hits@10 0.25157232704402516 MRR 0.18585589544380016 cur_rank 19 abs_cur_rank 19 total_num 158 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.125 Hits@3 0.175 Hits@10 0.25 MRR 0.18494429609727642 cur_rank 24 abs_cur_rank 24 total_num 159 500
# 152 26 116
# checkcorrect 60 60 real score 32.49790918827057 Hits@1 0.12422360248447205 Hits@3 0.18012422360248448 Hits@10 0.2546583850931677 MRR 0.18586596713600967 cur_rank 2 abs_cur_rank 2 total_num 160 500
# 152 31 1348
# checkcorrect 62 62 real score 12.056759230792522 Hits@1 0.12345679012345678 Hits@3 0.17901234567901234 Hits@10 0.25925925925925924 MRR 0.18595321425245406 cur_rank 4 abs_cur_rank 4 total_num 161 500
# 152 74 1924
# checkcorrect 124 124 real score 7.194389644777402 Hits@1 0.12269938650306748 Hits@3 0.17791411042944785 Hits@10 0.25766871165644173 MRR 0.1852506090817554 cur_rank 13 abs_cur_rank 13 total_num 162 500
# 152 18 840
# checkcorrect 124 124 real score -0.17797689815051854 Hits@1 0.12195121951219512 Hits@3 0.17682926829268292 Hits@10 0.25609756097560976 MRR 0.1842858311423973 cur_rank 36 abs_cur_rank 36 total_num 163 500
# 152 22 165
# checkcorrect 14 14 real score 37.68952292203903 Hits@1 0.12121212121212122 Hits@3 0.18181818181818182 Hits@10 0.2606060606060606 MRR 0.18518914933749386 cur_rank 2 abs_cur_rank 2 total_num 164 500
# 152 39 1784
# checkcorrect 114 114 real score -3.2176043624058366 Hits@1 0.12048192771084337 Hits@3 0.18072289156626506 Hits@10 0.25903614457831325 MRR 0.1841250400556235 cur_rank 116 abs_cur_rank 117 total_num 165 500
# 152 4 272
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.12574850299401197 Hits@3 0.18562874251497005 Hits@10 0.2634730538922156 MRR 0.1890105188576856 cur_rank 0 abs_cur_rank 0 total_num 166 500
# 152 19 336
# checkcorrect 124 124 real score -2.547711888793856 Hits@1 0.125 Hits@3 0.18452380952380953 Hits@10 0.2619047619047619 MRR 0.1879608028397714 cur_rank 78 abs_cur_rank 78 total_num 167 500
# 152 20 1865
# checkcorrect 124 124 real score 0.4384010194335133 Hits@1 0.1242603550295858 Hits@3 0.1834319526627219 Hits@10 0.2603550295857988 MRR 0.1870526487319662 cur_rank 28 abs_cur_rank 28 total_num 168 500
# 152 66 1030
# checkcorrect 124 124 real score 3.595010221702978 Hits@1 0.12352941176470589 Hits@3 0.18235294117647058 Hits@10 0.25882352941176473 MRR 0.1862791364191638 cur_rank 17 abs_cur_rank 17 total_num 169 500
# 152 21 2040
# checkcorrect 124 124 real score -1.9642726657912135 Hits@1 0.12280701754385964 Hits@3 0.18128654970760233 Hits@10 0.2573099415204678 MRR 0.18528260939842608 cur_rank 62 abs_cur_rank 62 total_num 170 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.12209302325581395 Hits@3 0.18023255813953487 Hits@10 0.2558139534883721 MRR 0.18438156533391797 cur_rank 32 abs_cur_rank 32 total_num 171 500
# 152 39 307
# checkcorrect 34 34 real score 45.99539166688919 Hits@1 0.12138728323699421 Hits@3 0.18497109826589594 Hits@10 0.26011560693641617 MRR 0.18524255821252733 cur_rank 2 abs_cur_rank 2 total_num 172 500
# 152 41 1803
# checkcorrect 124 124 real score 1.8346260632388294 Hits@1 0.1206896551724138 Hits@3 0.1839080459770115 Hits@10 0.25862068965517243 MRR 0.1844278208714758 cur_rank 22 abs_cur_rank 22 total_num 173 500
# 152 22 235
# checkcorrect 12 12 real score 36.794399842619896 Hits@1 0.12 Hits@3 0.18857142857142858 Hits@10 0.26285714285714284 MRR 0.18527870951411501 cur_rank 2 abs_cur_rank 2 total_num 174 500
# 152 22 150
# checkcorrect 14 14 real score 41.02262878417969 Hits@1 0.11931818181818182 Hits@3 0.19318181818181818 Hits@10 0.26704545454545453 MRR 0.187066898664603 cur_rank 1 abs_cur_rank 1 total_num 175 500
# 152 40 3
# checkcorrect 146 146 real score -0.24155805399641395 Hits@1 0.11864406779661017 Hits@3 0.192090395480226 Hits@10 0.2655367231638418 MRR 0.18610743245356196 cur_rank 57 abs_cur_rank 57 total_num 176 500
# 152 27 126
# checkcorrect 14 14 real score 35.70500901341438 Hits@1 0.12359550561797752 Hits@3 0.19662921348314608 Hits@10 0.2696629213483146 MRR 0.19067986260831724 cur_rank 0 abs_cur_rank 0 total_num 177 500
# 152 44 2462
# checkcorrect 124 124 real score 3.16902903560549 Hits@1 0.12290502793296089 Hits@3 0.19553072625698323 Hits@10 0.2681564245810056 MRR 0.18994323504855998 cur_rank 16 abs_cur_rank 16 total_num 178 500
# 152 51 166
# checkcorrect 62 62 real score 24.756227558944374 Hits@1 0.12777777777777777 Hits@3 0.2 Hits@10 0.2722222222222222 MRR 0.1944435504094013 cur_rank 0 abs_cur_rank 0 total_num 179 500
# 152 51 107
# checkcorrect 134 134 real score 2.3542442072648555 Hits@1 0.1270718232044199 Hits@3 0.19889502762430938 Hits@10 0.27071823204419887 MRR 0.19357390116425013 cur_rank 26 abs_cur_rank 26 total_num 180 500
# 152 18 2404
# checkcorrect 124 124 real score -0.690005334559828 Hits@1 0.12637362637362637 Hits@3 0.1978021978021978 Hits@10 0.2692307692307692 MRR 0.19265880844921043 cur_rank 36 abs_cur_rank 36 total_num 181 500
# 152 4 35
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.13114754098360656 Hits@3 0.20218579234972678 Hits@10 0.273224043715847 MRR 0.19707050894948797 cur_rank 0 abs_cur_rank 0 total_num 182 500
# 152 44 38
# checkcorrect 24 24 real score 42.14736399054527 Hits@1 0.1358695652173913 Hits@3 0.20652173913043478 Hits@10 0.27717391304347827 MRR 0.20143425618345814 cur_rank 0 abs_cur_rank 0 total_num 183 500
# 152 34 194
# checkcorrect 24 24 real score 0.29154884326271713 Hits@1 0.13513513513513514 Hits@3 0.20540540540540542 Hits@10 0.2756756756756757 MRR 0.20048766987691882 cur_rank 37 abs_cur_rank 37 total_num 184 500
# 152 71 248
# checkcorrect 124 124 real score 2.6888572266325355 Hits@1 0.13440860215053763 Hits@3 0.20430107526881722 Hits@10 0.27419354838709675 MRR 0.1996165616435028 cur_rank 25 abs_cur_rank 25 total_num 185 500
# 152 47 649
# checkcorrect 124 124 real score 1.851950298063457 Hits@1 0.13368983957219252 Hits@3 0.20320855614973263 Hits@10 0.2727272727272727 MRR 0.1987629971427354 cur_rank 24 abs_cur_rank 24 total_num 186 500
# 152 44 810
# checkcorrect 124 124 real score 1.1861693398095667 Hits@1 0.13297872340425532 Hits@3 0.20212765957446807 Hits@10 0.2712765957446808 MRR 0.19785350129504947 cur_rank 35 abs_cur_rank 35 total_num 187 500
# 152 22 311
# checkcorrect 4 4 real score 41.380391061306 Hits@1 0.13227513227513227 Hits@3 0.20634920634920634 Hits@10 0.2751322751322751 MRR 0.19857032580318856 cur_rank 2 abs_cur_rank 2 total_num 188 500
# 152 26 873
# checkcorrect 62 62 real score 19.60431106830947 Hits@1 0.13157894736842105 Hits@3 0.21052631578947367 Hits@10 0.2789473684210526 MRR 0.20015679777264545 cur_rank 1 abs_cur_rank 1 total_num 189 500
# 152 32 559
# checkcorrect 0 0 real score -0.4644329957664013 Hits@1 0.13089005235602094 Hits@3 0.2094240837696335 Hits@10 0.2774869109947644 MRR 0.19922267385988177 cur_rank 45 abs_cur_rank 45 total_num 190 500
# 152 40 128
# checkcorrect 24 24 real score 13.18775121960789 Hits@1 0.13020833333333334 Hits@3 0.20833333333333334 Hits@10 0.28125 MRR 0.1987058891001949 cur_rank 9 abs_cur_rank 9 total_num 191 500
# 152 37 332
# checkcorrect 28 28 real score -1.1940597279462963 Hits@1 0.12953367875647667 Hits@3 0.20725388601036268 Hits@10 0.27979274611398963 MRR 0.19778896288949327 cur_rank 45 abs_cur_rank 45 total_num 192 500
# 152 48 466
# checkcorrect 68 68 real score 1.9660726487636566 Hits@1 0.12886597938144329 Hits@3 0.20618556701030927 Hits@10 0.27835051546391754 MRR 0.19695352640920868 cur_rank 27 abs_cur_rank 27 total_num 193 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.1282051282051282 Hits@3 0.20512820512820512 Hits@10 0.27692307692307694 MRR 0.1961486365301871 cur_rank 24 abs_cur_rank 24 total_num 194 500
# 152 20 122
# checkcorrect 124 124 real score -0.3542841069865972 Hits@1 0.12755102040816327 Hits@3 0.20408163265306123 Hits@10 0.2755102040816326 MRR 0.19528577117557913 cur_rank 36 abs_cur_rank 36 total_num 195 500
# 152 28 416
# checkcorrect 28 28 real score 10.361838057404384 Hits@1 0.12690355329949238 Hits@3 0.20304568527918782 Hits@10 0.27411167512690354 MRR 0.19471748468907027 cur_rank 11 abs_cur_rank 11 total_num 196 500
# 152 4 184
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.13131313131313133 Hits@3 0.20707070707070707 Hits@10 0.2777777777777778 MRR 0.19878456809973155 cur_rank 0 abs_cur_rank 0 total_num 197 500
# 152 4 50
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.135678391959799 Hits@3 0.21105527638190955 Hits@10 0.2814070351758794 MRR 0.2028107763002354 cur_rank 0 abs_cur_rank 0 total_num 198 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.135 Hits@3 0.21 Hits@10 0.28 MRR 0.2022133890854009 cur_rank 11 abs_cur_rank 12 total_num 199 500
# 152 47 948
# checkcorrect 124 124 real score 2.7588947913609445 Hits@1 0.13432835820895522 Hits@3 0.208955223880597 Hits@10 0.27860696517412936 MRR 0.20146920097526144 cur_rank 18 abs_cur_rank 18 total_num 200 500
# 152 22 2193
# checkcorrect 124 124 real score -1.0643981413450092 Hits@1 0.13366336633663367 Hits@3 0.2079207920792079 Hits@10 0.27722772277227725 MRR 0.20057496400673705 cur_rank 47 abs_cur_rank 47 total_num 201 500
# 152 42 651
# checkcorrect 124 124 real score 1.6593405555468053 Hits@1 0.1330049261083744 Hits@3 0.20689655172413793 Hits@10 0.27586206896551724 MRR 0.19977637570355875 cur_rank 25 abs_cur_rank 25 total_num 202 500
# 152 29 1204
# checkcorrect 124 124 real score 0.589582028798759 Hits@1 0.1323529411764706 Hits@3 0.20588235294117646 Hits@10 0.27450980392156865 MRR 0.1989502660187374 cur_rank 31 abs_cur_rank 31 total_num 203 500
# 152 30 1027
# checkcorrect 124 124 real score -0.46996454847976565 Hits@1 0.13170731707317074 Hits@3 0.2048780487804878 Hits@10 0.2731707317073171 MRR 0.19806688493014427 cur_rank 55 abs_cur_rank 55 total_num 204 500
# 152 19 310
# checkcorrect 18 18 real score 37.04158188402653 Hits@1 0.13106796116504854 Hits@3 0.20388349514563106 Hits@10 0.2766990291262136 MRR 0.19807626898388145 cur_rank 4 abs_cur_rank 4 total_num 205 500
# 152 20 110
# checkcorrect 18 18 real score 33.65720055997372 Hits@1 0.13043478260869565 Hits@3 0.20772946859903382 Hits@10 0.28019323671497587 MRR 0.19872968475368555 cur_rank 2 abs_cur_rank 2 total_num 206 500
# 152 40 1330
# checkcorrect 124 124 real score 1.7261174423620105 Hits@1 0.12980769230769232 Hits@3 0.20673076923076922 Hits@10 0.27884615384615385 MRR 0.19799278504551662 cur_rank 21 abs_cur_rank 21 total_num 207 500
# 152 56 924
# checkcorrect 124 124 real score 2.3443680992349982 Hits@1 0.1291866028708134 Hits@3 0.20574162679425836 Hits@10 0.27751196172248804 MRR 0.19721633289560642 cur_rank 27 abs_cur_rank 27 total_num 208 500
# 152 34 313
# checkcorrect 32 32 real score 6.721543735824525 Hits@1 0.12857142857142856 Hits@3 0.20476190476190476 Hits@10 0.2761904761904762 MRR 0.19650396487047997 cur_rank 20 abs_cur_rank 20 total_num 209 500
# 152 38 339
# checkcorrect 34 34 real score 44.2325399518013 Hits@1 0.12796208530805686 Hits@3 0.20853080568720378 Hits@10 0.2796208530805687 MRR 0.19715244528973522 cur_rank 2 abs_cur_rank 2 total_num 210 500
# 152 41 999
# checkcorrect 0 0 real score 46.58366131782532 Hits@1 0.1320754716981132 Hits@3 0.21226415094339623 Hits@10 0.2830188679245283 MRR 0.20093946205723645 cur_rank 0 abs_cur_rank 0 total_num 211 500
# 152 4 628
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.13615023474178403 Hits@3 0.215962441314554 Hits@10 0.2863849765258216 MRR 0.20469091998185038 cur_rank 0 abs_cur_rank 0 total_num 212 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.13551401869158877 Hits@3 0.21495327102803738 Hits@10 0.2850467289719626 MRR 0.20387602330110824 cur_rank 32 abs_cur_rank 32 total_num 213 500
# 0 0 0
# checkcorrect 124 124 real score 0.0 Hits@1 0.13488372093023257 Hits@3 0.21395348837209302 Hits@10 0.2837209302325581 MRR 0.2029649720299403 cur_rank 124 abs_cur_rank 124 total_num 214 500
# 152 26 164
# checkcorrect 60 60 real score 28.50112397968769 Hits@1 0.13425925925925927 Hits@3 0.21296296296296297 Hits@10 0.28703703703703703 MRR 0.20295124530757946 cur_rank 4 abs_cur_rank 4 total_num 215 500
# 152 20 2709
# checkcorrect 124 124 real score -0.7075206162407994 Hits@1 0.1336405529953917 Hits@3 0.2119815668202765 Hits@10 0.2857142857142857 MRR 0.20214053462425893 cur_rank 36 abs_cur_rank 36 total_num 216 500
# 0 0 0
# checkcorrect 94 94 real score 0.0 Hits@1 0.13302752293577982 Hits@3 0.21100917431192662 Hits@10 0.28440366972477066 MRR 0.20126157031767739 cur_rank 94 abs_cur_rank 94 total_num 217 500
# 152 44 1293
# checkcorrect 46 46 real score 2.2995397252961993 Hits@1 0.1324200913242009 Hits@3 0.2100456621004566 Hits@10 0.2831050228310502 MRR 0.20047303085764887 cur_rank 34 abs_cur_rank 34 total_num 218 500
# 152 20 731
# checkcorrect 124 124 real score -1.9284568298608065 Hits@1 0.1318181818181818 Hits@3 0.20909090909090908 Hits@10 0.2818181818181818 MRR 0.1996208216855096 cur_rank 76 abs_cur_rank 76 total_num 219 500
# 152 46 248
# checkcorrect 112 112 real score 33.22174307703972 Hits@1 0.13122171945701358 Hits@3 0.21266968325791855 Hits@10 0.2850678733031674 MRR 0.2009800034878376 cur_rank 1 abs_cur_rank 1 total_num 220 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.13063063063063063 Hits@3 0.21171171171171171 Hits@10 0.28378378378378377 MRR 0.2002548683369915 cur_rank 24 abs_cur_rank 24 total_num 221 500
# 152 22 2852
# checkcorrect 124 124 real score -0.6771833936218172 Hits@1 0.13004484304932734 Hits@3 0.21076233183856502 Hits@10 0.2825112107623318 MRR 0.19946363360816877 cur_rank 41 abs_cur_rank 41 total_num 222 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.12946428571428573 Hits@3 0.20982142857142858 Hits@10 0.28125 MRR 0.1987084523434137 cur_rank 32 abs_cur_rank 32 total_num 223 500
# 152 32 710
# checkcorrect 124 124 real score 1.2692975127138197 Hits@1 0.1288888888888889 Hits@3 0.2088888888888889 Hits@10 0.28 MRR 0.19801048885151704 cur_rank 23 abs_cur_rank 23 total_num 224 500
# 152 29 501
# checkcorrect 124 124 real score 0.22832289477810264 Hits@1 0.12831858407079647 Hits@3 0.2079646017699115 Hits@10 0.27876106194690264 MRR 0.19725077779232308 cur_rank 37 abs_cur_rank 37 total_num 225 500
# 152 26 6
# checkcorrect 0 0 real score 50.37272834777832 Hits@1 0.13215859030837004 Hits@3 0.21145374449339208 Hits@10 0.28193832599118945 MRR 0.20078711797826 cur_rank 0 abs_cur_rank 0 total_num 226 500
# 152 20 2629
# checkcorrect 124 124 real score -1.9450844954699278 Hits@1 0.13157894736842105 Hits@3 0.21052631578947367 Hits@10 0.2807017543859649 MRR 0.19997500342572375 cur_rank 63 abs_cur_rank 63 total_num 227 500
# 152 23 2294
# checkcorrect 94 94 real score -2.1323525849729776 Hits@1 0.13100436681222707 Hits@3 0.2096069868995633 Hits@10 0.2794759825327511 MRR 0.1991537359955012 cur_rank 83 abs_cur_rank 84 total_num 228 500
# 0 0 0
# checkcorrect 30 30 real score 0.0 Hits@1 0.13043478260869565 Hits@3 0.20869565217391303 Hits@10 0.2782608695652174 MRR 0.19842810264124305 cur_rank 30 abs_cur_rank 30 total_num 229 500
# 152 42 683
# checkcorrect 106 106 real score 12.355150317773223 Hits@1 0.12987012987012986 Hits@3 0.2077922077922078 Hits@10 0.2813852813852814 MRR 0.1980501070069135 cur_rank 8 abs_cur_rank 9 total_num 230 500
# 152 27 3085
# checkcorrect 124 124 real score -2.1096994660329074 Hits@1 0.12931034482758622 Hits@3 0.20689655172413793 Hits@10 0.2801724137931034 MRR 0.19724433547287987 cur_rank 89 abs_cur_rank 89 total_num 231 500
# 152 63 452
# checkcorrect 124 124 real score 4.2775605586357415 Hits@1 0.12875536480686695 Hits@3 0.20600858369098712 Hits@10 0.27896995708154504 MRR 0.19658439523853088 cur_rank 22 abs_cur_rank 22 total_num 232 500
# 152 57 1088
# checkcorrect 124 124 real score 4.354508742690086 Hits@1 0.1282051282051282 Hits@3 0.20512820512820512 Hits@10 0.2777777777777778 MRR 0.19602919127027504 cur_rank 14 abs_cur_rank 14 total_num 233 500
# 152 34 968
# checkcorrect 124 124 real score 0.9693475228268653 Hits@1 0.1276595744680851 Hits@3 0.20425531914893616 Hits@10 0.2765957446808511 MRR 0.19534175964197895 cur_rank 28 abs_cur_rank 28 total_num 234 500
# 152 58 1216
# checkcorrect 124 124 real score 3.536185889970511 Hits@1 0.1271186440677966 Hits@3 0.2033898305084746 Hits@10 0.2754237288135593 MRR 0.19477887082993667 cur_rank 15 abs_cur_rank 15 total_num 235 500
# 152 31 188
# checkcorrect 60 60 real score 23.818142890930176 Hits@1 0.12658227848101267 Hits@3 0.20253164556962025 Hits@10 0.27848101265822783 MRR 0.19455979180895444 cur_rank 6 abs_cur_rank 6 total_num 236 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.13025210084033614 Hits@3 0.20588235294117646 Hits@10 0.2815126050420168 MRR 0.19794399436437898 cur_rank 0 abs_cur_rank 0 total_num 237 500
# 152 45 871
# checkcorrect 122 122 real score 27.48336743749678 Hits@1 0.13389121338912133 Hits@3 0.20920502092050208 Hits@10 0.28451882845188287 MRR 0.20129987723314727 cur_rank 0 abs_cur_rank 0 total_num 238 500
# 152 47 24
# checkcorrect 92 92 real score 8.599220682866871 Hits@1 0.13333333333333333 Hits@3 0.20833333333333334 Hits@10 0.2833333333333333 MRR 0.20065954044308854 cur_rank 20 abs_cur_rank 21 total_num 239 500
# 152 27 704
# checkcorrect 124 124 real score 0.6878296346403658 Hits@1 0.13278008298755187 Hits@3 0.2074688796680498 Hits@10 0.2821576763485477 MRR 0.19996524082852524 cur_rank 29 abs_cur_rank 29 total_num 240 500
# 152 26 862
# checkcorrect 124 124 real score -1.1856174715794623 Hits@1 0.1322314049586777 Hits@3 0.2066115702479339 Hits@10 0.2809917355371901 MRR 0.19919713862279684 cur_rank 70 abs_cur_rank 70 total_num 241 500
# 152 44 759
# checkcorrect 120 120 real score -0.825610818574205 Hits@1 0.13168724279835392 Hits@3 0.205761316872428 Hits@10 0.27983539094650206 MRR 0.19844959426488049 cur_rank 56 abs_cur_rank 56 total_num 242 500
# 152 22 1179
# checkcorrect 124 124 real score 0.12454697070643306 Hits@1 0.13114754098360656 Hits@3 0.20491803278688525 Hits@10 0.2786885245901639 MRR 0.1977470427598073 cur_rank 36 abs_cur_rank 36 total_num 243 500
# 152 19 2980
# checkcorrect 124 124 real score -0.4119412188883871 Hits@1 0.1306122448979592 Hits@3 0.20408163265306123 Hits@10 0.27755102040816326 MRR 0.1970599599922403 cur_rank 33 abs_cur_rank 33 total_num 244 500
# 152 44 262
# checkcorrect 24 24 real score 9.644036976969801 Hits@1 0.13008130081300814 Hits@3 0.2032520325203252 Hits@10 0.2764227642276423 MRR 0.19652990595433145 cur_rank 14 abs_cur_rank 14 total_num 245 500
# 152 54 1088
# checkcorrect 124 124 real score 3.668862466234714 Hits@1 0.12955465587044535 Hits@3 0.20242914979757085 Hits@10 0.27530364372469635 MRR 0.1959591595964417 cur_rank 17 abs_cur_rank 17 total_num 246 500
# 152 23 1057
# checkcorrect 124 124 real score 0.35503339720889926 Hits@1 0.12903225806451613 Hits@3 0.20161290322580644 Hits@10 0.27419354838709675 MRR 0.19529500975935926 cur_rank 31 abs_cur_rank 31 total_num 247 500
# 152 21 107
# checkcorrect 148 148 real score -1.526664787903428 Hits@1 0.1285140562248996 Hits@3 0.20080321285140562 Hits@10 0.27309236947791166 MRR 0.19457063370865632 cur_rank 66 abs_cur_rank 66 total_num 248 500
# 152 62 1219
# checkcorrect 124 124 real score 4.412786766886711 Hits@1 0.128 Hits@3 0.2 Hits@10 0.272 MRR 0.19404235117382168 cur_rank 15 abs_cur_rank 15 total_num 249 500
# 152 21 220
# checkcorrect 60 60 real score 2.2631369028240442 Hits@1 0.12749003984063745 Hits@3 0.199203187250996 Hits@10 0.27091633466135456 MRR 0.1935036307683952 cur_rank 16 abs_cur_rank 16 total_num 250 500
# 152 51 163
# checkcorrect 134 134 real score 2.2484556776471436 Hits@1 0.12698412698412698 Hits@3 0.1984126984126984 Hits@10 0.2698412698412698 MRR 0.19287259556145983 cur_rank 28 abs_cur_rank 28 total_num 251 500
# 152 28 193
# checkcorrect 94 94 real score -0.5664129757788032 Hits@1 0.12648221343873517 Hits@3 0.1976284584980237 Hits@10 0.26877470355731226 MRR 0.19216515008054058 cur_rank 71 abs_cur_rank 71 total_num 252 500
# 152 41 663
# checkcorrect 120 120 real score 1.6060887032654136 Hits@1 0.12598425196850394 Hits@3 0.1968503937007874 Hits@10 0.2677165354330709 MRR 0.19152108031081969 cur_rank 34 abs_cur_rank 34 total_num 253 500
# 152 28 353
# checkcorrect 60 60 real score 20.812765456736088 Hits@1 0.12549019607843137 Hits@3 0.19607843137254902 Hits@10 0.27058823529411763 MRR 0.19120574709827182 cur_rank 8 abs_cur_rank 8 total_num 254 500
# 152 4 944
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.12890625 Hits@3 0.19921875 Hits@10 0.2734375 MRR 0.1943650996486692 cur_rank 0 abs_cur_rank 0 total_num 255 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.12840466926070038 Hits@3 0.19844357976653695 Hits@10 0.2723735408560311 MRR 0.19390812679759686 cur_rank 12 abs_cur_rank 12 total_num 256 500
# 152 61 1097
# checkcorrect 124 124 real score 3.6784941386431456 Hits@1 0.12790697674418605 Hits@3 0.19767441860465115 Hits@10 0.2713178294573643 MRR 0.19336054327879754 cur_rank 18 abs_cur_rank 18 total_num 257 500
# 152 35 897
# checkcorrect 120 120 real score 2.2732251897687092 Hits@1 0.1274131274131274 Hits@3 0.1969111969111969 Hits@10 0.2702702702702703 MRR 0.1927426776033324 cur_rank 29 abs_cur_rank 29 total_num 258 500
# 152 24 1475
# checkcorrect 124 124 real score -1.080962271662429 Hits@1 0.12692307692307692 Hits@3 0.19615384615384615 Hits@10 0.2692307692307692 MRR 0.19207532410959177 cur_rank 51 abs_cur_rank 51 total_num 259 500
# 152 49 1076
# checkcorrect 32 32 real score 7.876780807971954 Hits@1 0.12643678160919541 Hits@3 0.19540229885057472 Hits@10 0.2681992337164751 MRR 0.19163412776021815 cur_rank 12 abs_cur_rank 12 total_num 260 500
# 152 28 185
# checkcorrect 0 0 real score 48.625470999628305 Hits@1 0.1297709923664122 Hits@3 0.1984732824427481 Hits@10 0.27099236641221375 MRR 0.1947194936847975 cur_rank 0 abs_cur_rank 0 total_num 261 500
# 152 29 699
# checkcorrect 124 124 real score 0.016526099061593413 Hits@1 0.12927756653992395 Hits@3 0.19771863117870722 Hits@10 0.26996197718631176 MRR 0.19407417241603397 cur_rank 39 abs_cur_rank 39 total_num 262 500
# 152 22 140
# checkcorrect 60 60 real score 23.654909297823906 Hits@1 0.12878787878787878 Hits@3 0.19696969696969696 Hits@10 0.2727272727272727 MRR 0.19388016851618972 cur_rank 6 abs_cur_rank 7 total_num 263 500
# 152 21 1577
# checkcorrect 124 124 real score -0.5382571297232062 Hits@1 0.12830188679245283 Hits@3 0.19622641509433963 Hits@10 0.27169811320754716 MRR 0.19324785010470857 cur_rank 37 abs_cur_rank 37 total_num 264 500
# 152 59 741
# checkcorrect 124 124 real score 2.647556322393939 Hits@1 0.12781954887218044 Hits@3 0.19548872180451127 Hits@10 0.2706766917293233 MRR 0.19269223617745232 cur_rank 21 abs_cur_rank 21 total_num 265 500
# 152 57 1249
# checkcorrect 124 124 real score 4.261530718300492 Hits@1 0.12734082397003746 Hits@3 0.1947565543071161 Hits@10 0.2696629213483146 MRR 0.19219085525323626 cur_rank 16 abs_cur_rank 16 total_num 266 500
# 152 41 424
# checkcorrect 132 132 real score -0.9678447600454092 Hits@1 0.12686567164179105 Hits@3 0.19402985074626866 Hits@10 0.26865671641791045 MRR 0.19152095738978428 cur_rank 78 abs_cur_rank 78 total_num 267 500
# 0 0 0
# checkcorrect 28 28 real score 0.0 Hits@1 0.12639405204460966 Hits@3 0.19330855018587362 Hits@10 0.26765799256505574 MRR 0.1909371722642486 cur_rank 28 abs_cur_rank 28 total_num 268 500
# 0 0 0
# checkcorrect 62 62 real score 0.0 Hits@1 0.1259259259259259 Hits@3 0.1925925925925926 Hits@10 0.26666666666666666 MRR 0.19028878649983663 cur_rank 62 abs_cur_rank 62 total_num 269 500
# 152 19 982
# checkcorrect 124 124 real score -0.38575235242024064 Hits@1 0.12546125461254612 Hits@3 0.1918819188191882 Hits@10 0.2656826568265683 MRR 0.1896863445829628 cur_rank 36 abs_cur_rank 36 total_num 270 500
# 152 26 3336
# checkcorrect 124 124 real score 0.21090179774910212 Hits@1 0.125 Hits@3 0.19117647058823528 Hits@10 0.2647058823529412 MRR 0.18909709980400294 cur_rank 33 abs_cur_rank 33 total_num 271 500
# 152 32 128
# checkcorrect 148 148 real score 2.268963740905747 Hits@1 0.12454212454212454 Hits@3 0.19047619047619047 Hits@10 0.26373626373626374 MRR 0.18855706158738267 cur_rank 23 abs_cur_rank 23 total_num 272 500
# 152 4 761
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.12773722627737227 Hits@3 0.19343065693430658 Hits@10 0.2664233576642336 MRR 0.1915185321655309 cur_rank 0 abs_cur_rank 0 total_num 273 500
# 152 24 258
# checkcorrect 12 12 real score 35.062265519285575 Hits@1 0.13090909090909092 Hits@3 0.19636363636363635 Hits@10 0.2690909090909091 MRR 0.19445846477583806 cur_rank 0 abs_cur_rank 0 total_num 274 500
# 152 22 1573
# checkcorrect 124 124 real score -0.3740156274288893 Hits@1 0.13043478260869565 Hits@3 0.1956521739130435 Hits@10 0.26811594202898553 MRR 0.19383442041875976 cur_rank 44 abs_cur_rank 44 total_num 275 500
# 152 41 1994
# checkcorrect 122 122 real score 16.920648608356714 Hits@1 0.1299638989169675 Hits@3 0.19855595667870035 Hits@10 0.27075812274368233 MRR 0.19493971131977506 cur_rank 1 abs_cur_rank 1 total_num 276 500
# 152 25 9
# checkcorrect 14 14 real score 26.253487035632133 Hits@1 0.12949640287769784 Hits@3 0.19784172661870503 Hits@10 0.2733812949640288 MRR 0.19495791379704208 cur_rank 4 abs_cur_rank 4 total_num 277 500
# 152 24 116
# checkcorrect 4 4 real score 47.37538820505142 Hits@1 0.12903225806451613 Hits@3 0.2007168458781362 Hits@10 0.27598566308243727 MRR 0.19605125460780537 cur_rank 1 abs_cur_rank 1 total_num 278 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.12857142857142856 Hits@3 0.2 Hits@10 0.275 MRR 0.19549988107944413 cur_rank 23 abs_cur_rank 24 total_num 279 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.12811387900355872 Hits@3 0.199288256227758 Hits@10 0.27402135231316727 MRR 0.19494650071973083 cur_rank 24 abs_cur_rank 24 total_num 280 500
# 0 0 0
# checkcorrect 140 140 real score 0.0 Hits@1 0.1276595744680851 Hits@3 0.19858156028368795 Hits@10 0.2730496453900709 MRR 0.19428035071214864 cur_rank 140 abs_cur_rank 140 total_num 281 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.127208480565371 Hits@3 0.1978798586572438 Hits@10 0.27208480565371024 MRR 0.1937009255516924 cur_rank 32 abs_cur_rank 32 total_num 282 500
# 152 53 110
# checkcorrect 120 120 real score 7.589946752414107 Hits@1 0.1267605633802817 Hits@3 0.19718309859154928 Hits@10 0.2711267605633803 MRR 0.1931655936542099 cur_rank 23 abs_cur_rank 23 total_num 283 500
# 152 40 164
# checkcorrect 32 32 real score 49.771566569805145 Hits@1 0.12982456140350876 Hits@3 0.2 Hits@10 0.2736842105263158 MRR 0.19599659157121269 cur_rank 0 abs_cur_rank 0 total_num 284 500
# 152 59 1513
# checkcorrect 124 124 real score 4.513111753854901 Hits@1 0.12937062937062938 Hits@3 0.1993006993006993 Hits@10 0.2727272727272727 MRR 0.1955169654797461 cur_rank 16 abs_cur_rank 16 total_num 285 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.1289198606271777 Hits@3 0.1986062717770035 Hits@10 0.27177700348432055 MRR 0.19501910699008623 cur_rank 18 abs_cur_rank 18 total_num 286 500
# 152 21 183
# checkcorrect 90 90 real score -2.98527490766719 Hits@1 0.1284722222222222 Hits@3 0.19791666666666666 Hits@10 0.2708333333333333 MRR 0.19438825360933365 cur_rank 74 abs_cur_rank 74 total_num 287 500
# 152 65 869
# checkcorrect 124 124 real score 3.9669655908364803 Hits@1 0.12802768166089964 Hits@3 0.1972318339100346 Hits@10 0.2698961937716263 MRR 0.19390786365067006 cur_rank 17 abs_cur_rank 17 total_num 288 500
# 152 35 1030
# checkcorrect 124 124 real score 2.017822772730142 Hits@1 0.12758620689655173 Hits@3 0.19655172413793104 Hits@10 0.2689655172413793 MRR 0.19338914088245934 cur_rank 22 abs_cur_rank 22 total_num 289 500
# 152 20 2146
# checkcorrect 124 124 real score -0.5899611432105303 Hits@1 0.12714776632302405 Hits@3 0.1958762886597938 Hits@10 0.26804123711340205 MRR 0.1928150056542505 cur_rank 37 abs_cur_rank 37 total_num 290 500
# 152 23 1793
# checkcorrect 6 6 real score 4.359447815455496 Hits@1 0.1267123287671233 Hits@3 0.1952054794520548 Hits@10 0.2671232876712329 MRR 0.19234493904432345 cur_rank 17 abs_cur_rank 17 total_num 291 500
# 152 38 1350
# checkcorrect 28 28 real score 23.08914345409721 Hits@1 0.12627986348122866 Hits@3 0.19795221843003413 Hits@10 0.2696245733788396 MRR 0.19339495631720974 cur_rank 1 abs_cur_rank 1 total_num 292 500
# 152 37 60
# checkcorrect 32 32 real score 27.552157074213028 Hits@1 0.12585034013605442 Hits@3 0.19727891156462585 Hits@10 0.272108843537415 MRR 0.19322305899251563 cur_rank 6 abs_cur_rank 6 total_num 293 500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/714174927.py in <module>
#      18     s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
#      19
# ---> 20     score_dict = relation_ranking(s_true, t_true, 2, 8, one_hop_ind, id2relation, model)
#      21
#      22     #[... [score, r], ...]
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/1646218996.py in relation_ranking(s, t, lower_bd, upper_bd, one_hop, id2relation, model)
#      25         while count <= 50:
#      26
# ---> 27             temp_pair = random.sample(path_holder, 3)
#      28
#      29             path_1, path_2, path_3 = temp_pair[0], temp_pair[1], temp_pair[2]
#
# /opt/anaconda3/envs/python39_tensorfl/lib/python3.9/random.py in sample(self, population, k, counts)
#     448         randbelow = self._randbelow
#     449         if not 0 <= k <= n:
# --> 450             raise ValueError("Sample larger than population or is negative")
#     451         result = [None] * k
#     452         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
########################################################
#obtain the precision-recall area under curve (AUC-PR)##

#randomly select 10% of the triples
selected = random.sample(list(data_ind), min(len(data_ind), 500))

random.shuffle(selected)

###Hit at 1#############################
#generate the negative samples by randomly replace relation with all the other relaiton
Hits_at_1 = 0
Hits_at_3 = 0
Hits_at_10 = 0
MRR_raw = 0.

for i in range(len(selected)):
    
    s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
    
    score_dict = relation_ranking(s_true, t_true, 2, 8, one_hop_ind, id2relation, model)
    
    #[... [score, r], ...]
    temp_list = list()
    
    for r in id2relation:
        
        if r in score_dict:
            
            temp_list.append([score_dict[r], r])
            
        else:
            
            temp_list.append([0.0, r])
        
    sorted_list = sorted(temp_list, key = lambda x: x[0], reverse=True)
    
    p = 0
    exist_tri = 0
    
    while p < len(sorted_list) and sorted_list[p][1] != r_true:
        
        #moreover, we want to remove existing triples
        if ((s_true, sorted_list[p][1], t_true) in data_test) or (
            (s_true, sorted_list[p][1], t_true) in data_valid) or (
            (s_true, sorted_list[p][1], t_true) in data_ind) or (
            (s_true, sorted_list[p][1], t_true) in data) or (
            (s_true, sorted_list[p][1], t_true) in data_train_valid) or (
            (s_true, sorted_list[p][1], t_true) in data_train_test):
            
            exist_tri += 1
            
        p += 1
    
    if p - exist_tri == 0:
        
        Hits_at_1 += 1
        
    if p - exist_tri < 3:
        
        Hits_at_3 += 1
        
    if p - exist_tri < 10:
        
        Hits_at_10 += 1
        
    MRR_raw += 1./float(p - exist_tri + 1.) 
        
    print('checkcorrect', r_true, sorted_list[p][1],
          'real score', sorted_list[p][0],
          'Hits@1', Hits_at_1/(i+1),
          'Hits@3', Hits_at_3/(i+1),
          'Hits@10', Hits_at_10/(i+1),
          'MRR', MRR_raw/(i+1),
          'cur_rank', p - exist_tri,
          'abs_cur_rank', p,
          'total_num', i, len(selected))
# Out:
# 152 40 303
# checkcorrect 24 24 real score 3.467067563906312 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.03333333333333333 cur_rank 29 abs_cur_rank 29 total_num 0 500
# 152 58 121
# checkcorrect 32 32 real score 0.03531505726277828 Hits@1 0.0 Hits@3 0.0 Hits@10 0.0 MRR 0.023076923076923078 cur_rank 77 abs_cur_rank 77 total_num 1 500
# 152 46 369
# checkcorrect 34 34 real score 32.589312763884664 Hits@1 0.0 Hits@3 0.0 Hits@10 0.3333333333333333 MRR 0.09871794871794871 cur_rank 3 abs_cur_rank 3 total_num 2 500
# 152 24 2121
# checkcorrect 124 124 real score 0.014906604774296284 Hits@1 0.0 Hits@3 0.0 Hits@10 0.25 MRR 0.0807952182952183 cur_rank 36 abs_cur_rank 36 total_num 3 500
# 152 62 1161
# checkcorrect 124 124 real score 4.658795545808971 Hits@1 0.0 Hits@3 0.0 Hits@10 0.2 MRR 0.07713617463617464 cur_rank 15 abs_cur_rank 15 total_num 4 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.0 Hits@3 0.0 Hits@10 0.16666666666666666 MRR 0.07305207535470694 cur_rank 18 abs_cur_rank 18 total_num 5 500
# 152 46 470
# checkcorrect 20 20 real score 46.316094517707825 Hits@1 0.14285714285714285 Hits@3 0.14285714285714285 Hits@10 0.2857142857142857 MRR 0.20547320744689165 cur_rank 0 abs_cur_rank 0 total_num 6 500
# 152 37 941
# checkcorrect 124 124 real score 0.6359270170796663 Hits@1 0.125 Hits@3 0.125 Hits@10 0.25 MRR 0.18269603326021625 cur_rank 42 abs_cur_rank 42 total_num 7 500
# 152 42 298
# checkcorrect 28 28 real score 11.80524664837867 Hits@1 0.1111111111111111 Hits@3 0.1111111111111111 Hits@10 0.3333333333333333 MRR 0.17350758512019224 cur_rank 9 abs_cur_rank 9 total_num 8 500
# 152 22 212
# checkcorrect 60 60 real score 21.090814135968685 Hits@1 0.1 Hits@3 0.1 Hits@10 0.4 MRR 0.168656826608173 cur_rank 7 abs_cur_rank 7 total_num 9 500
# 152 20 1169
# checkcorrect 124 124 real score -0.24906084267422557 Hits@1 0.09090909090909091 Hits@3 0.09090909090909091 Hits@10 0.36363636363636365 MRR 0.15554168272583355 cur_rank 40 abs_cur_rank 40 total_num 10 500
# 152 30 523
# checkcorrect 28 28 real score 5.6909054815769196 Hits@1 0.08333333333333333 Hits@3 0.08333333333333333 Hits@10 0.3333333333333333 MRR 0.14778820916534743 cur_rank 15 abs_cur_rank 15 total_num 11 500
# 152 4 1004
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.15384615384615385 Hits@3 0.15384615384615385 Hits@10 0.38461538461538464 MRR 0.21334296230647457 cur_rank 0 abs_cur_rank 0 total_num 12 500
# 152 4 16
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.21428571428571427 Hits@3 0.21428571428571427 Hits@10 0.42857142857142855 MRR 0.26953275071315497 cur_rank 0 abs_cur_rank 0 total_num 13 500
# 0 0 0
# checkcorrect 34 34 real score 0.0 Hits@1 0.2 Hits@3 0.2 Hits@10 0.4 MRR 0.2534686625703732 cur_rank 34 abs_cur_rank 34 total_num 14 500
# 152 60 857
# checkcorrect 124 124 real score 3.8995408648625016 Hits@1 0.1875 Hits@3 0.1875 Hits@10 0.375 MRR 0.24153312115972486 cur_rank 15 abs_cur_rank 15 total_num 15 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.17647058823529413 Hits@3 0.17647058823529413 Hits@10 0.35294117647058826 MRR 0.22967823167974105 cur_rank 24 abs_cur_rank 24 total_num 16 500
# 152 46 703
# checkcorrect 124 124 real score 2.16615473292768 Hits@1 0.16666666666666666 Hits@3 0.16666666666666666 Hits@10 0.3333333333333333 MRR 0.21923314473457023 cur_rank 23 abs_cur_rank 23 total_num 17 500
# 152 17 2424
# checkcorrect 124 124 real score -0.6401675310917199 Hits@1 0.15789473684210525 Hits@3 0.15789473684210525 Hits@10 0.3157894736842105 MRR 0.20897825521708965 cur_rank 40 abs_cur_rank 40 total_num 18 500
# 152 35 761
# checkcorrect 124 124 real score 1.1993095711804926 Hits@1 0.15 Hits@3 0.15 Hits@10 0.3 MRR 0.20019600912290186 cur_rank 29 abs_cur_rank 29 total_num 19 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.14285714285714285 Hits@3 0.14285714285714285 Hits@10 0.2857142857142857 MRR 0.19144350595623752 cur_rank 60 abs_cur_rank 60 total_num 20 500
# 152 36 151
# checkcorrect 2 2 real score 25.711940188892186 Hits@1 0.18181818181818182 Hits@3 0.18181818181818182 Hits@10 0.3181818181818182 MRR 0.22819607386731763 cur_rank 0 abs_cur_rank 0 total_num 21 500
# 0 0 0
# checkcorrect 140 140 real score 0.0 Hits@1 0.17391304347826086 Hits@3 0.17391304347826086 Hits@10 0.30434782608695654 MRR 0.21858286189837164 cur_rank 140 abs_cur_rank 140 total_num 22 500
# 152 20 139
# checkcorrect 4 4 real score 47.45858719944954 Hits@1 0.20833333333333334 Hits@3 0.20833333333333334 Hits@10 0.3333333333333333 MRR 0.2511419093192728 cur_rank 0 abs_cur_rank 0 total_num 23 500
# 152 4 1797
# checkcorrect 10 10 real score 50.99950706958771 Hits@1 0.24 Hits@3 0.24 Hits@10 0.36 MRR 0.28109623294650193 cur_rank 0 abs_cur_rank 0 total_num 24 500
# 152 67 766
# checkcorrect 124 124 real score 4.310509166680276 Hits@1 0.23076923076923078 Hits@3 0.23076923076923078 Hits@10 0.34615384615384615 MRR 0.27242159150838857 cur_rank 17 abs_cur_rank 17 total_num 25 500
# 152 22 1168
# checkcorrect 124 124 real score -0.32531782938167453 Hits@1 0.2222222222222222 Hits@3 0.2222222222222222 Hits@10 0.3333333333333333 MRR 0.26311992499862163 cur_rank 46 abs_cur_rank 46 total_num 26 500
# 152 53 1077
# checkcorrect 124 124 real score 3.7687947023659945 Hits@1 0.21428571428571427 Hits@3 0.21428571428571427 Hits@10 0.32142857142857145 MRR 0.25534616144347605 cur_rank 21 abs_cur_rank 21 total_num 27 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.20689655172413793 Hits@3 0.20689655172413793 Hits@10 0.3103448275862069 MRR 0.24758605347311585 cur_rank 32 abs_cur_rank 32 total_num 28 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.23333333333333334 Hits@3 0.23333333333333334 Hits@10 0.3333333333333333 MRR 0.27266651835734534 cur_rank 0 abs_cur_rank 0 total_num 29 500
# 152 20 1086
# checkcorrect 124 124 real score -0.17443029186688364 Hits@1 0.22580645161290322 Hits@3 0.22580645161290322 Hits@10 0.3225806451612903 MRR 0.26465760627815477 cur_rank 40 abs_cur_rank 40 total_num 30 500
# 152 51 17
# checkcorrect 90 90 real score -2.9869830682873726 Hits@1 0.21875 Hits@3 0.21875 Hits@10 0.3125 MRR 0.25664112112261284 cur_rank 122 abs_cur_rank 122 total_num 31 500
# 152 38 18
# checkcorrect 18 18 real score 16.444448007503524 Hits@1 0.21212121212121213 Hits@3 0.21212121212121213 Hits@10 0.3333333333333333 MRR 0.25319312178123493 cur_rank 6 abs_cur_rank 6 total_num 32 500
# 152 51 911
# checkcorrect 120 120 real score 0.3720072997966781 Hits@1 0.20588235294117646 Hits@3 0.20588235294117646 Hits@10 0.3235294117647059 MRR 0.24630120421497217 cur_rank 52 abs_cur_rank 52 total_num 33 500
# 0 0 0
# checkcorrect 14 14 real score 0.0 Hits@1 0.2 Hits@3 0.2 Hits@10 0.3142857142857143 MRR 0.24146182914948947 cur_rank 12 abs_cur_rank 14 total_num 34 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.2222222222222222 Hits@3 0.2222222222222222 Hits@10 0.3333333333333333 MRR 0.262532333895337 cur_rank 0 abs_cur_rank 0 total_num 35 500
# 152 59 895
# checkcorrect 124 124 real score 3.383857248816639 Hits@1 0.21621621621621623 Hits@3 0.21621621621621623 Hits@10 0.32432432432432434 MRR 0.2569383669131807 cur_rank 17 abs_cur_rank 17 total_num 36 500
# 152 31 185
# checkcorrect 0 0 real score 49.604769825935364 Hits@1 0.23684210526315788 Hits@3 0.23684210526315788 Hits@10 0.34210526315789475 MRR 0.2764926204154654 cur_rank 0 abs_cur_rank 0 total_num 37 500
# 152 21 2319
# checkcorrect 124 124 real score -1.1336023586336523 Hits@1 0.23076923076923078 Hits@3 0.23076923076923078 Hits@10 0.3333333333333333 MRR 0.27006052824176185 cur_rank 38 abs_cur_rank 38 total_num 38 500
# 152 56 1012
# checkcorrect 124 124 real score 3.2857534303329885 Hits@1 0.225 Hits@3 0.225 Hits@10 0.325 MRR 0.264624804509402 cur_rank 18 abs_cur_rank 18 total_num 39 500
# 152 16 2615
# checkcorrect 124 124 real score -1.1578025575727224 Hits@1 0.21951219512195122 Hits@3 0.21951219512195122 Hits@10 0.3170731707317073 MRR 0.25862221216816095 cur_rank 53 abs_cur_rank 53 total_num 40 500
# 152 68 1211
# checkcorrect 124 124 real score 5.340010401327163 Hits@1 0.21428571428571427 Hits@3 0.21428571428571427 Hits@10 0.30952380952380953 MRR 0.254051842037173 cur_rank 14 abs_cur_rank 14 total_num 41 500
# 152 20 2583
# checkcorrect 124 124 real score -0.9507281864061952 Hits@1 0.20930232558139536 Hits@3 0.20930232558139536 Hits@10 0.3023255813953488 MRR 0.24867220089043113 cur_rank 43 abs_cur_rank 43 total_num 42 500
# 152 35 20
# checkcorrect 0 0 real score 38.94167596101761 Hits@1 0.22727272727272727 Hits@3 0.22727272727272727 Hits@10 0.3181818181818182 MRR 0.2657478326883759 cur_rank 0 abs_cur_rank 0 total_num 43 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.2222222222222222 Hits@3 0.2222222222222222 Hits@10 0.3111111111111111 MRR 0.2602066240202553 cur_rank 60 abs_cur_rank 60 total_num 44 500
# 152 19 2495
# checkcorrect 124 124 real score -0.3196194116026163 Hits@1 0.21739130434782608 Hits@3 0.21739130434782608 Hits@10 0.30434782608695654 MRR 0.2551073718815764 cur_rank 38 abs_cur_rank 38 total_num 45 500
# 152 51 960
# checkcorrect 124 124 real score 2.676052486291155 Hits@1 0.2127659574468085 Hits@3 0.2127659574468085 Hits@10 0.2978723404255319 MRR 0.2506927266845013 cur_rank 20 abs_cur_rank 20 total_num 46 500
# 152 33 1006
# checkcorrect 124 124 real score -0.7940260786563158 Hits@1 0.20833333333333334 Hits@3 0.20833333333333334 Hits@10 0.2916666666666667 MRR 0.24578090681887274 cur_rank 66 abs_cur_rank 66 total_num 47 500
# 152 47 1023
# checkcorrect 124 124 real score 1.5613039329182357 Hits@1 0.20408163265306123 Hits@3 0.20408163265306123 Hits@10 0.2857142857142857 MRR 0.24158129647563042 cur_rank 24 abs_cur_rank 24 total_num 48 500
# 152 61 954
# checkcorrect 124 124 real score 5.093213888350874 Hits@1 0.2 Hits@3 0.2 Hits@10 0.28 MRR 0.23799967054611781 cur_rank 15 abs_cur_rank 15 total_num 49 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.19607843137254902 Hits@3 0.19607843137254902 Hits@10 0.27450980392156865 MRR 0.23411732406482136 cur_rank 24 abs_cur_rank 24 total_num 50 500
# 152 40 1383
# checkcorrect 106 106 real score 10.262104566209018 Hits@1 0.19230769230769232 Hits@3 0.19230769230769232 Hits@10 0.2692307692307692 MRR 0.23136331958105733 cur_rank 10 abs_cur_rank 11 total_num 51 500
# 0 0 0
# checkcorrect 120 120 real score 0.0 Hits@1 0.18867924528301888 Hits@3 0.18867924528301888 Hits@10 0.2641509433962264 MRR 0.22715390718914902 cur_rank 120 abs_cur_rank 120 total_num 52 500
# 152 76 1006
# checkcorrect 124 124 real score 5.395769857335836 Hits@1 0.18518518518518517 Hits@3 0.18518518518518517 Hits@10 0.25925925925925924 MRR 0.22403667797104931 cur_rank 16 abs_cur_rank 16 total_num 53 500
# 152 18 2736
# checkcorrect 124 124 real score -0.9676001584157348 Hits@1 0.18181818181818182 Hits@3 0.18181818181818182 Hits@10 0.2545454545454545 MRR 0.2204294842923216 cur_rank 38 abs_cur_rank 38 total_num 54 500
# 152 26 1766
# checkcorrect 6 6 real score 4.993340854998678 Hits@1 0.17857142857142858 Hits@3 0.17857142857142858 Hits@10 0.25 MRR 0.21754366366945452 cur_rank 16 abs_cur_rank 16 total_num 55 500
# 152 49 160
# checkcorrect 30 30 real score -4.234715498052537 Hits@1 0.17543859649122806 Hits@3 0.17543859649122806 Hits@10 0.24561403508771928 MRR 0.2138600161941265 cur_rank 131 abs_cur_rank 131 total_num 56 500
# 152 70 370
# checkcorrect 0 0 real score 38.02245789766312 Hits@1 0.1896551724137931 Hits@3 0.1896551724137931 Hits@10 0.25862068965517243 MRR 0.2274141538459519 cur_rank 0 abs_cur_rank 0 total_num 57 500
# 152 42 1191
# checkcorrect 116 116 real score -0.8933813815237954 Hits@1 0.1864406779661017 Hits@3 0.1864406779661017 Hits@10 0.2542372881355932 MRR 0.22386234010037886 cur_rank 55 abs_cur_rank 56 total_num 58 500
# 152 26 8
# checkcorrect 0 0 real score 50.85820388793945 Hits@1 0.2 Hits@3 0.2 Hits@10 0.26666666666666666 MRR 0.23679796776537254 cur_rank 0 abs_cur_rank 0 total_num 59 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.19672131147540983 Hits@3 0.19672131147540983 Hits@10 0.26229508196721313 MRR 0.2335717715724976 cur_rank 24 abs_cur_rank 24 total_num 60 500
# 152 38 213
# checkcorrect 32 32 real score 48.563433051109314 Hits@1 0.20967741935483872 Hits@3 0.20967741935483872 Hits@10 0.27419354838709675 MRR 0.245933517192296 cur_rank 0 abs_cur_rank 0 total_num 61 500
# 152 61 136
# checkcorrect 98 98 real score -1.1571099106222391 Hits@1 0.20634920634920634 Hits@3 0.20634920634920634 Hits@10 0.2698412698412698 MRR 0.24219344990909314 cur_rank 96 abs_cur_rank 97 total_num 62 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.203125 Hits@3 0.203125 Hits@10 0.265625 MRR 0.23923154567531618 cur_rank 18 abs_cur_rank 18 total_num 63 500
# 152 22 1834
# checkcorrect 124 124 real score 0.2849293958861381 Hits@1 0.2 Hits@3 0.2 Hits@10 0.26153846153846155 MRR 0.23597841078458484 cur_rank 35 abs_cur_rank 35 total_num 64 500
# 152 24 2810
# checkcorrect 124 124 real score -0.3476592074148357 Hits@1 0.19696969696969696 Hits@3 0.19696969696969696 Hits@10 0.25757575757575757 MRR 0.23272535298094993 cur_rank 46 abs_cur_rank 46 total_num 65 500
# 152 40 1217
# checkcorrect 120 120 real score 5.1932504079304636 Hits@1 0.19402985074626866 Hits@3 0.19402985074626866 Hits@10 0.2537313432835821 MRR 0.2301846760707865 cur_rank 15 abs_cur_rank 16 total_num 66 500
# 0 0 0
# checkcorrect 90 90 real score 0.0 Hits@1 0.19117647058823528 Hits@3 0.19117647058823528 Hits@10 0.25 MRR 0.2269612104078192 cur_rank 90 abs_cur_rank 90 total_num 67 500
# 152 21 146
# checkcorrect 14 14 real score 38.42397880554199 Hits@1 0.18840579710144928 Hits@3 0.2028985507246377 Hits@10 0.2608695652173913 MRR 0.23091829431495225 cur_rank 1 abs_cur_rank 1 total_num 68 500
# 0 0 0
# checkcorrect 42 42 real score 0.0 Hits@1 0.18571428571428572 Hits@3 0.2 Hits@10 0.2571428571428571 MRR 0.22795168745264563 cur_rank 42 abs_cur_rank 42 total_num 69 500
# 152 35 313
# checkcorrect 120 120 real score -1.1252833630423993 Hits@1 0.18309859154929578 Hits@3 0.19718309859154928 Hits@10 0.2535211267605634 MRR 0.2249926093597512 cur_rank 55 abs_cur_rank 55 total_num 70 500
# 152 4 188
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.19444444444444445 Hits@3 0.20833333333333334 Hits@10 0.2638888888888889 MRR 0.2357566008964213 cur_rank 0 abs_cur_rank 0 total_num 71 500
# 152 58 945
# checkcorrect 124 124 real score 3.149134307168424 Hits@1 0.1917808219178082 Hits@3 0.2054794520547945 Hits@10 0.2602739726027397 MRR 0.23324803895191376 cur_rank 18 abs_cur_rank 18 total_num 72 500
# 0 0 0
# checkcorrect 2 2 real score 0.0 Hits@1 0.1891891891891892 Hits@3 0.21621621621621623 Hits@10 0.2702702702702703 MRR 0.23460054293004104 cur_rank 2 abs_cur_rank 2 total_num 73 500
# 0 0 0
# checkcorrect 120 120 real score 0.0 Hits@1 0.18666666666666668 Hits@3 0.21333333333333335 Hits@10 0.26666666666666666 MRR 0.23158272852843942 cur_rank 120 abs_cur_rank 120 total_num 74 500
# 152 23 168
# checkcorrect 14 14 real score 37.58619222044945 Hits@1 0.18421052631578946 Hits@3 0.2236842105263158 Hits@10 0.27631578947368424 MRR 0.23292155227587222 cur_rank 2 abs_cur_rank 2 total_num 75 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.18181818181818182 Hits@3 0.22077922077922077 Hits@10 0.2727272727272727 MRR 0.23041607757099075 cur_rank 24 abs_cur_rank 24 total_num 76 500
# 152 26 121
# checkcorrect 4 4 real score 35.94058379530907 Hits@1 0.1794871794871795 Hits@3 0.23076923076923078 Hits@10 0.28205128205128205 MRR 0.23387228170469598 cur_rank 1 abs_cur_rank 1 total_num 77 500
# 152 19 1196
# checkcorrect 94 94 real score -1.9529854780994356 Hits@1 0.17721518987341772 Hits@3 0.22784810126582278 Hits@10 0.27848101265822783 MRR 0.23107010092362387 cur_rank 79 abs_cur_rank 79 total_num 78 500
# 152 37 433
# checkcorrect 120 120 real score -0.6477944630896673 Hits@1 0.175 Hits@3 0.225 Hits@10 0.275 MRR 0.22843172466207856 cur_rank 49 abs_cur_rank 49 total_num 79 500
# 152 37 763
# checkcorrect 92 92 real score 13.425652148202062 Hits@1 0.1728395061728395 Hits@3 0.2222222222222222 Hits@10 0.2716049382716049 MRR 0.2267339143688318 cur_rank 10 abs_cur_rank 10 total_num 80 500
# 152 56 62
# checkcorrect 92 92 real score 9.136347594670951 Hits@1 0.17073170731707318 Hits@3 0.21951219512195122 Hits@10 0.2682926829268293 MRR 0.22461071515637496 cur_rank 18 abs_cur_rank 18 total_num 81 500
# 152 61 1217
# checkcorrect 124 124 real score 4.176192943239585 Hits@1 0.1686746987951807 Hits@3 0.21686746987951808 Hits@10 0.26506024096385544 MRR 0.2226575740099126 cur_rank 15 abs_cur_rank 15 total_num 82 500
# 152 42 388
# checkcorrect 120 120 real score 8.114009948447347 Hits@1 0.16666666666666666 Hits@3 0.21428571428571427 Hits@10 0.2619047619047619 MRR 0.22075093622408032 cur_rank 15 abs_cur_rank 15 total_num 83 500
# 152 26 2042
# checkcorrect 124 124 real score -0.6313469563610852 Hits@1 0.16470588235294117 Hits@3 0.21176470588235294 Hits@10 0.25882352941176473 MRR 0.21844798403320875 cur_rank 39 abs_cur_rank 39 total_num 84 500
# 152 21 1137
# checkcorrect 124 124 real score -0.4944718738552183 Hits@1 0.16279069767441862 Hits@3 0.20930232558139536 Hits@10 0.2558139534883721 MRR 0.21616067178206425 cur_rank 45 abs_cur_rank 45 total_num 85 500
# 152 47 764
# checkcorrect 116 116 real score 14.68192882835865 Hits@1 0.16091954022988506 Hits@3 0.20689655172413793 Hits@10 0.26436781609195403 MRR 0.2149532055674556 cur_rank 8 abs_cur_rank 8 total_num 86 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.1590909090909091 Hits@3 0.20454545454545456 Hits@10 0.26136363636363635 MRR 0.21269684462490443 cur_rank 60 abs_cur_rank 60 total_num 87 500
# 152 24 84
# checkcorrect 4 4 real score 27.22908551618457 Hits@1 0.15730337078651685 Hits@3 0.21348314606741572 Hits@10 0.2696629213483146 MRR 0.21405231079016765 cur_rank 2 abs_cur_rank 2 total_num 88 500
# 152 25 2439
# checkcorrect 92 92 real score 0.5620250425999984 Hits@1 0.15555555555555556 Hits@3 0.2111111111111111 Hits@10 0.26666666666666666 MRR 0.2120323747204561 cur_rank 30 abs_cur_rank 30 total_num 89 500
# 152 44 1250
# checkcorrect 122 122 real score 20.114829276688397 Hits@1 0.15384615384615385 Hits@3 0.21978021978021978 Hits@10 0.27472527472527475 MRR 0.21336535228763057 cur_rank 2 abs_cur_rank 2 total_num 90 500
# 152 37 46
# checkcorrect 12 12 real score 19.12904894212261 Hits@1 0.15217391304347827 Hits@3 0.21739130434782608 Hits@10 0.2826086956521739 MRR 0.2137635549801563 cur_rank 3 abs_cur_rank 3 total_num 91 500
# 152 51 1104
# checkcorrect 124 124 real score 1.9377458663657308 Hits@1 0.15053763440860216 Hits@3 0.21505376344086022 Hits@10 0.27956989247311825 MRR 0.21189512965778903 cur_rank 24 abs_cur_rank 24 total_num 92 500
# 152 29 3069
# checkcorrect 124 124 real score 1.2542457452509552 Hits@1 0.14893617021276595 Hits@3 0.2127659574468085 Hits@10 0.2765957446808511 MRR 0.21010346084089304 cur_rank 22 abs_cur_rank 22 total_num 93 500
# 152 53 1083
# checkcorrect 124 124 real score 2.109921117313206 Hits@1 0.14736842105263157 Hits@3 0.21052631578947367 Hits@10 0.2736842105263158 MRR 0.20834951136751065 cur_rank 22 abs_cur_rank 22 total_num 94 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.15625 Hits@3 0.21875 Hits@10 0.28125 MRR 0.2165958706240991 cur_rank 0 abs_cur_rank 0 total_num 95 500
# 152 40 95
# checkcorrect 0 0 real score 8.13043019385077 Hits@1 0.15463917525773196 Hits@3 0.21649484536082475 Hits@10 0.27835051546391754 MRR 0.2148783874217888 cur_rank 19 abs_cur_rank 19 total_num 96 500
# 152 19 965
# checkcorrect 124 124 real score 0.1830196543596685 Hits@1 0.15306122448979592 Hits@3 0.21428571428571427 Hits@10 0.2755102040816326 MRR 0.21297729600494839 cur_rank 34 abs_cur_rank 34 total_num 97 500
# 152 89 322
# checkcorrect 124 124 real score 12.57808954268694 Hits@1 0.15151515151515152 Hits@3 0.21212121212121213 Hits@10 0.2828282828282828 MRR 0.21226901162971804 cur_rank 6 abs_cur_rank 6 total_num 98 500
# 152 22 123
# checkcorrect 14 14 real score 39.76684692502022 Hits@1 0.16 Hits@3 0.22 Hits@10 0.29 MRR 0.22014632151342084 cur_rank 0 abs_cur_rank 0 total_num 99 500
# 0 0 0
# checkcorrect 122 122 real score 0.0 Hits@1 0.15841584158415842 Hits@3 0.21782178217821782 Hits@10 0.2871287128712871 MRR 0.2180471508182465 cur_rank 122 abs_cur_rank 122 total_num 100 500
# 152 28 288
# checkcorrect 12 12 real score 34.96543687582016 Hits@1 0.16666666666666666 Hits@3 0.22549019607843138 Hits@10 0.29411764705882354 MRR 0.22571335522198918 cur_rank 0 abs_cur_rank 0 total_num 101 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.1650485436893204 Hits@3 0.22330097087378642 Hits@10 0.2912621359223301 MRR 0.22403294962708997 cur_rank 18 abs_cur_rank 18 total_num 102 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.16346153846153846 Hits@3 0.22115384615384615 Hits@10 0.28846153846153844 MRR 0.22203641590589634 cur_rank 60 abs_cur_rank 60 total_num 103 500
# 152 4 105
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.17142857142857143 Hits@3 0.22857142857142856 Hits@10 0.29523809523809524 MRR 0.22944559289726876 cur_rank 0 abs_cur_rank 0 total_num 104 500
# 152 18 2957
# checkcorrect 124 124 real score -1.0522599313408136 Hits@1 0.16981132075471697 Hits@3 0.22641509433962265 Hits@10 0.29245283018867924 MRR 0.2275004063034595 cur_rank 42 abs_cur_rank 42 total_num 105 500
# 152 21 75
# checkcorrect 32 32 real score 0.6597422405611724 Hits@1 0.16822429906542055 Hits@3 0.22429906542056074 Hits@10 0.2897196261682243 MRR 0.22579904311795562 cur_rank 21 abs_cur_rank 21 total_num 106 500
# 152 43 1381
# checkcorrect 124 124 real score 2.748175308573991 Hits@1 0.16666666666666666 Hits@3 0.2222222222222222 Hits@10 0.28703703703703703 MRR 0.22419564067193168 cur_rank 18 abs_cur_rank 18 total_num 107 500
# 152 75 930
# checkcorrect 124 124 real score 5.580013566184789 Hits@1 0.1651376146788991 Hits@3 0.22018348623853212 Hits@10 0.28440366972477066 MRR 0.22271219442723508 cur_rank 15 abs_cur_rank 15 total_num 108 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.16363636363636364 Hits@3 0.21818181818181817 Hits@10 0.2818181818181818 MRR 0.2208365694108325 cur_rank 60 abs_cur_rank 60 total_num 109 500
# 152 22 460
# checkcorrect 12 12 real score 27.448484167456627 Hits@1 0.16216216216216217 Hits@3 0.21621621621621623 Hits@10 0.2882882882882883 MRR 0.21997317689361778 cur_rank 7 abs_cur_rank 7 total_num 110 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.16071428571428573 Hits@3 0.21428571428571427 Hits@10 0.2857142857142857 MRR 0.21847905548338345 cur_rank 18 abs_cur_rank 18 total_num 111 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.1592920353982301 Hits@3 0.21238938053097345 Hits@10 0.2831858407079646 MRR 0.21669310513987267 cur_rank 59 abs_cur_rank 60 total_num 112 500
# 152 23 830
# checkcorrect 124 124 real score 0.26464239740744233 Hits@1 0.15789473684210525 Hits@3 0.21052631578947367 Hits@10 0.2807017543859649 MRR 0.215029367612567 cur_rank 36 abs_cur_rank 36 total_num 113 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.16521739130434782 Hits@3 0.21739130434782608 Hits@10 0.28695652173913044 MRR 0.22185519919854468 cur_rank 0 abs_cur_rank 0 total_num 114 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.16379310344827586 Hits@3 0.21551724137931033 Hits@10 0.28448275862068967 MRR 0.22008397715909991 cur_rank 60 abs_cur_rank 60 total_num 115 500
# 0 0 0
# checkcorrect 68 68 real score 0.0 Hits@1 0.1623931623931624 Hits@3 0.21367521367521367 Hits@10 0.28205128205128205 MRR 0.21833048481700787 cur_rank 66 abs_cur_rank 68 total_num 116 500
# 0 0 0
# checkcorrect 34 34 real score 0.0 Hits@1 0.16101694915254236 Hits@3 0.211864406779661 Hits@10 0.2796610169491525 MRR 0.21672947871437123 cur_rank 33 abs_cur_rank 34 total_num 117 500
# 0 0 0
# checkcorrect 90 90 real score 0.0 Hits@1 0.15966386554621848 Hits@3 0.21008403361344538 Hits@10 0.2773109243697479 MRR 0.2150005672208808 cur_rank 90 abs_cur_rank 90 total_num 118 500
# 152 24 1092
# checkcorrect 124 124 real score -0.038855946622788906 Hits@1 0.15833333333333333 Hits@3 0.20833333333333334 Hits@10 0.275 MRR 0.21343412105259868 cur_rank 36 abs_cur_rank 36 total_num 119 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.15702479338842976 Hits@3 0.2066115702479339 Hits@10 0.2727272727272727 MRR 0.211805685693676 cur_rank 60 abs_cur_rank 60 total_num 120 500
# 152 62 1073
# checkcorrect 124 124 real score 2.367295641452074 Hits@1 0.1557377049180328 Hits@3 0.20491803278688525 Hits@10 0.27049180327868855 MRR 0.21036231356269738 cur_rank 27 abs_cur_rank 27 total_num 121 500
# 152 31 921
# checkcorrect 124 124 real score 0.841271536424756 Hits@1 0.15447154471544716 Hits@3 0.2032520325203252 Hits@10 0.2682926829268293 MRR 0.20892305356083266 cur_rank 29 abs_cur_rank 29 total_num 122 500
# 152 54 315
# checkcorrect 0 0 real score 23.61251731752418 Hits@1 0.1532258064516129 Hits@3 0.20967741935483872 Hits@10 0.27419354838709675 MRR 0.2099263622686754 cur_rank 2 abs_cur_rank 2 total_num 123 500
# 152 15 3132
# checkcorrect 124 124 real score -1.0471918296534568 Hits@1 0.152 Hits@3 0.208 Hits@10 0.272 MRR 0.20839509951867413 cur_rank 53 abs_cur_rank 53 total_num 124 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.15079365079365079 Hits@3 0.20634920634920634 Hits@10 0.2698412698412698 MRR 0.20705863047487513 cur_rank 24 abs_cur_rank 24 total_num 125 500
# 152 35 4
# checkcorrect 60 60 real score 23.25424900650978 Hits@1 0.14960629921259844 Hits@3 0.2047244094488189 Hits@10 0.2755905511811024 MRR 0.20655310695032605 cur_rank 6 abs_cur_rank 6 total_num 126 500
# 152 26 349
# checkcorrect 0 0 real score 50.85659921169281 Hits@1 0.15625 Hits@3 0.2109375 Hits@10 0.28125 MRR 0.21275191080227662 cur_rank 0 abs_cur_rank 0 total_num 127 500
# 0 0 0
# checkcorrect 4 4 real score 0.0 Hits@1 0.15503875968992248 Hits@3 0.20930232558139536 Hits@10 0.2868217054263566 MRR 0.21265305878055354 cur_rank 4 abs_cur_rank 4 total_num 128 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.15384615384615385 Hits@3 0.2076923076923077 Hits@10 0.2846153846153846 MRR 0.21165829166172875 cur_rank 11 abs_cur_rank 12 total_num 129 500
# 152 67 797
# checkcorrect 124 124 real score 4.4288312629796565 Hits@1 0.15267175572519084 Hits@3 0.20610687022900764 Hits@10 0.2824427480916031 MRR 0.21044434728986341 cur_rank 18 abs_cur_rank 18 total_num 130 500
# 152 42 1251
# checkcorrect 114 114 real score -2.3720484604127705 Hits@1 0.15151515151515152 Hits@3 0.20454545454545456 Hits@10 0.2803030303030303 MRR 0.2089273755803391 cur_rank 97 abs_cur_rank 98 total_num 131 500
# 152 37 154
# checkcorrect 32 32 real score 2.696713514160365 Hits@1 0.15037593984962405 Hits@3 0.20300751879699247 Hits@10 0.2781954887218045 MRR 0.20760711962359474 cur_rank 29 abs_cur_rank 29 total_num 132 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.14925373134328357 Hits@3 0.20149253731343283 Hits@10 0.27611940298507465 MRR 0.20645058573795125 cur_rank 18 abs_cur_rank 18 total_num 133 500
# 152 20 165
# checkcorrect 14 14 real score 36.99306562542915 Hits@1 0.14814814814814814 Hits@3 0.2 Hits@10 0.2814814814814815 MRR 0.20677317399174422 cur_rank 3 abs_cur_rank 3 total_num 134 500
# 152 61 1150
# checkcorrect 124 124 real score 4.4079144520219415 Hits@1 0.14705882352941177 Hits@3 0.19852941176470587 Hits@10 0.27941176470588236 MRR 0.2057123418300402 cur_rank 15 abs_cur_rank 15 total_num 135 500
# 152 71 696
# checkcorrect 124 124 real score 4.101202441845089 Hits@1 0.145985401459854 Hits@3 0.19708029197080293 Hits@10 0.2773722627737226 MRR 0.20464016071749805 cur_rank 16 abs_cur_rank 16 total_num 136 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.14492753623188406 Hits@3 0.1956521739130435 Hits@10 0.2753623188405797 MRR 0.2033768481782628 cur_rank 32 abs_cur_rank 32 total_num 137 500
# 152 30 53
# checkcorrect 32 32 real score 26.224515438079834 Hits@1 0.14388489208633093 Hits@3 0.19424460431654678 Hits@10 0.2805755395683453 MRR 0.20294145461480148 cur_rank 6 abs_cur_rank 6 total_num 138 500
# 152 23 545
# checkcorrect 124 124 real score 0.17125033400952816 Hits@1 0.14285714285714285 Hits@3 0.19285714285714287 Hits@10 0.2785714285714286 MRR 0.2016750229792745 cur_rank 38 abs_cur_rank 38 total_num 139 500
# 152 28 286
# checkcorrect 12 12 real score 28.357987642288208 Hits@1 0.14893617021276595 Hits@3 0.19858156028368795 Hits@10 0.28368794326241137 MRR 0.20733690224892504 cur_rank 0 abs_cur_rank 0 total_num 140 500
# 152 28 1416
# checkcorrect 124 124 real score 0.873025237582624 Hits@1 0.14788732394366197 Hits@3 0.19718309859154928 Hits@10 0.28169014084507044 MRR 0.20613760742348922 cur_rank 26 abs_cur_rank 26 total_num 141 500
# 152 35 1889
# checkcorrect 124 124 real score 1.7567655658349395 Hits@1 0.14685314685314685 Hits@3 0.1958041958041958 Hits@10 0.27972027972027974 MRR 0.20502908602625536 cur_rank 20 abs_cur_rank 20 total_num 142 500
# 152 53 774
# checkcorrect 124 124 real score 2.1079759337008 Hits@1 0.14583333333333334 Hits@3 0.19444444444444445 Hits@10 0.2777777777777778 MRR 0.20384473653038337 cur_rank 28 abs_cur_rank 28 total_num 143 500
# 152 21 1091
# checkcorrect 124 124 real score -0.7718793610110879 Hits@1 0.14482758620689656 Hits@3 0.19310344827586207 Hits@10 0.27586206896551724 MRR 0.202546669381898 cur_rank 63 abs_cur_rank 63 total_num 144 500
# 152 20 243
# checkcorrect 124 124 real score -1.3666548975743353 Hits@1 0.14383561643835616 Hits@3 0.1917808219178082 Hits@10 0.273972602739726 MRR 0.2012572107853488 cur_rank 69 abs_cur_rank 69 total_num 145 500
# 0 0 0
# checkcorrect 4 4 real score 0.0 Hits@1 0.14285714285714285 Hits@3 0.19047619047619047 Hits@10 0.2789115646258503 MRR 0.20124865833102668 cur_rank 4 abs_cur_rank 4 total_num 146 500
# 0 0 0
# checkcorrect 94 94 real score 0.0 Hits@1 0.14189189189189189 Hits@3 0.1891891891891892 Hits@10 0.27702702702702703 MRR 0.19995999385439456 cur_rank 94 abs_cur_rank 94 total_num 147 500
# 0 0 0
# checkcorrect 148 148 real score 0.0 Hits@1 0.14093959731543623 Hits@3 0.18791946308724833 Hits@10 0.2751677852348993 MRR 0.1986630234889018 cur_rank 148 abs_cur_rank 148 total_num 148 500
# 0 0 0
# checkcorrect 16 16 real score 0.0 Hits@1 0.14 Hits@3 0.18666666666666668 Hits@10 0.2733333333333333 MRR 0.19773076019505423 cur_rank 16 abs_cur_rank 16 total_num 149 500
# 152 20 945
# checkcorrect 28 28 real score -2.416594546753913 Hits@1 0.1390728476821192 Hits@3 0.18543046357615894 Hits@10 0.271523178807947 MRR 0.19657179670189012 cur_rank 43 abs_cur_rank 43 total_num 150 500
# 152 23 1128
# checkcorrect 124 124 real score 0.7616708013229072 Hits@1 0.13815789473684212 Hits@3 0.18421052631578946 Hits@10 0.26973684210526316 MRR 0.19553159763451938 cur_rank 25 abs_cur_rank 25 total_num 151 500
# 152 37 212
# checkcorrect 30 30 real score 38.15072363615036 Hits@1 0.13725490196078433 Hits@3 0.1830065359477124 Hits@10 0.27450980392156865 MRR 0.1955608028787382 cur_rank 4 abs_cur_rank 4 total_num 152 500
# 152 66 2082
# checkcorrect 124 124 real score 6.3643108564428985 Hits@1 0.13636363636363635 Hits@3 0.18181818181818182 Hits@10 0.2727272727272727 MRR 0.1947547494277631 cur_rank 13 abs_cur_rank 13 total_num 153 500
# 152 34 152
# checkcorrect 4 4 real score 21.554534657858312 Hits@1 0.13548387096774195 Hits@3 0.1870967741935484 Hits@10 0.27741935483870966 MRR 0.19672407362500335 cur_rank 1 abs_cur_rank 1 total_num 154 500
# 152 56 753
# checkcorrect 124 124 real score 2.6821427387185395 Hits@1 0.1346153846153846 Hits@3 0.1858974358974359 Hits@10 0.27564102564102566 MRR 0.19574172867144285 cur_rank 22 abs_cur_rank 22 total_num 155 500
# 152 21 29
# checkcorrect 18 18 real score 23.735639042337425 Hits@1 0.1337579617834395 Hits@3 0.1910828025477707 Hits@10 0.2802547770700637 MRR 0.1966181083189708 cur_rank 2 abs_cur_rank 2 total_num 156 500
# 152 45 1401
# checkcorrect 12 12 real score 19.30354082211852 Hits@1 0.13291139240506328 Hits@3 0.189873417721519 Hits@10 0.2848101265822785 MRR 0.19642854223256384 cur_rank 5 abs_cur_rank 5 total_num 157 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.13836477987421383 Hits@3 0.1949685534591195 Hits@10 0.2893081761006289 MRR 0.20148245077198168 cur_rank 0 abs_cur_rank 0 total_num 158 500
# 152 48 566
# checkcorrect 134 134 real score 1.9387096725404263 Hits@1 0.1375 Hits@3 0.19375 Hits@10 0.2875 MRR 0.20047318545465678 cur_rank 24 abs_cur_rank 24 total_num 159 500
# 0 0 1
# checkcorrect 94 94 real score 0.0 Hits@1 0.13664596273291926 Hits@3 0.19254658385093168 Hits@10 0.2857142857142857 MRR 0.19929339123313392 cur_rank 94 abs_cur_rank 94 total_num 160 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.13580246913580246 Hits@3 0.19135802469135801 Hits@10 0.2839506172839506 MRR 0.19825024085702217 cur_rank 32 abs_cur_rank 32 total_num 161 500
# 152 19 1010
# checkcorrect 124 124 real score -1.138583761639893 Hits@1 0.13496932515337423 Hits@3 0.1901840490797546 Hits@10 0.2822085889570552 MRR 0.19715918516627545 cur_rank 48 abs_cur_rank 48 total_num 162 500
# 152 27 1253
# checkcorrect 124 124 real score 0.16942035406827927 Hits@1 0.13414634146341464 Hits@3 0.18902439024390244 Hits@10 0.2804878048780488 MRR 0.19610943403721282 cur_rank 39 abs_cur_rank 39 total_num 163 500
# 0 0 0
# checkcorrect 94 94 real score 0.0 Hits@1 0.13333333333333333 Hits@3 0.18787878787878787 Hits@10 0.2787878787878788 MRR 0.1949846878660144 cur_rank 94 abs_cur_rank 94 total_num 164 500
# 152 43 1257
# checkcorrect 124 124 real score 0.6478894725441933 Hits@1 0.13253012048192772 Hits@3 0.18674698795180722 Hits@10 0.27710843373493976 MRR 0.19393825357612685 cur_rank 46 abs_cur_rank 46 total_num 165 500
# 152 20 2694
# checkcorrect 124 124 real score -0.9305451697437093 Hits@1 0.1317365269461078 Hits@3 0.18562874251497005 Hits@10 0.2754491017964072 MRR 0.1929345262461721 cur_rank 37 abs_cur_rank 37 total_num 166 500
# 0 0 0
# checkcorrect 64 64 real score 0.0 Hits@1 0.13095238095238096 Hits@3 0.18452380952380953 Hits@10 0.27380952380952384 MRR 0.19187768153866286 cur_rank 64 abs_cur_rank 64 total_num 167 500
# 152 28 927
# checkcorrect 124 124 real score 0.7664006177801639 Hits@1 0.1301775147928994 Hits@3 0.1834319526627219 Hits@10 0.27218934911242604 MRR 0.1909463506338228 cur_rank 28 abs_cur_rank 28 total_num 168 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.12941176470588237 Hits@3 0.18235294117647058 Hits@10 0.27058823529411763 MRR 0.19005843092421207 cur_rank 24 abs_cur_rank 24 total_num 169 500
# 152 4 352
# checkcorrect 10 10 real score 50.99950647354126 Hits@1 0.13450292397660818 Hits@3 0.1871345029239766 Hits@10 0.27485380116959063 MRR 0.19479493132816403 cur_rank 0 abs_cur_rank 0 total_num 170 500
# 0 0 0
# checkcorrect 120 120 real score 0.0 Hits@1 0.13372093023255813 Hits@3 0.18604651162790697 Hits@10 0.27325581395348836 MRR 0.19371045186003472 cur_rank 120 abs_cur_rank 120 total_num 171 500
# 152 23 2114
# checkcorrect 124 124 real score 0.08315829001367092 Hits@1 0.1329479768786127 Hits@3 0.18497109826589594 Hits@10 0.27167630057803466 MRR 0.19278341649282832 cur_rank 29 abs_cur_rank 29 total_num 172 500
# 152 18 2131
# checkcorrect 124 124 real score -0.690527216065675 Hits@1 0.13218390804597702 Hits@3 0.1839080459770115 Hits@10 0.27011494252873564 MRR 0.19181914398424885 cur_rank 39 abs_cur_rank 39 total_num 173 500
# 152 33 1994
# checkcorrect 34 34 real score 15.100811839103699 Hits@1 0.13142857142857142 Hits@3 0.18285714285714286 Hits@10 0.26857142857142857 MRR 0.19113119785535926 cur_rank 13 abs_cur_rank 13 total_num 174 500
# 152 49 171
# checkcorrect 30 30 real score 36.37891244888306 Hits@1 0.13068181818181818 Hits@3 0.18181818181818182 Hits@10 0.2727272727272727 MRR 0.19118158877663563 cur_rank 4 abs_cur_rank 4 total_num 175 500
# 152 4 205
# checkcorrect 10 10 real score 50.84752142429352 Hits@1 0.13559322033898305 Hits@3 0.1864406779661017 Hits@10 0.2768361581920904 MRR 0.19575118432027047 cur_rank 0 abs_cur_rank 0 total_num 176 500
# 152 45 743
# checkcorrect 30 30 real score 36.75635865330696 Hits@1 0.1348314606741573 Hits@3 0.1853932584269663 Hits@10 0.2808988764044944 MRR 0.19577505407128018 cur_rank 4 abs_cur_rank 4 total_num 177 500
# 152 39 61
# checkcorrect 0 0 real score 24.408101201057434 Hits@1 0.1340782122905028 Hits@3 0.18435754189944134 Hits@10 0.2849162011173184 MRR 0.19561243738186893 cur_rank 5 abs_cur_rank 5 total_num 178 500
# 152 26 7
# checkcorrect 0 0 real score 50.85779684782028 Hits@1 0.1388888888888889 Hits@3 0.18888888888888888 Hits@10 0.28888888888888886 MRR 0.20008125717419187 cur_rank 0 abs_cur_rank 0 total_num 179 500
# 152 68 952
# checkcorrect 124 124 real score 3.9764452558010817 Hits@1 0.13812154696132597 Hits@3 0.1878453038674033 Hits@10 0.287292817679558 MRR 0.19930082773904037 cur_rank 16 abs_cur_rank 16 total_num 180 500
# 152 26 10
# checkcorrect 124 124 real score 0.6722869537770748 Hits@1 0.13736263736263737 Hits@3 0.18681318681318682 Hits@10 0.2857142857142857 MRR 0.1984020005850582 cur_rank 27 abs_cur_rank 27 total_num 181 500
# 152 23 992
# checkcorrect 124 124 real score 0.11460286541841924 Hits@1 0.1366120218579235 Hits@3 0.18579234972677597 Hits@10 0.28415300546448086 MRR 0.1974696277828326 cur_rank 35 abs_cur_rank 35 total_num 182 500
# 152 58 529
# checkcorrect 20 20 real score 37.631750881671906 Hits@1 0.14130434782608695 Hits@3 0.19021739130434784 Hits@10 0.28804347826086957 MRR 0.20183120589270853 cur_rank 0 abs_cur_rank 0 total_num 183 500
# 152 55 827
# checkcorrect 124 124 real score 2.91172657860443 Hits@1 0.14054054054054055 Hits@3 0.1891891891891892 Hits@10 0.2864864864864865 MRR 0.20102472142273373 cur_rank 18 abs_cur_rank 18 total_num 184 500
# 152 37 410
# checkcorrect 32 32 real score 7.783770594745874 Hits@1 0.13978494623655913 Hits@3 0.1881720430107527 Hits@10 0.2849462365591398 MRR 0.20026019888504037 cur_rank 16 abs_cur_rank 16 total_num 185 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.13903743315508021 Hits@3 0.18716577540106952 Hits@10 0.28342245989304815 MRR 0.19960064208310474 cur_rank 12 abs_cur_rank 12 total_num 186 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.13829787234042554 Hits@3 0.18617021276595744 Hits@10 0.28191489361702127 MRR 0.1987517024975563 cur_rank 24 abs_cur_rank 24 total_num 187 500
# 152 17 2193
# checkcorrect 124 124 real score -1.391036062501371 Hits@1 0.13756613756613756 Hits@3 0.18518518518518517 Hits@10 0.2804232804232804 MRR 0.19780185628979552 cur_rank 51 abs_cur_rank 51 total_num 188 500
# 152 26 2536
# checkcorrect 124 124 real score -1.498487105127424 Hits@1 0.1368421052631579 Hits@3 0.18421052631578946 Hits@10 0.2789473684210526 MRR 0.19684176554818933 cur_rank 64 abs_cur_rank 64 total_num 189 500
# 152 61 1013
# checkcorrect 124 124 real score 4.626484351698309 Hits@1 0.13612565445026178 Hits@3 0.18324607329842932 Hits@10 0.2774869109947644 MRR 0.19610204717126456 cur_rank 17 abs_cur_rank 17 total_num 190 500
# 152 37 18
# checkcorrect 4 4 real score 3.075664398726076 Hits@1 0.13541666666666666 Hits@3 0.18229166666666666 Hits@10 0.2760416666666667 MRR 0.195260280043397 cur_rank 28 abs_cur_rank 28 total_num 191 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.13471502590673576 Hits@3 0.18134715025906736 Hits@10 0.27461139896373055 MRR 0.1944558226338457 cur_rank 24 abs_cur_rank 24 total_num 192 500
# 152 20 3202
# checkcorrect 124 124 real score -0.13071755366399884 Hits@1 0.13402061855670103 Hits@3 0.18041237113402062 Hits@10 0.27319587628865977 MRR 0.19359665745417526 cur_rank 35 abs_cur_rank 35 total_num 193 500
# 0 0 0
# checkcorrect 42 42 real score 0.0 Hits@1 0.13333333333333333 Hits@3 0.1794871794871795 Hits@10 0.2717948717948718 MRR 0.19272311466699224 cur_rank 42 abs_cur_rank 42 total_num 194 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.1326530612244898 Hits@3 0.17857142857142858 Hits@10 0.27040816326530615 MRR 0.19182347348309406 cur_rank 60 abs_cur_rank 60 total_num 195 500
# 152 49 707
# checkcorrect 120 120 real score 4.921337853651494 Hits@1 0.1319796954314721 Hits@3 0.17766497461928935 Hits@10 0.26903553299492383 MRR 0.1911169156428112 cur_rank 18 abs_cur_rank 18 total_num 196 500
# 0 0 0
# checkcorrect 32 32 real score 0.0 Hits@1 0.13131313131313133 Hits@3 0.17676767676767677 Hits@10 0.2676767676767677 MRR 0.1903047243027113 cur_rank 32 abs_cur_rank 32 total_num 197 500
# 152 55 651
# checkcorrect 24 24 real score 6.135694057215005 Hits@1 0.1306532663316583 Hits@3 0.17587939698492464 Hits@10 0.2663316582914573 MRR 0.18957683395674063 cur_rank 21 abs_cur_rank 21 total_num 198 500
# 0 0 0
# checkcorrect 30 30 real score 0.0 Hits@1 0.13 Hits@3 0.175 Hits@10 0.265 MRR 0.18879024010953757 cur_rank 30 abs_cur_rank 30 total_num 199 500
# 152 26 874
# checkcorrect 124 124 real score -1.880041440948844 Hits@1 0.12935323383084577 Hits@3 0.17412935323383086 Hits@10 0.263681592039801 MRR 0.18793122912520188 cur_rank 61 abs_cur_rank 61 total_num 200 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.12871287128712872 Hits@3 0.17326732673267325 Hits@10 0.2623762376237624 MRR 0.18719889630775038 cur_rank 24 abs_cur_rank 24 total_num 201 500
# 152 26 2791
# checkcorrect 124 124 real score 1.01160634518601 Hits@1 0.12807881773399016 Hits@3 0.1724137931034483 Hits@10 0.26108374384236455 MRR 0.18650064827399077 cur_rank 21 abs_cur_rank 21 total_num 202 500
# 152 17 159
# checkcorrect 12 12 real score 8.645892035681754 Hits@1 0.12745098039215685 Hits@3 0.1715686274509804 Hits@10 0.2647058823529412 MRR 0.18607662548833395 cur_rank 9 abs_cur_rank 10 total_num 203 500
# 152 22 619
# checkcorrect 124 124 real score -1.179951356491074 Hits@1 0.12682926829268293 Hits@3 0.17073170731707318 Hits@10 0.2634146341463415 MRR 0.18527733571630414 cur_rank 44 abs_cur_rank 44 total_num 204 500
# 152 31 183
# checkcorrect 0 0 real score 49.69392251968384 Hits@1 0.13106796116504854 Hits@3 0.17475728155339806 Hits@10 0.2669902912621359 MRR 0.18923230010603082 cur_rank 0 abs_cur_rank 0 total_num 205 500
# 152 58 1140
# checkcorrect 124 124 real score 5.052664733957499 Hits@1 0.13043478260869565 Hits@3 0.17391304347826086 Hits@10 0.26570048309178745 MRR 0.18864019559666192 cur_rank 14 abs_cur_rank 14 total_num 206 500
# 152 26 325
# checkcorrect 74 74 real score 34.310797929763794 Hits@1 0.12980769230769232 Hits@3 0.17307692307692307 Hits@10 0.2692307692307692 MRR 0.18893519465629335 cur_rank 3 abs_cur_rank 4 total_num 207 500
# 152 38 523
# checkcorrect 118 118 real score 21.713668674230576 Hits@1 0.1291866028708134 Hits@3 0.1722488038277512 Hits@10 0.2727272727272727 MRR 0.18862928463401446 cur_rank 7 abs_cur_rank 7 total_num 208 500
# 152 58 972
# checkcorrect 124 124 real score 4.4494321728125215 Hits@1 0.12857142857142856 Hits@3 0.17142857142857143 Hits@10 0.2714285714285714 MRR 0.18801116199009898 cur_rank 16 abs_cur_rank 16 total_num 209 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.12796208530805686 Hits@3 0.17061611374407584 Hits@10 0.27014218009478674 MRR 0.1873096872887241 cur_rank 24 abs_cur_rank 24 total_num 210 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.12735849056603774 Hits@3 0.16981132075471697 Hits@10 0.2688679245283019 MRR 0.18650347858747046 cur_rank 60 abs_cur_rank 60 total_num 211 500
# 152 24 1341
# checkcorrect 124 124 real score -0.17349485028535128 Hits@1 0.1267605633802817 Hits@3 0.16901408450704225 Hits@10 0.2676056338028169 MRR 0.18573705762674755 cur_rank 42 abs_cur_rank 42 total_num 212 500
# 152 21 324
# checkcorrect 4 4 real score 34.05930785648525 Hits@1 0.1261682242990654 Hits@3 0.17289719626168223 Hits@10 0.27102803738317754 MRR 0.18720557604905247 cur_rank 1 abs_cur_rank 1 total_num 213 500
# 0 0 0
# checkcorrect 98 98 real score 0.0 Hits@1 0.12558139534883722 Hits@3 0.17209302325581396 Hits@10 0.26976744186046514 MRR 0.18638183388185225 cur_rank 98 abs_cur_rank 98 total_num 214 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.12962962962962962 Hits@3 0.17592592592592593 Hits@10 0.27314814814814814 MRR 0.19014858465091777 cur_rank 0 abs_cur_rank 0 total_num 215 500
# 152 28 513
# checkcorrect 124 124 real score 0.7907504332251847 Hits@1 0.12903225806451613 Hits@3 0.17511520737327188 Hits@10 0.271889400921659 MRR 0.1894312306139121 cur_rank 28 abs_cur_rank 28 total_num 216 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.12844036697247707 Hits@3 0.1743119266055046 Hits@10 0.2706422018348624 MRR 0.1888037092759922 cur_rank 18 abs_cur_rank 18 total_num 217 500
# 152 33 1747
# checkcorrect 124 124 real score 1.4999349024146795 Hits@1 0.1278538812785388 Hits@3 0.1735159817351598 Hits@10 0.2694063926940639 MRR 0.18812424028386437 cur_rank 24 abs_cur_rank 24 total_num 218 500
# 152 37 1778
# checkcorrect 6 6 real score 21.155684677883983 Hits@1 0.12727272727272726 Hits@3 0.17272727272727273 Hits@10 0.2727272727272727 MRR 0.18802670585833164 cur_rank 5 abs_cur_rank 5 total_num 219 500
# 152 35 323
# checkcorrect 12 12 real score -4.895967274904251 Hits@1 0.12669683257918551 Hits@3 0.17194570135746606 Hits@10 0.27149321266968324 MRR 0.18720845942731798 cur_rank 138 abs_cur_rank 138 total_num 220 500
# 152 35 1105
# checkcorrect 124 124 real score 1.3055296344682574 Hits@1 0.12612612612612611 Hits@3 0.17117117117117117 Hits@10 0.2702702702702703 MRR 0.18652605323942142 cur_rank 27 abs_cur_rank 27 total_num 221 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.12556053811659193 Hits@3 0.17040358744394618 Hits@10 0.26905829596412556 MRR 0.18576312673441484 cur_rank 60 abs_cur_rank 60 total_num 222 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.125 Hits@3 0.16964285714285715 Hits@10 0.26785714285714285 MRR 0.18500701207320294 cur_rank 60 abs_cur_rank 60 total_num 223 500
# 152 24 186
# checkcorrect 60 60 real score 1.9857795026618987 Hits@1 0.12444444444444444 Hits@3 0.1688888888888889 Hits@10 0.26666666666666666 MRR 0.1844186768148659 cur_rank 18 abs_cur_rank 18 total_num 224 500
# 152 19 484
# checkcorrect 18 18 real score 42.01223361492157 Hits@1 0.12389380530973451 Hits@3 0.17256637168141592 Hits@10 0.26991150442477874 MRR 0.18507759122423967 cur_rank 2 abs_cur_rank 2 total_num 225 500
# 152 57 758
# checkcorrect 124 124 real score 1.9002566642593592 Hits@1 0.12334801762114538 Hits@3 0.17180616740088106 Hits@10 0.2687224669603524 MRR 0.18441960309423985 cur_rank 27 abs_cur_rank 27 total_num 226 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.12280701754385964 Hits@3 0.17105263157894737 Hits@10 0.2675438596491228 MRR 0.183786183782423 cur_rank 24 abs_cur_rank 24 total_num 227 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.1222707423580786 Hits@3 0.1703056768558952 Hits@10 0.2663755458515284 MRR 0.18315829651699758 cur_rank 24 abs_cur_rank 24 total_num 228 500
# 152 32 106
# checkcorrect 148 148 real score -0.8541948867496103 Hits@1 0.12173913043478261 Hits@3 0.16956521739130434 Hits@10 0.26521739130434785 MRR 0.18248617969984293 cur_rank 34 abs_cur_rank 34 total_num 229 500
# 0 0 0
# checkcorrect 12 12 real score 0.0 Hits@1 0.12121212121212122 Hits@3 0.16883116883116883 Hits@10 0.26406926406926406 MRR 0.18208974208603018 cur_rank 10 abs_cur_rank 12 total_num 230 500
# 0 0 0
# checkcorrect 0 0 real score 0.0 Hits@1 0.125 Hits@3 0.1724137931034483 Hits@10 0.2672413793103448 MRR 0.18561521733565936 cur_rank 0 abs_cur_rank 0 total_num 231 500
# 152 19 1574
# checkcorrect 124 124 real score -0.7713671931996942 Hits@1 0.12446351931330472 Hits@3 0.17167381974248927 Hits@10 0.26609442060085836 MRR 0.18490112099186154 cur_rank 51 abs_cur_rank 51 total_num 232 500
# 152 35 853
# checkcorrect 124 124 real score 0.9096838876139373 Hits@1 0.12393162393162394 Hits@3 0.17094017094017094 Hits@10 0.26495726495726496 MRR 0.1842330453832272 cur_rank 34 abs_cur_rank 34 total_num 233 500
# 152 21 2732
# checkcorrect 124 124 real score -0.5537818090524524 Hits@1 0.12340425531914893 Hits@3 0.1702127659574468 Hits@10 0.26382978723404255 MRR 0.18355818572474977 cur_rank 38 abs_cur_rank 38 total_num 234 500
# 0 0 0
# checkcorrect 90 90 real score 0.0 Hits@1 0.1228813559322034 Hits@3 0.1694915254237288 Hits@10 0.2627118644067797 MRR 0.18282696040807295 cur_rank 90 abs_cur_rank 90 total_num 235 500
# 0 0 0
# checkcorrect 140 140 real score 0.0 Hits@1 0.12236286919831224 Hits@3 0.16877637130801687 Hits@10 0.2616033755274262 MRR 0.182085463522729 cur_rank 140 abs_cur_rank 140 total_num 236 500
# 152 22 212
# checkcorrect 60 60 real score 24.201404005289078 Hits@1 0.12184873949579832 Hits@3 0.16806722689075632 Hits@10 0.2647058823529412 MRR 0.18192063864598285 cur_rank 6 abs_cur_rank 6 total_num 237 500
# 152 44 2914
# checkcorrect 124 124 real score 2.7148397411219776 Hits@1 0.12133891213389121 Hits@3 0.16736401673640167 Hits@10 0.26359832635983266 MRR 0.18135870730277392 cur_rank 20 abs_cur_rank 20 total_num 238 500
# 152 21 2272
# checkcorrect 124 124 real score -0.21216057473793626 Hits@1 0.12083333333333333 Hits@3 0.16666666666666666 Hits@10 0.2625 MRR 0.18072930864860834 cur_rank 32 abs_cur_rank 32 total_num 239 500
# 152 51 25
# checkcorrect 90 90 real score -4.095025461167097 Hits@1 0.12033195020746888 Hits@3 0.16597510373443983 Hits@10 0.26141078838174275 MRR 0.18001397265144953 cur_rank 119 abs_cur_rank 119 total_num 240 500
# 0 0 0
# checkcorrect 120 120 real score 0.0 Hits@1 0.11983471074380166 Hits@3 0.1652892561983471 Hits@10 0.2603305785123967 MRR 0.1793042639330961 cur_rank 120 abs_cur_rank 120 total_num 241 500
# 152 43 591
# checkcorrect 30 30 real score 3.1705090049654245 Hits@1 0.11934156378600823 Hits@3 0.1646090534979424 Hits@10 0.25925925925925924 MRR 0.17870356051499006 cur_rank 29 abs_cur_rank 29 total_num 242 500
# 152 34 184
# checkcorrect 124 124 real score -0.6723406980745494 Hits@1 0.11885245901639344 Hits@3 0.16393442622950818 Hits@10 0.2581967213114754 MRR 0.1780515288863928 cur_rank 50 abs_cur_rank 50 total_num 243 500
# 152 45 797
# checkcorrect 34 34 real score 12.553792118094862 Hits@1 0.11836734693877551 Hits@3 0.16326530612244897 Hits@10 0.2571428571428571 MRR 0.17759689679570004 cur_rank 14 abs_cur_rank 14 total_num 244 500
# 0 0 0
# checkcorrect 24 24 real score 0.0 Hits@1 0.11788617886178862 Hits@3 0.16260162601626016 Hits@10 0.25609756097560976 MRR 0.17703755981685573 cur_rank 24 abs_cur_rank 24 total_num 245 500
# 0 0 0
# checkcorrect 122 122 real score 0.0 Hits@1 0.11740890688259109 Hits@3 0.16194331983805668 Hits@10 0.2550607287449393 MRR 0.17635372387144665 cur_rank 122 abs_cur_rank 122 total_num 246 500
# 0 0 0
# checkcorrect 18 18 real score 0.0 Hits@1 0.11693548387096774 Hits@3 0.16129032258064516 Hits@10 0.2540322580645161 MRR 0.17586663448307613 cur_rank 17 abs_cur_rank 18 total_num 247 500
# 152 49 186
# checkcorrect 120 120 real score 0.7970997312804684 Hits@1 0.11646586345381527 Hits@3 0.1606425702811245 Hits@10 0.25301204819277107 MRR 0.1752406640634654 cur_rank 49 abs_cur_rank 49 total_num 248 500
# 152 30 1524
# checkcorrect 60 60 real score 12.137865078635514 Hits@1 0.116 Hits@3 0.16 Hits@10 0.252 MRR 0.1749033377708479 cur_rank 10 abs_cur_rank 10 total_num 249 500
# 152 4 195
# checkcorrect 10 10 real score 50.999507546424866 Hits@1 0.11952191235059761 Hits@3 0.16334661354581673 Hits@10 0.2549800796812749 MRR 0.17819057546897202 cur_rank 0 abs_cur_rank 0 total_num 250 500
# 152 18 307
# checkcorrect 146 146 real score -2.036908849142492 Hits@1 0.11904761904761904 Hits@3 0.1626984126984127 Hits@10 0.25396825396825395 MRR 0.17754747410702398 cur_rank 61 abs_cur_rank 61 total_num 251 500
# 0 0 0
# checkcorrect 10 10 real score 0.0 Hits@1 0.11857707509881422 Hits@3 0.16205533596837945 Hits@10 0.25296442687747034 MRR 0.1772050299046606 cur_rank 10 abs_cur_rank 10 total_num 252 500
# 152 33 183
# checkcorrect 60 60 real score 25.16241727769375 Hits@1 0.11811023622047244 Hits@3 0.16141732283464566 Hits@10 0.2559055118110236 MRR 0.17716354028561337 cur_rank 5 abs_cur_rank 5 total_num 253 500
# 152 18 204
# checkcorrect 4 4 real score 41.85661840438843 Hits@1 0.11764705882352941 Hits@3 0.16470588235294117 Hits@10 0.25882352941176473 MRR 0.17777597084658484 cur_rank 2 abs_cur_rank 2 total_num 254 500
# 0 0 0
# checkcorrect 60 60 real score 0.0 Hits@1 0.1171875 Hits@3 0.1640625 Hits@10 0.2578125 MRR 0.17714557034571127 cur_rank 60 abs_cur_rank 60 total_num 255 500
# 152 30 273
# checkcorrect 60 60 real score 24.146059274673462 Hits@1 0.11673151750972763 Hits@3 0.16342412451361868 Hits@10 0.2607003891050584 MRR 0.17701215233991918 cur_rank 6 abs_cur_rank 6 total_num 256 500
# 152 24 33
# checkcorrect 24 24 real score -1.9000235884450376 Hits@1 0.11627906976744186 Hits@3 0.16279069767441862 Hits@10 0.2596899224806202 MRR 0.17641219137047076 cur_rank 44 abs_cur_rank 44 total_num 257 500
# 152 24 22
# checkcorrect 2 2 real score 29.058510199189186 Hits@1 0.11583011583011583 Hits@3 0.16216216216216217 Hits@10 0.2625482625482625 MRR 0.1762136887010867 cur_rank 7 abs_cur_rank 7 total_num 258 500
# 152 35 31
# checkcorrect 32 32 real score 24.61047300696373 Hits@1 0.11538461538461539 Hits@3 0.16153846153846155 Hits@10 0.2653846153846154 MRR 0.1760853942939946 cur_rank 6 abs_cur_rank 6 total_num 259 500
# 152 30 1044
# checkcorrect 4 4 real score 28.11343102902174 Hits@1 0.11877394636015326 Hits@3 0.16475095785440613 Hits@10 0.2681992337164751 MRR 0.17924215523539694 cur_rank 0 abs_cur_rank 0 total_num 260 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/1312089677.py in <module>
#      18     s_true, r_true, t_true = selected[i][0], selected[i][1], selected[i][2]
#      19
# ---> 20     score_dict = relation_ranking(s_true, t_true, 2, 8, one_hop_ind, id2relation, model)
#      21
#      22     #[... [score, r], ...]
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/1646218996.py in relation_ranking(s, t, lower_bd, upper_bd, one_hop, id2relation, model)
#       5     for iteration in range(20):
#       6
# ----> 7         result, length_dict = Class_2.obtain_paths('target_specified',
#       8                                                    s, t, lower_bd, upper_bd, one_hop)
#       9         if t in result:
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/3003381867.py in obtain_paths(self, mode, s, t_input, lower_bd, upper_bd, one_hop)
#     130         count_dict = defaultdict(int)
#     131
# --> 132         helper(s, [], {s}, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     133
#     134         return(res, length_dict)
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/3003381867.py in helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     124                             count_dict[len(path)] += 1
#     125
# --> 126                             helper(t, path + [r], on_path_en.union({t}), res, direct_nb,
#     127                                    lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     128
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/3003381867.py in helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     124                             count_dict[len(path)] += 1
#     125
# --> 126                             helper(t, path + [r], on_path_en.union({t}), res, direct_nb,
#     127                                    lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     128
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/3003381867.py in helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     124                             count_dict[len(path)] += 1
#     125
# --> 126                             helper(t, path + [r], on_path_en.union({t}), res, direct_nb,
#     127                                    lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     128
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/3003381867.py in helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     124                             count_dict[len(path)] += 1
#     125
# --> 126                             helper(t, path + [r], on_path_en.union({t}), res, direct_nb,
#     127                                    lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     128
#
# /var/folders/1h/rcbfn0354hv_dhq9m90rp5kc0000gn/T/ipykernel_20949/3003381867.py in helper(node, path, on_path_en, res, direct_nb, lower_bd, upper_bd, one_hop, length_dict, count_dict)
#     113                     r = random.choice(temp_list)
#     114
# --> 115                     for i_1 in range(len(one_hop[node][r])):
#     116
#     117                         if count_dict[len(path)] > self.threshold:
#
# KeyboardInterrupt:
